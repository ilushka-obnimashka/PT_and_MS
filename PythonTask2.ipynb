# %% [markdown]
# # Naïve Bayes Classifier

# %% [markdown]
# ## Теория

# %% [markdown]
# ***Примечание 1.*** В основе NBC (Naïve Bayes Classifier) для классификации лежит, **теорема Байеса** :
# \\[P(H|E) = \frac{P(H) P(E|H)}{P(E)}\\]
#
# Для принятия решения нам потребуется научиться вычислять следующие величины:
# \\[P(спам|сообщение) = \frac{P(спам) P(сообщение|спам)}{P(сообщение)}\\]
# где,
# * \\(P(спам|сообщение)\\) - вероятность что сообщение принадлежит классу cпам, именно её нам надо рассчитать;
# * \\(P(спам)\\) - безусловная вероятность встретить сообщение класса спам в корпусе сообщений;
# * \\(P(сообщение|спам)\\) - вероятность встретить сообщение среди всех собщений класса спам;
# * \\(P(сообщение)\\) - безусловная вероятность сообщения в корпусе соообщений.
#
# ***Аналогично рассматривается величина \\(P(не\spaceспам|сообщение)\\)***

# %% [markdown]
# ***Примечание 2.*** Цель классификации состоит в том чтобы понять к какому классу принадлежит сообщение, поэтому нам нужна не сама вероятность, а наиболее вероятный класс(спам / не спам).
# Байесовский классификатор использует оценку **апостериорного максимума (Maximum a posteriori estimation)** для определения наиболее вероятного класса. Грубо говоря, это класс с максимальной вероятностью.
#
# \\[C_{\text{map}} = max(\frac{P(спам) P(сообщение|спам)}{P(сообщение)}, \frac{P(не\spaceспам) P(сообщение|не\spaceспам)}{P(сообщение)})\\]
#
# То есть нам надо рассчитать вероятность для всех классов и выбрать тот класс, который обладает максимальной вероятностью.

# %% [markdown]
# ***Примечание 3.*** знаменатель (вероятность сообщения) является константой и никак не может повлиять на ранжирование классов, поэтому в нашей задаче мы можем его игнорировать.
# **Формула №1:**
# \\[C_{\text{map}} = max(\space P(спам) P(сообщение|спам), P(не\spaceспам) P(сообщение|не\spaceспам)\space)\\]

# %% [markdown]
# ***Примечание 4.*** Байесовский же классификатор представляет документ как набор слов вероятности которых условно не зависят друг от друга.
#
# Исходя из этого предположения условная вероятность документа аппроксимируется произведением условных вероятностей всех слов входящих в документ.
#
# *например для сообщения "Купите наш товар!" принадлежещего классу **Спам***:
# \\[P(Купите\spaceнаш\spaceтовар|спам) ≈ P(Купите|спам) P(наш|спам) P(товар|спам)\\]
#
# Подставив полученное выражение в общем виде в **Формула №1** мы получим:
# \\[C_{\text{map}} = max(\space P(спам) \prod_{i=1}^{n}P(слово\space из\space сообщения|спам), P(не\spaceспам) \prod_{i=1}^{n}P(слово\space из\space сообщения|не\spaceспам)\space)\\]

# %% [markdown]
# ***Примечание 5.***  При достаточно большой длине документа придется перемножать большое количество очень маленьких чисел. Для того чтобы при этом избежать арифметического переполнения снизу зачастую пользуются свойством логарифма произведения: \\(log(ab) = \log(a) + \log(b)\\)
#
# \\[C_{\text{map}} = max(\space \log P(спам) + \sum_{i=1}^{n}\log P(слово\space из\space сообщения|спам), \log P(не\spaceспам) + \sum_{i=1}^{n}\log P(слово\space из\space сообщения|не\spaceспам)\space)\\]

# %% [markdown]
# ***Примечание 6.*** **Проблема неизвестных слов :**
# Но так как может оказаться даже что отдельное слово больше нигде не встречалось, то следует пойти на шаг дальше и применить так называемое сглаживание Лапласа, при котором мы для каждого слова мы притворяемся, что у нас есть ещё два письма: одно содержащее это слово и одно без такого слова. Т.е. финальная формула для вычисления
# такой вероятности выглядит так:
#
# \\[P(слово|спам) = \frac{P(спам-писем\space с\space словом + 1)}{P(спам-писем + 2)}\\]

# %% [markdown]
# ## Реализация

# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import os
import nltk

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Ilya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# ### Обучение
# #### Сбор данных: Соберем набор писем, которые уже помечены как спам или не спам. Создадим DataFrame на основе каталога содержащего наборы данных Enron-Spam.

# %%
def read_files(directory, label):
    """
    Прочитывает все файлы из directory и подготавливает их к упаковке в DF
    :param directory: директория из которой будут читаться файлы
    :param label: метка показывающая класс файла (spam/nam)
    :return: возвращает список подготовленных для упаковки в DF сообщений
    *(сообщение готово к упаковке в DF, если:
        -все слова находятся в lowerCase
        -отсутствуют знаки пунктуации, в т.ч. \space
        -сообщение разбито на токены ([word1, word2, .... wordn])
    """
    messages = []
    for filename in os.listdir(directory):
        with open(os.path.join(directory, filename), 'r') as file:
            text = preprocessing(file.read())
            messages.append((label, text))
    return messages


def create_dataFrame(messages):
    """
    Возвращает dataFrame с подготовленными данными для обучения классификатора на основе Naïve Bayes Classifier
    :param messages: Preprocessed Data (подготовленные данные)
    :return: dataFrame
    """
    df = pd.DataFrame(messages, columns=['Class', 'Message'])
    return df


def preprocessing(text):
    """
    Функция необходима для переработки text.
    Функция выполняет:
        1) Очистка text - удаление ненужных символов, таких как пунктуация, специальные символы.
        2) Приведение к нижнему регистру
        3) Токенизация text - разделение text на отдельные слова или токены.

    :param text: текст, который будет переработан
    :return: переработанный text
    """
    # Перевод слов в нижний регистр
    text = text.lower()

    # Удаление знаков пунткуации
    punctuation = "!\"#$%&'()*+,-./:;<=>?@[\\]^_`{|}~"
    translator = str.maketrans('', '', punctuation)
    text = text.translate(translator)

    #Токенизация
    words = text.split()
    words = list(set(words))

    return words
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Ilya\AppData\Local\Temp\ipykernel_17788\2304485705.py:2: SyntaxWarning: invalid escape sequence '\s'
#   """

# %%
path_directory_spam = r"data2\data\spam"
path_directory_ham = r"data2\data\ham"

messages_spam = read_files(path_directory_spam, "spam")
messages_ham = read_files(path_directory_ham, "ham")

all_messages = messages_ham + messages_spam

df = create_dataFrame(all_messages)
df
# Out:
#      Class                                            Message
# 0      ham  [for, currently, commercial, 2, business, work...
# 1      ham  [means, entirety, would, what, taking, work, s...
# 2      ham  [or, provide, anything, revised, entex, me, el...
# 3      ham  [summary, what, repeat, outlined, answering, p...
# 4      ham  [assignments, hill, would, summary, place, wha...
# ...    ...                                                ...
# 4134  spam  [2005, would, localized, 29, is, listed, ali, ...
# 4135  spam  [2005, would, localized, 29, is, regards, 39, ...
# 4136  spam  [made, suffering, security, 2005, hair, leads,...
# 4137  spam  [unknown, 2005, its, discounted, who, loss, a,...
# 4138  spam  [2005, would, localized, 29, is, regards, list...
#
# [4139 rows x 2 columns]

# %% [markdown]
# #### Найдем оценку вероятности встретить каждое слово в спамном или не спамном сообщении.

# %% [markdown]
# Посчитаем сколько раз каждое слово встречается в каждом из типов сообщений:

# %%
def counts_word(data):
    """
    создает словарь вида {key = слово; value = [#количество вхождений в сообщения spam, #количество вхождений в сообщения ham]
    :param data: dataFrame с указанием класса сообщения (spam/ham) и токенизированным сообщением
    :return: словарь вида {key = слово; value = [#количество вхождений в сообщения spam, #количество вхождений в сообщения ham]
    """
    counts = defaultdict(lambda: [0,0])
    for idx, row in data.iterrows():
        for word in row["Message"]:
            counts[word][0 if  row["Class"] =='spam' else 1] +=1
    return counts

# %%
freq = counts_word(df)
freq
# Out:
# defaultdict(<function __main__.counts_word.<locals>.<lambda>()>,
#             {'for': [1860, 915],
#              'currently': [97, 106],
#              'commercial': [37, 101],
#              '2': [509, 263],
#              'business': [685, 258],
#              'work': [260, 201],
#              'a': [2102, 866],
#              'eott': [0, 5],
#              'me': [284, 528],
#              'analysis': [24, 59],
#              'related': [55, 63],
#              'to': [2374, 1029],
#              'am': [246, 422],
#              'analysts': [10, 36],
#              'subject': [2939, 1200],
#              'months': [117, 78],
#              'i': [840, 722],
#              '6': [290, 108],
#              'roles': [2, 29],
#              'in': [1732, 770],
#              'need': [406, 328],
#              'of': [2031, 831],
#              'period': [39, 30],
#              'means': [144, 20],
#              'entirety': [3, 3],
#              'would': [370, 366],
#              'what': [458, 227],
#              'taking': [61, 44],
#              'stay': [31, 28],
#              'end': [174, 121],
#              'want': [454, 144],
#              'seemed': [14, 13],
#              'met': [13, 48],
#              'arrangements': [2, 21],
#              'energy': [41, 98],
#              'is': [1814, 745],
#              'see': [516, 169],
#              'ltd': [34, 9],
#              'chief': [24, 17],
#              'sue': [5, 8],
#              'ensure': [65, 95],
#              'was': [455, 269],
#              're': [180, 285],
#              'confirmation': [23, 32],
#              'coming': [50, 33],
#              'still': [81, 126],
#              'signed': [26, 28],
#              'piece': [7, 9],
#              'unavailable': [9, 8],
#              'do': [887, 269],
#              'audit': [4, 35],
#              'discussed': [9, 117],
#              'held': [48, 43],
#              'accessible': [9, 5],
#              'are': [1247, 655],
#              'quilkey': [0, 4],
#              'thank': [220, 163],
#              'occur': [58, 17],
#              'fact': [109, 45],
#              'until': [96, 110],
#              'both': [120, 120],
#              'have': [1329, 749],
#              'they': [260, 224],
#              'procedure': [5, 9],
#              'speak': [18, 24],
#              'australia': [24, 17],
#              'houston': [9, 180],
#              'areas': [35, 46],
#              'it': [1218, 486],
#              'independent': [76, 22],
#              'being': [181, 130],
#              'needs': [87, 102],
#              'good': [381, 108],
#              'confirmations': [1, 26],
#              'return': [130, 46],
#              'had': [176, 170],
#              'senior': [33, 40],
#              'our': [1207, 382],
#              'on': [1036, 800],
#              'legal': [110, 57],
#              'required': [90, 66],
#              'individual': [41, 57],
#              'finance': [46, 35],
#              'taken': [39, 44],
#              'lunch': [2, 33],
#              'signing': [6, 6],
#              'directory': [26, 6],
#              'relevant': [18, 13],
#              'therefore': [64, 69],
#              'desk': [18, 62],
#              'make': [576, 153],
#              'working': [123, 147],
#              'with': [1291, 622],
#              'over': [577, 168],
#              'distribute': [38, 15],
#              'settlement': [4, 23],
#              'my': [311, 257],
#              'managing': [34, 51],
#              'you': [2050, 848],
#              'mason': [1, 22],
#              'all': [912, 430],
#              'log': [40, 11],
#              'the': [2230, 1051],
#              'minns': [0, 2],
#              'counsel': [3, 16],
#              'that': [1118, 621],
#              'advise': [9, 25],
#              'authorised': [0, 12],
#              'responsibility': [21, 50],
#              'look': [278, 82],
#              'director': [109, 56],
#              'and': [2020, 954],
#              'event': [21, 41],
#              'office': [88, 213],
#              'quite': [32, 31],
#              'upon': [113, 77],
#              'someone': [42, 55],
#              'clearly': [11, 19],
#              'could': [256, 147],
#              'stage': [25, 10],
#              'primary': [23, 29],
#              'by': [855, 546],
#              'maintained': [2, 8],
#              'planning': [27, 57],
#              'paul': [16, 49],
#              'plan': [57, 110],
#              'new': [542, 264],
#              'heidi': [0, 30],
#              'when': [323, 183],
#              'key': [88, 71],
#              'thanks': [125, 417],
#              'volume': [31, 42],
#              'meantime': [1, 11],
#              'pty': [0, 2],
#              'change': [165, 81],
#              'week': [178, 234],
#              'raised': [9, 19],
#              'agreed': [38, 45],
#              'which': [420, 257],
#              'now': [752, 156],
#              'quickly': [65, 26],
#              'her': [193, 82],
#              'signatories': [0, 2],
#              'timing': [23, 28],
#              'dealer': [29, 2],
#              'procedures': [8, 36],
#              'not': [1247, 416],
#              'enact': [0, 2],
#              'from': [1100, 557],
#              'please': [631, 689],
#              'but': [550, 282],
#              'decided': [60, 26],
#              'david': [21, 131],
#              'list': [262, 180],
#              'opportunity': [132, 58],
#              'order': [413, 86],
#              'approval': [44, 79],
#              'comprehensive': [15, 11],
#              'prepared': [9, 28],
#              'briefly': [0, 11],
#              'we': [1360, 638],
#              'such': [197, 76],
#              'will': [918, 652],
#              'here': [944, 179],
#              'there': [288, 256],
#              'together': [56, 84],
#              'or': [923, 417],
#              'signatory': [0, 2],
#              'current': [182, 122],
#              'its': [421, 50],
#              'going': [129, 127],
#              'sally': [4, 452],
#              'officer': [60, 21],
#              'allow': [44, 42],
#              'changes': [132, 119],
#              'transfer': [150, 33],
#              'due': [153, 113],
#              'be': [1217, 674],
#              'frusco': [0, 2],
#              'detailed': [20, 36],
#              'as': [669, 624],
#              'like': [560, 253],
#              'enron': [0, 612],
#              'structure': [57, 46],
#              'review': [104, 232],
#              'implemented': [3, 20],
#              'move': [97, 57],
#              'no': [735, 150],
#              'issue': [54, 85],
#              'take': [307, 123],
#              'happy': [66, 47],
#              'advised': [32, 9],
#              'implement': [2, 17],
#              'clients': [59, 14],
#              'at': [896, 491],
#              'invoicing': [0, 7],
#              'sydney': [1, 8],
#              'this': [1186, 761],
#              'financial': [125, 84],
#              'action': [91, 54],
#              'time': [609, 321],
#              'faxed': [1, 10],
#              'provide': [264, 139],
#              'anything': [69, 60],
#              'revised': [1, 49],
#              'entex': [0, 5],
#              'else': [33, 43],
#              'attached': [47, 238],
#              'know': [403, 382],
#              'shankman': [0, 24],
#              'if': [749, 576],
#              'explain': [10, 19],
#              'help': [294, 175],
#              'let': [108, 326],
#              'understand': [64, 67],
#              'can': [728, 392],
#              'files': [29, 23],
#              'jeff': [2, 104],
#              'summary': [2, 87],
#              'repeat': [12, 5],
#              'outlined': [11, 17],
#              'answering': [1, 2],
#              'port': [6, 32],
#              'develop': [48, 35],
#              'appropriately': [2, 5],
#              'worryingly': [0, 3],
#              'so': [369, 272],
#              'turmoil': [3, 1],
#              'rapidly': [13, 5],
#              '17': [90, 99],
#              'immersed': [0, 3],
#              'virro': [0, 2],
#              'arrive': [6, 15],
#              'monitor': [14, 23],
#              'ian': [3, 10],
#              'john': [32, 124],
#              'these': [388, 288],
#              'pablo': [0, 2],
#              'listing': [19, 15],
#              'just': [718, 202],
#              'institution': [5, 3],
#              'simply': [169, 30],
#              'between': [67, 82],
#              'pressure': [12, 7],
#              'get': [626, 240],
#              'forgotten': [2, 2],
#              'right': [318, 53],
#              'anyone': [66, 53],
#              'pissanetzky': [0, 2],
#              'single': [30, 12],
#              'explains': [2, 3],
#              'form': [217, 53],
#              'some': [245, 220],
#              'were': [204, 167],
#              'late': [55, 49],
#              'lewis': [4, 25],
#              'seen': [50, 29],
#              'resulted': [7, 14],
#              'polish': [0, 1],
#              'yesterday': [5, 61],
#              'effort': [53, 65],
#              'findings': [4, 19],
#              'add': [65, 49],
#              'likely': [16, 21],
#              'doesn': [35, 20],
#              'risk': [127, 242],
#              'border': [3, 4],
#              't': [603, 189],
#              'because': [243, 111],
#              'largest': [43, 12],
#              'addressed': [4, 20],
#              'capture': [19, 35],
#              'young': [27, 17],
#              'solution': [34, 33],
#              'treatment': [18, 6],
#              'possible': [119, 111],
#              'slipped': [3, 1],
#              'arguing': [0, 1],
#              'given': [111, 87],
#              'steve': [13, 100],
#              'big': [98, 26],
#              'use': [378, 96],
#              'amsterdam': [8, 2],
#              '08': [32, 126],
#              'models': [5, 12],
#              'based': [162, 89],
#              'area': [82, 39],
#              'today': [250, 151],
#              'controls': [3, 52],
#              'corollary': [0, 1],
#              'exhaustive': [0, 6],
#              'enough': [115, 19],
#              'rac': [50, 59],
#              'manual': [13, 29],
#              '05': [60, 111],
#              'exercise': [12, 12],
#              'transaction': [101, 47],
#              'firm': [20, 18],
#              'poullain': [0, 27],
#              'reported': [15, 19],
#              'sage': [2, 32],
#              '09': [37, 155],
#              'booked': [3, 10],
#              'issues': [20, 144],
#              'bound': [8, 3],
#              'lon': [5, 149],
#              '4': [372, 189],
#              'may': [467, 220],
#              'derivative': [1, 3],
#              'joe': [10, 60],
#              'symptoms': [1, 3],
#              'has': [527, 340],
#              'day': [326, 174],
#              '12': [235, 231],
#              'memo': [0, 76],
#              'hill': [14, 14],
#              'place': [123, 95],
#              'last': [170, 149],
#              'justify': [1, 5],
#              'position': [113, 91],
#              'incomplete': [2, 4],
#              'functionality': [1, 22],
#              'sections': [12, 3],
#              'finalised': [0, 3],
#              'deal': [87, 107],
#              'proposed': [16, 32],
#              'play': [49, 6],
#              'spreadsheets': [0, 14],
#              '11': [118, 219],
#              'davies': [1, 15],
#              'completed': [50, 77],
#              'astray': [0, 2],
#              'certain': [95, 43],
#              'beck': [0, 259],
#              'soon': [124, 99],
#              'drop': [18, 10],
#              'london': [25, 155],
#              '30': [232, 176],
#              'recommend': [12, 14],
#              'th': [129, 135],
#              'brown': [8, 45],
#              'gold': [38, 14],
#              'leave': [42, 35],
#              'sloman': [0, 9],
#              'then': [194, 109],
#              'overall': [12, 34],
#              'project': [55, 93],
#              'matter': [75, 20],
#              'millerchip': [0, 3],
#              'many': [292, 82],
#              'completion': [8, 26],
#              'rebecca': [3, 21],
#              'dpr': [0, 68],
#              'surely': [5, 3],
#              'ticking': [0, 2],
#              'system': [228, 129],
#              'expect': [68, 30],
#              'richard': [15, 114],
#              'thing': [142, 32],
#              'steps': [43, 37],
#              'band': [5, 2],
#              'ebs': [0, 37],
#              'apx': [0, 1],
#              'mark': [23, 130],
#              'pay': [120, 21],
#              'response': [83, 37],
#              'cc': [3, 418],
#              'r': [319, 75],
#              'pickering': [1, 11],
#              'revalued': [0, 1],
#              'everyday': [18, 6],
#              'appears': [16, 19],
#              'nevertheless': [1, 6],
#              'lack': [24, 11],
#              'loss': [44, 22],
#              'people': [298, 147],
#              'purpose': [33, 18],
#              'points': [11, 33],
#              'them': [185, 165],
#              'andrew': [8, 64],
#              'way': [514, 83],
#              '3': [625, 251],
#              'set': [106, 115],
#              'w': [76, 80],
#              'tim': [7, 50],
#              'individuals': [36, 45],
#              'james': [10, 112],
#              'ask': [90, 43],
#              'more': [691, 198],
#              'stem': [0, 2],
#              'tool': [23, 10],
#              'comments': [7, 125],
#              'bright': [5, 2],
#              'milder': [1, 1],
#              'processes': [18, 66],
#              'projects': [85, 36],
#              'allowed': [23, 4],
#              'excel': [2, 19],
#              'items': [101, 55],
#              'apologies': [17, 11],
#              'apply': [45, 6],
#              'cornfield': [0, 47],
#              'recall': [0, 12],
#              'year': [158, 135],
#              'too': [166, 44],
#              'memory': [13, 8],
#              'become': [144, 33],
#              'dp': [1, 9],
#              'rather': [18, 41],
#              'off': [105, 110],
#              'identifying': [9, 9],
#              'those': [164, 77],
#              'comment': [1, 22],
#              'during': [79, 110],
#              'former': [27, 8],
#              'seems': [13, 28],
#              'irritating': [0, 2],
#              'stand': [151, 7],
#              'worrying': [2, 3],
#              'an': [691, 347],
#              'changing': [13, 20],
#              'any': [648, 470],
#              'sponsors': [7, 5],
#              'analyse': [0, 2],
#              'uk': [128, 29],
#              'hypothesis': [1, 3],
#              'how': [390, 152],
#              'exchange': [89, 23],
#              'tani': [0, 9],
#              'ted': [2, 99],
#              'sherriff': [0, 30],
#              'alluded': [0, 2],
#              'inappropriate': [0, 2],
#              'operation': [30, 12],
#              '5': [714, 167],
#              'spent': [112, 11],
#              'made': [335, 123],
#              'errors': [45, 22],
#              'jordan': [5, 110],
#              'applied': [8, 13],
#              'fernley': [0, 83],
#              'january': [19, 39],
#              'holes': [3, 1],
#              'brent': [0, 130],
#              'witnessed': [1, 1],
#              '10': [461, 212],
#              'why': [103, 40],
#              'matrix': [11, 11],
#              '1998': [15, 4],
#              'first': [212, 127],
#              'usually': [13, 8],
#              'consists': [13, 5],
#              'much': [198, 77],
#              'counterpart': [0, 2],
#              'murphy': [0, 71],
#              'than': [323, 103],
#              'options': [31, 31],
#              'missed': [4, 9],
#              'concentrated': [0, 2],
#              'incompleteness': [0, 1],
#              'who': [326, 194],
#              'out': [584, 239],
#              'hou': [4, 331],
#              'questions': [72, 283],
#              'basis': [44, 77],
#              'reviews': [23, 28],
#              'built': [27, 12],
#              'value': [99, 60],
#              'part': [181, 77],
#              'power': [80, 104],
#              'accommodate': [4, 7],
#              'price': [274, 131],
#              'process': [102, 241],
#              'knock': [3, 3],
#              'control': [90, 66],
#              'injury': [3, 1],
#              'should': [246, 262],
#              'doorpost': [0, 1],
#              'mike': [5, 186],
#              'especially': [32, 20],
#              'post': [47, 25],
#              'intended': [48, 18],
#              'aid': [8, 3],
#              'identified': [64, 35],
#              'suspect': [8, 7],
#              'limits': [4, 28],
#              'version': [198, 46],
#              'effects': [85, 5],
#              '1': [694, 269],
#              'commenced': [2, 5],
#              'deliveries': [1, 4],
#              'assignments': [0, 22],
#              'structured': [3, 13],
#              'happened': [16, 13],
#              'sweeney': [0, 27],
#              'operate': [35, 9],
#              'notification': [101, 14],
#              'timelines': [0, 9],
#              'm': [383, 173],
#              'partly': [2, 5],
#              'gail': [0, 13],
#              '31': [52, 73],
#              'corp': [29, 241],
#              'most': [235, 99],
#              'higher': [63, 12],
#              'amazed': [6, 2],
#              'relatively': [10, 12],
#              'ect': [3, 385],
#              'did': [93, 94],
#              'about': [544, 206],
#              'gas': [36, 125],
#              'doorstep': [1, 71],
#              'widespread': [2, 1],
#              'prioritisation': [0, 8],
#              'example': [40, 28],
#              'socrates': [0, 2],
#              'dyson': [0, 72],
#              'anyway': [1, 6],
#              'stabilise': [0, 1],
#              'eric': [0, 29],
#              'continental': [9, 17],
#              'responsible': [12, 75],
#              'nuances': [0, 2],
#              'been': [444, 295],
#              'possibly': [8, 8],
#              'market': [185, 96],
#              'contains': [99, 18],
#              'final': [59, 75],
#              'kevin': [3, 59],
#              'think': [71, 152],
#              'causes': [12, 6],
#              'nath': [0, 11],
#              'moment': [36, 11],
#              'important': [97, 60],
#              'communicate': [9, 27],
#              'fundamental': [0, 12],
#              'although': [34, 39],
#              '2000': [38, 374],
#              'month': [147, 82],
#              'go': [285, 126],
#              'insult': [1, 1],
#              'ongoing': [19, 15],
#              'react': [0, 3],
#              'state': [111, 19],
#              'viewed': [1, 7],
#              'history': [61, 9],
#              'revisions': [0, 9],
#              'patterson': [0, 28],
#              'us': [532, 269],
#              '7': [300, 96],
#              'concern': [21, 22],
#              'document': [19, 61],
#              'commodity': [5, 93],
#              'performing': [15, 9],
#              'michael': [23, 117],
#              'trades': [3, 54],
#              'result': [144, 48],
#              'point': [58, 79],
#              'microsoft': [37, 7],
#              'forwarded': [6, 311],
#              'heads': [2, 31],
#              'recent': [49, 48],
#              'valdez': [0, 4],
#              'causey': [1, 66],
#              'buy': [234, 57],
#              'following': [271, 217],
#              'kaminski': [0, 6],
#              'whalley': [0, 17],
#              'america': [68, 103],
#              'thoughts': [9, 47],
#              'website': [446, 20],
#              'kenneth': [4, 13],
#              'posted': [5, 38],
#              'cliff': [1, 5],
#              'joseph': [7, 31],
#              'lavorato': [0, 35],
#              'employees': [21, 71],
#              'vince': [1, 9],
#              '02': [31, 105],
#              'bradford': [0, 14],
#              'veronica': [1, 11],
#              'opinion': [44, 11],
#              'e': [612, 232],
#              'taylor': [4, 27],
#              'baxter': [1, 30],
#              'moscoso': [0, 41],
#              'north': [51, 101],
#              'liz': [1, 4],
#              'perez': [4, 22],
#              '9': [156, 114],
#              'message': [488, 134],
#              '34': [34, 35],
#              'jim': [5, 41],
#              'access': [145, 108],
#              'jeffrey': [2, 50],
#              'executive': [14, 46],
#              'changed': [29, 35],
#              'executives': [19, 4],
#              'eugenio': [0, 42],
#              'your': [1984, 475],
#              'j': [123, 64],
#              'abel': [0, 23],
#              'reports': [35, 89],
#              'lay': [8, 12],
#              'well': [160, 185],
#              '00': [212, 229],
#              'skilling': [0, 24],
#              'delete': [38, 7],
#              'chris': [4, 55],
#              'wanda': [0, 24],
#              'below': [273, 159],
#              'hannon': [0, 2],
#              'pm': [40, 342],
#              'greg': [3, 65],
#              'haedicke': [0, 12],
#              'communications': [23, 40],
#              'william': [4, 22],
#              'curry': [2, 22],
#              '50': [271, 41],
#              's': [885, 507],
#              'regarding': [58, 146],
#              'sutton': [0, 25],
#              'rick': [2, 88],
#              'fallon': [1, 2],
#              'select': [32, 31],
#              'requests': [18, 28],
#              'goals': [64, 21],
#              'online': [428, 20],
#              '783': [0, 12],
#              'management': [165, 195],
#              'date': [174, 208],
#              'canada': [58, 40],
#              'villarreal': [0, 14],
#              'call': [109, 236],
#              'mid': [22, 74],
#              'quick': [68, 39],
#              'longer': [77, 27],
#              'guide': [32, 10],
#              'listed': [115, 82],
#              'group': [118, 207],
#              '19': [162, 98],
#              'campos': [1, 1],
#              'success': [230, 51],
#              'described': [11, 15],
#              '18': [77, 97],
#              'receive': [294, 49],
#              'each': [125, 199],
#              '54': [14, 28],
#              'note': [106, 119],
#              'constance': [0, 3],
#              'input': [10, 47],
#              'selected': [57, 26],
#              'completing': [10, 20],
#              'performance': [114, 68],
#              'providing': [54, 43],
#              'immediately': [118, 41],
#              '4777': [0, 12],
#              'melodick': [0, 6],
#              '853': [1, 66],
#              'europe': [39, 74],
#              'ees': [0, 64],
#              '15': [156, 137],
#              'submit': [116, 22],
#              '974': [0, 4],
#              '6724': [0, 4],
#              'norma': [0, 13],
#              'button': [40, 14],
#              'skinner': [0, 10],
#              'sbeck': [0, 2],
#              'employee': [11, 39],
#              'meaningful': [1, 19],
#              'u': [224, 24],
#              'once': [150, 69],
#              'name': [236, 114],
#              'role': [9, 53],
#              'reviewer': [1, 12],
#              'very': [316, 120],
#              'status': [56, 81],
#              'accessing': [1, 6],
#              'participate': [33, 37],
#              'reference': [68, 28],
#              'open': [59, 51],
#              'participation': [15, 47],
#              'noted': [14, 23],
#              '207': [6, 10],
#              'specific': [70, 66],
#              'mail': [540, 124],
#              'forms': [23, 17],
#              'feedback': [12, 83],
#              'com': [920, 168],
#              'critical': [14, 46],
#              'option': [16, 42],
#              '03': [52, 121],
#              'numbers': [79, 53],
#              'l': [262, 93],
#              'anthony': [10, 8],
#              'plays': [10, 10],
#              'appear': [10, 18],
#              'only': [546, 151],
#              '44': [36, 38],
#              'jun': [17, 8],
#              'kimberly': [1, 8],
#              '4040': [0, 10],
#              'company': [461, 88],
#              'perfmgmt': [0, 11],
#              'cumulative': [2, 13],
#              'operating': [57, 37],
#              'cindy': [1, 49],
#              '713': [1, 102],
#              'begin': [44, 43],
#              'pep': [0, 30],
#              'supervisor': [2, 36],
#              '403': [3, 4],
#              '07': [42, 104],
#              'difficult': [19, 25],
#              'contingency': [1, 3],
#              'news': [195, 18],
#              'unify': [0, 29],
#              'financials': [1, 6],
#              'above': [161, 63],
#              'believe': [141, 86],
#              'test': [25, 21],
#              'testing': [17, 36],
#              'scheduled': [8, 70],
#              'automated': [21, 9],
#              'hopefully': [1, 22],
#              'close': [53, 54],
#              'meeting': [19, 246],
#              'mtg': [1, 5],
#              'sift': [0, 3],
#              'development': [89, 111],
#              'net': [301, 53],
#              'interface': [6, 21],
#              'fit': [70, 24],
#              'include': [145, 72],
#              'requirement': [4, 14],
#              'check': [205, 37],
#              'june': [91, 58],
#              'coordination': [2, 14],
#              'resolutions': [0, 1],
#              'sap': [2, 59],
#              'their': [376, 197],
#              '35850': [0, 1],
#              'summer': [22, 25],
#              'request': [99, 107],
#              'x': [218, 113],
#              'jones': [25, 26],
#              'per': [208, 92],
#              'shelly': [0, 22],
#              'information': [597, 250],
#              'resources': [61, 109],
#              '00834': [0, 1],
#              'sheila': [0, 76],
#              'hector': [0, 40],
#              'walton': [0, 12],
#              '52': [27, 31],
#              'bien': [1, 1],
#              'k': [78, 39],
#              'parra': [0, 13],
#              'pharr': [0, 1],
#              'janice': [1, 1],
#              'rc': [12, 10],
#              '39995': [0, 3],
#              'monday': [22, 124],
#              'hire': [0, 11],
#              'sarah': [3, 14],
#              'specialist': [11, 12],
#              'michelle': [2, 25],
#              'wilson': [5, 80],
#              'allison': [1, 1],
#              '02631': [0, 1],
#              'n': [118, 19],
#              'weekly': [30, 49],
#              'chance': [69, 27],
#              'smith': [12, 45],
#              'teresa': [1, 8],
#              'mary': [21, 110],
#              '00813': [0, 1],
#              'dempsey': [0, 1],
#              'felicia': [0, 1],
#              'linda': [4, 14],
#              'gibson': [0, 3],
#              'carmen': [1, 2],
#              '000': [345, 39],
#              'title': [22, 10],
#              'robbin': [0, 1],
#              'susan': [5, 33],
#              'jennings': [1, 1],
#              'skarness': [0, 1],
#              '22': [76, 80],
#              'doh': [0, 4],
#              'vargo': [0, 1],
#              'report': [157, 183],
#              '00720': [0, 1],
#              'orientation': [0, 11],
#              'davis': [3, 22],
#              'rep': [5, 15],
#              'george': [12, 22],
#              'lerea': [0, 1],
#              'yes': [65, 11],
#              'solis': [0, 3],
#              'pamela': [1, 9],
#              'nedre': [0, 1],
#              'henenberg': [0, 10],
#              'toni': [1, 5],
#              'joll': [0, 1],
#              'graham': [2, 8],
#              'hr': [3, 42],
#              'angela': [2, 8],
#              'hargrave': [0, 1],
#              'solmonson': [0, 61],
#              'jennifer': [6, 36],
#              'chavira': [0, 1],
#              'riedel': [0, 1],
#              'd': [240, 135],
#              'co': [101, 40],
#              'shona': [0, 131],
#              'gretchen': [0, 2],
#              '02372': [0, 1],
#              'ann': [6, 7],
#              'bryce': [2, 23],
#              'continue': [100, 94],
#              'mcloughlin': [0, 36],
#              'h': [65, 33],
#              'dan': [10, 15],
#              'sprock': [0, 3],
#              'human': [33, 34],
#              'sr': [2, 12],
#              'strambler': [0, 1],
#              'stewart': [8, 5],
#              'tumey': [0, 1],
#              'lee': [5, 19],
#              'robin': [0, 3],
#              'kyle': [0, 4],
#              'dalton': [0, 3],
#              '413': [0, 3],
#              'badge': [2, 4],
#              'burns': [4, 1],
#              'lisa': [6, 33],
#              'bob': [4, 115],
#              'charlene': [0, 20],
#              'hayslett': [0, 3],
#              'oxley': [0, 17],
#              'wade': [0, 11],
#              '83': [17, 3],
#              'apollo': [0, 47],
#              'ena': [0, 97],
#              'dashboard': [0, 1],
#              'cynthia': [0, 16],
#              '04': [21, 107],
#              'padron': [0, 3],
#              'denise': [1, 4],
#              'bonnard': [0, 3],
#              'coombe': [0, 1],
#              'participated': [2, 8],
#              'attended': [5, 7],
#              'sengupta': [1, 3],
#              'lawrence': [2, 3],
#              'mahendra': [0, 1],
#              'jackson': [5, 40],
#              'attachment': [7, 22],
#              '39': [104, 29],
#              'attend': [11, 70],
#              'stubbs': [0, 5],
#              'poston': [0, 1],
#              'lessner': [0, 1],
#              'peikert': [0, 1],
#              'kathy': [1, 9],
#              'turn': [49, 13],
#              'grimes': [0, 1],
#              'sparger': [0, 2],
#              '16': [75, 106],
#              'perkins': [0, 15],
#              'petruszka': [0, 4],
#              'mclean': [0, 3],
#              'cassandra': [0, 29],
#              'ots': [0, 3],
#              'rice': [3, 6],
#              'yowman': [0, 5],
#              'wysatta': [0, 1],
#              'training': [34, 32],
#              'selzer': [0, 3],
#              'gilchrist': [0, 3],
#              'hughes': [2, 9],
#              '32': [24, 29],
#              'projected': [9, 9],
#              'ellen': [0, 6],
#              '76': [7, 3],
#              'brad': [2, 17],
#              'b': [161, 64],
#              'castleman': [0, 3],
#              'schnauber': [0, 1],
#              'rod': [2, 7],
#              '8': [403, 125],
#              'harman': [0, 2],
#              'ervin': [0, 1],
#              'williams': [13, 15],
#              'marlow': [0, 3],
#              'goh': [0, 1],
#              '64': [26, 4],
#              'attendance': [4, 17],
#              'daler': [0, 1],
#              'brian': [6, 58],
#              'everyone': [53, 72],
#              'eckels': [0, 1],
#              'margaret': [2, 2],
#              'melissa': [0, 32],
#              'sherry': [0, 4],
#              'fance': [0, 1],
#              '53': [11, 20],
#              'kent': [0, 4],
#              'bobby': [0, 1],
#              'scott': [14, 95],
#              'stubblefield': [0, 10],
#              'gerry': [0, 5],
#              'howes': [0, 3],
#              'debbie': [1, 26],
#              'sommers': [0, 3],
#              'nikkel': [0, 1],
#              'andrea': [1, 31],
#              'statistics': [7, 6],
#              'sullivan': [0, 8],
#              'keith': [4, 13],
#              'drew': [29, 7],
#              'lorna': [0, 1],
#              '40': [69, 42],
#              'biren': [0, 1],
#              'howard': [6, 19],
#              'morton': [0, 1],
#              'fgt': [0, 5],
#              'carol': [1, 18],
#              'janie': [1, 4],
#              'bennett': [0, 5],
#              'colwell': [0, 26],
#              'diane': [5, 11],
#              'cagney': [0, 2],
#              'coleman': [0, 7],
#              'et': [28, 8],
#              'kathryn': [0, 12],
#              'merlyn': [0, 1],
#              'ron': [1, 9],
#              'amabile': [0, 1],
#              'greek': [0, 2],
#              'schultz': [3, 24],
#              'fink': [0, 1],
#              'units': [4, 35],
#              'classes': [2, 10],
#              'knudsen': [0, 5],
#              '100': [245, 22],
#              'patrick': [3, 23],
#              '94': [8, 2],
#              'jandrell': [0, 1],
#              'traylor': [0, 1],
#              'gco': [0, 2],
#              'encouraging': [5, 3],
#              'jill': [0, 7],
#              'gpgfin': [0, 13],
#              'miguel': [2, 6],
#              'kokas': [0, 4],
#              '91': [15, 3],
#              'willie': [0, 5],
#              'chor': [0, 1],
#              'details': [153, 87],
#              'donnis': [0, 1],
#              'joyce': [5, 15],
#              'butts': [0, 3],
#              'c': [121, 99],
#              'lynch': [3, 3],
#              'grest': [0, 1],
#              'olson': [4, 13],
#              'todd': [2, 45],
#              'wes': [0, 33],
#              'barrow': [0, 2],
#              'ray': [4, 9],
#              'kumar': [0, 1],
#              'morrow': [0, 4],
#              'yates': [0, 2],
#              'ranendra': [0, 2],
#              'erwin': [0, 8],
#              'dave': [2, 49],
#              'franz': [5, 2],
#              '68': [12, 2],
#              'sa': [33, 15],
#              'schafer': [1, 3],
#              'beth': [0, 89],
#              'jeannie': [0, 1],
#              'chatham': [0, 3],
#              'ellis': [0, 2],
#              '78': [7, 3],
#              'robert': [15, 63],
#              'gpg': [0, 6],
#              '21': [130, 76],
#              'dell': [1, 4],
#              'o': [205, 21],
#              'lim': [4, 9],
#              'becker': [0, 4],
#              'woods': [2, 3],
#              'angelique': [0, 1],
#              'addendum': [0, 1],
#              'really': [158, 61],
#              ...})

# %% [markdown]
# Сохраним в переменные общее число сообщений класса spam и ham :

# %%
all_spam = df['Class'].loc[df['Class'] == 'spam'].count()
all_ham = df['Class'].loc[df['Class'] == 'ham'].count()

all_spam, all_ham
# Out:
# (np.int64(2939), np.int64(1200))

# %% [markdown]
# Сохраним в переменные Априорные вероятности \\(P(спам)\\) \\(P(не \space спам)\\) :

# %%
p_spam = all_spam / (all_spam + all_ham)
p_ham = all_ham / (all_spam + all_ham)

p_spam, p_ham
# Out:
# (np.float64(0.7100748973181928), np.float64(0.2899251026818072))

# %% [markdown]
# Для каждого слова найдем вероятность встретить его в каждом из классов сообщений spam, hum :
# ***(Найдем \\(P(слово|не\spaceспам)\\) и \\(P(слово|спам)\\))*** Используя сглаживание Лапласса.

# %%
words_prob = {}
for word, counts in freq.items():
    spam_count, ham_count = counts
    prob_word_in_spam = (spam_count + 1) / (all_spam + 2)
    prob__word_in_ham = (ham_count + 1) / (all_ham + 2)
    words_prob[word] = (prob_word_in_spam, prob__word_in_ham)

# %%
words_prob
# Out:
# {'for': (np.float64(0.6327779666780007), np.float64(0.762063227953411)),
#  'currently': (np.float64(0.033321999319959196),
#   np.float64(0.08901830282861897)),
#  'commercial': (np.float64(0.01292077524651479),
#   np.float64(0.08485856905158069)),
#  '2': (np.float64(0.17341040462427745), np.float64(0.21963394342762063)),
#  'business': (np.float64(0.23325399523971438),
#   np.float64(0.21547420965058237)),
#  'work': (np.float64(0.08874532471948317), np.float64(0.16805324459234608)),
#  'a': (np.float64(0.7150629037742264), np.float64(0.721297836938436)),
#  'eott': (np.float64(0.00034002040122407346),
#   np.float64(0.004991680532445923)),
#  'me': (np.float64(0.09690581434886093), np.float64(0.4400998336106489)),
#  'analysis': (np.float64(0.008500510030601836),
#   np.float64(0.04991680532445923)),
#  'related': (np.float64(0.019041142468548114),
#   np.float64(0.05324459234608985)),
#  'to': (np.float64(0.8075484529071745), np.float64(0.8569051580698835)),
#  'am': (np.float64(0.08398503910234614), np.float64(0.3519134775374376)),
#  'analysts': (np.float64(0.003740224413464808),
#   np.float64(0.030782029950083195)),
#  'subject': (np.float64(0.999659979598776), np.float64(0.9991680532445923)),
#  'months': (np.float64(0.04012240734444067), np.float64(0.06572379367720466)),
#  'i': (np.float64(0.2859571574294458), np.float64(0.6014975041597338)),
#  '6': (np.float64(0.09894593675620537), np.float64(0.09068219633943428)),
#  'roles': (np.float64(0.0010200612036722204),
#   np.float64(0.024958402662229616)),
#  'in': (np.float64(0.5892553553213192), np.float64(0.6414309484193012)),
#  'need': (np.float64(0.1383883032981979), np.float64(0.2737104825291181)),
#  'of': (np.float64(0.6909214552873172), np.float64(0.6921797004991681)),
#  'period': (np.float64(0.013600816048962938),
#   np.float64(0.025790349417637273)),
#  'means': (np.float64(0.04930295817749065), np.float64(0.01747088186356073)),
#  'entirety': (np.float64(0.0013600816048962938),
#   np.float64(0.0033277870216306157)),
#  'would': (np.float64(0.12614756885413125), np.float64(0.305324459234609)),
#  'what': (np.float64(0.15606936416184972), np.float64(0.1896838602329451)),
#  'taking': (np.float64(0.021081264875892555), np.float64(0.03743760399334443)),
#  'stay': (np.float64(0.01088065283917035), np.float64(0.024126455906821963)),
#  'end': (np.float64(0.059503570214212854), np.float64(0.10149750415973377)),
#  'want': (np.float64(0.1547092825569534), np.float64(0.12063227953410982)),
#  'seemed': (np.float64(0.0051003060183611015),
#   np.float64(0.011647254575707155)),
#  'met': (np.float64(0.0047602856171370285), np.float64(0.04076539101497504)),
#  'arrangements': (np.float64(0.0010200612036722204),
#   np.float64(0.018302828618968387)),
#  'energy': (np.float64(0.014280856851411085), np.float64(0.08236272878535773)),
#  'is': (np.float64(0.6171370282216933), np.float64(0.6206322795341098)),
#  'see': (np.float64(0.17579054743284597), np.float64(0.14143094841930118)),
#  'ltd': (np.float64(0.011900714042842571), np.float64(0.008319467554076539)),
#  'chief': (np.float64(0.008500510030601836), np.float64(0.014975041597337771)),
#  'sue': (np.float64(0.002040122407344441), np.float64(0.0074875207986688855)),
#  'ensure': (np.float64(0.022441346480788847), np.float64(0.07986688851913477)),
#  'was': (np.float64(0.15504930295817748), np.float64(0.22462562396006655)),
#  're': (np.float64(0.061543692621557296), np.float64(0.23793677204658903)),
#  'confirmation': (np.float64(0.008160489629377763),
#   np.float64(0.02745424292845258)),
#  'coming': (np.float64(0.017341040462427744),
#   np.float64(0.028286189683860232)),
#  'still': (np.float64(0.02788167290037402), np.float64(0.10565723793677205)),
#  'signed': (np.float64(0.009180550833049982),
#   np.float64(0.024126455906821963)),
#  'piece': (np.float64(0.0027201632097925877),
#   np.float64(0.008319467554076539)),
#  'unavailable': (np.float64(0.0034002040122407345),
#   np.float64(0.0074875207986688855)),
#  'do': (np.float64(0.3019381162869772), np.float64(0.22462562396006655)),
#  'audit': (np.float64(0.0017001020061203672),
#   np.float64(0.029950083194675542)),
#  'discussed': (np.float64(0.0034002040122407345),
#   np.float64(0.09816971713810316)),
#  'held': (np.float64(0.016660999659979598), np.float64(0.036605657237936774)),
#  'accessible': (np.float64(0.0034002040122407345),
#   np.float64(0.004991680532445923)),
#  'are': (np.float64(0.4243454607276437), np.float64(0.5457570715474209)),
#  'quilkey': (np.float64(0.00034002040122407346),
#   np.float64(0.004159733777038269)),
#  'thank': (np.float64(0.07514450867052024), np.float64(0.13643926788685523)),
#  'occur': (np.float64(0.020061203672220335), np.float64(0.014975041597337771)),
#  'fact': (np.float64(0.03740224413464808), np.float64(0.03826955074875208)),
#  'until': (np.float64(0.032981978918735125), np.float64(0.09234608985024959)),
#  'both': (np.float64(0.04114246854811289), np.float64(0.10066555740432612)),
#  'have': (np.float64(0.4522271336280177), np.float64(0.6239600665557404)),
#  'they': (np.float64(0.08874532471948317), np.float64(0.18718801996672213)),
#  'procedure': (np.float64(0.002040122407344441),
#   np.float64(0.008319467554076539)),
#  'speak': (np.float64(0.006460387623257395), np.float64(0.020798668885191347)),
#  'australia': (np.float64(0.008500510030601836),
#   np.float64(0.014975041597337771)),
#  'houston': (np.float64(0.0034002040122407345),
#   np.float64(0.15058236272878536)),
#  'areas': (np.float64(0.012240734444066644), np.float64(0.039101497504159734)),
#  'it': (np.float64(0.41448486909214555), np.float64(0.4051580698835274)),
#  'independent': (np.float64(0.026181570894253655),
#   np.float64(0.01913477537437604)),
#  'being': (np.float64(0.06188371302278137), np.float64(0.10898502495840266)),
#  'needs': (np.float64(0.029921795307718463), np.float64(0.08569051580698835)),
#  'good': (np.float64(0.12988779326759606), np.float64(0.09068219633943428)),
#  'confirmations': (np.float64(0.0006800408024481469),
#   np.float64(0.022462562396006656)),
#  'return': (np.float64(0.04454267256035362), np.float64(0.039101497504159734)),
#  'had': (np.float64(0.060183611016661), np.float64(0.14226289517470883)),
#  'senior': (np.float64(0.011560693641618497), np.float64(0.03410981697171381)),
#  'our': (np.float64(0.4107446446786807), np.float64(0.31863560732113144)),
#  'on': (np.float64(0.35260115606936415), np.float64(0.6663893510815307)),
#  'legal': (np.float64(0.03774226453587215), np.float64(0.048252911813643926)),
#  'required': (np.float64(0.030941856511390683),
#   np.float64(0.05574043261231281)),
#  'individual': (np.float64(0.014280856851411085),
#   np.float64(0.048252911813643926)),
#  'finance': (np.float64(0.015980958857531452),
#   np.float64(0.029950083194675542)),
#  'taken': (np.float64(0.013600816048962938), np.float64(0.03743760399334443)),
#  'lunch': (np.float64(0.0010200612036722204),
#   np.float64(0.028286189683860232)),
#  'signing': (np.float64(0.0023801428085685142),
#   np.float64(0.005823627287853577)),
#  'directory': (np.float64(0.009180550833049982),
#   np.float64(0.005823627287853577)),
#  'relevant': (np.float64(0.006460387623257395),
#   np.float64(0.011647254575707155)),
#  'therefore': (np.float64(0.022101326079564772),
#   np.float64(0.05823627287853577)),
#  'desk': (np.float64(0.006460387623257395), np.float64(0.0524126455906822)),
#  'make': (np.float64(0.19619177150629039), np.float64(0.1281198003327787)),
#  'working': (np.float64(0.04216252975178511), np.float64(0.12312811980033278)),
#  'with': (np.float64(0.4393063583815029), np.float64(0.5183028286189684)),
#  'over': (np.float64(0.19653179190751446), np.float64(0.1405990016638935)),
#  'distribute': (np.float64(0.013260795647738865),
#   np.float64(0.013311148086522463)),
#  'settlement': (np.float64(0.0017001020061203672),
#   np.float64(0.019966722129783693)),
#  'my': (np.float64(0.10608636518191092), np.float64(0.2146422628951747)),
#  'managing': (np.float64(0.011900714042842571),
#   np.float64(0.04326123128119801)),
#  'you': (np.float64(0.6973818429105746), np.float64(0.7063227953410982)),
#  'mason': (np.float64(0.0006800408024481469), np.float64(0.01913477537437604)),
#  'all': (np.float64(0.31043862631757907), np.float64(0.35856905158069885)),
#  'log': (np.float64(0.01394083645018701), np.float64(0.009983361064891847)),
#  'the': (np.float64(0.7585855151309079), np.float64(0.8752079866888519)),
#  'minns': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'counsel': (np.float64(0.0013600816048962938),
#   np.float64(0.014143094841930116)),
#  'that': (np.float64(0.3804828289697382), np.float64(0.5174708818635607)),
#  'advise': (np.float64(0.0034002040122407345),
#   np.float64(0.021630615640599003)),
#  'authorised': (np.float64(0.00034002040122407346),
#   np.float64(0.010815307820299502)),
#  'responsibility': (np.float64(0.007480448826929616),
#   np.float64(0.042429284525790346)),
#  'look': (np.float64(0.09486569194151649), np.float64(0.06905158069883527)),
#  'director': (np.float64(0.03740224413464808),
#   np.float64(0.04742096505823627)),
#  'and': (np.float64(0.6871812308738524), np.float64(0.7945091514143094)),
#  'event': (np.float64(0.007480448826929616), np.float64(0.03494176372712146)),
#  'office': (np.float64(0.030261815708942538), np.float64(0.17803660565723795)),
#  'quite': (np.float64(0.011220673240394424), np.float64(0.026622296173044926)),
#  'upon': (np.float64(0.03876232573954437), np.float64(0.064891846921797)),
#  'someone': (np.float64(0.014620877252635158),
#   np.float64(0.04658901830282862)),
#  'clearly': (np.float64(0.004080244814688882),
#   np.float64(0.016638935108153077)),
#  'could': (np.float64(0.08738524311458687), np.float64(0.12312811980033278)),
#  'stage': (np.float64(0.00884053043182591), np.float64(0.009151414309484194)),
#  'primary': (np.float64(0.008160489629377763),
#   np.float64(0.024958402662229616)),
#  'by': (np.float64(0.29105746344780686), np.float64(0.4550748752079867)),
#  'maintained': (np.float64(0.0010200612036722204),
#   np.float64(0.0074875207986688855)),
#  'planning': (np.float64(0.009520571234274057),
#   np.float64(0.048252911813643926)),
#  'paul': (np.float64(0.005780346820809248), np.float64(0.04159733777038269)),
#  'plan': (np.float64(0.01972118327099626), np.float64(0.09234608985024959)),
#  'new': (np.float64(0.18463107786467187), np.float64(0.22046589018302828)),
#  'heidi': (np.float64(0.00034002040122407346),
#   np.float64(0.025790349417637273)),
#  'when': (np.float64(0.1101666099965998), np.float64(0.15307820299500832)),
#  'key': (np.float64(0.030261815708942538), np.float64(0.059900166389351084)),
#  'thanks': (np.float64(0.04284257055423325), np.float64(0.34775374376039936)),
#  'volume': (np.float64(0.01088065283917035), np.float64(0.03577371048252912)),
#  'meantime': (np.float64(0.0006800408024481469),
#   np.float64(0.009983361064891847)),
#  'pty': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'change': (np.float64(0.05644338660319619), np.float64(0.06821963394342762)),
#  'week': (np.float64(0.060863651819109146), np.float64(0.19550748752079866)),
#  'raised': (np.float64(0.0034002040122407345),
#   np.float64(0.016638935108153077)),
#  'agreed': (np.float64(0.013260795647738865), np.float64(0.03826955074875208)),
#  'which': (np.float64(0.1431485889153349), np.float64(0.2146422628951747)),
#  'now': (np.float64(0.2560353621217273), np.float64(0.13061564059900166)),
#  'quickly': (np.float64(0.022441346480788847),
#   np.float64(0.022462562396006656)),
#  'her': (np.float64(0.06596395783747025), np.float64(0.06905158069883527)),
#  'signatories': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'timing': (np.float64(0.008160489629377763),
#   np.float64(0.024126455906821963)),
#  'dealer': (np.float64(0.010200612036722203),
#   np.float64(0.0024958402662229617)),
#  'procedures': (np.float64(0.003060183611016661),
#   np.float64(0.030782029950083195)),
#  'not': (np.float64(0.4243454607276437), np.float64(0.3469217970049917)),
#  'enact': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'from': (np.float64(0.3743624617477049), np.float64(0.46422628951747086)),
#  'please': (np.float64(0.2148928935736144), np.float64(0.5740432612312812)),
#  'but': (np.float64(0.18735124107446446), np.float64(0.23544093178036607)),
#  'decided': (np.float64(0.02074124447466848),
#   np.float64(0.022462562396006656)),
#  'david': (np.float64(0.007480448826929616), np.float64(0.10981697171381032)),
#  'list': (np.float64(0.08942536552193131), np.float64(0.15058236272878536)),
#  'opportunity': (np.float64(0.045222713362801766),
#   np.float64(0.04908485856905158)),
#  'order': (np.float64(0.1407684461067664), np.float64(0.0723793677204659)),
#  'approval': (np.float64(0.015300918055083304),
#   np.float64(0.06655574043261231)),
#  'comprehensive': (np.float64(0.005440326419585175),
#   np.float64(0.009983361064891847)),
#  'prepared': (np.float64(0.0034002040122407345),
#   np.float64(0.024126455906821963)),
#  'briefly': (np.float64(0.00034002040122407346),
#   np.float64(0.009983361064891847)),
#  'we': (np.float64(0.462767766065964), np.float64(0.5316139767054908)),
#  'such': (np.float64(0.06732403944236655), np.float64(0.06405990016638935)),
#  'will': (np.float64(0.3124787487249235), np.float64(0.543261231281198)),
#  'here': (np.float64(0.3213192791567494), np.float64(0.1497504159733777)),
#  'there': (np.float64(0.09826589595375723), np.float64(0.21381031613976706)),
#  'together': (np.float64(0.019381162869772185),
#   np.float64(0.07071547420965059)),
#  'or': (np.float64(0.31417885073104385), np.float64(0.34775374376039936)),
#  'signatory': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'current': (np.float64(0.06222373342400544), np.float64(0.10232945091514144)),
#  'its': (np.float64(0.143488609316559), np.float64(0.042429284525790346)),
#  'going': (np.float64(0.044202652159129545), np.float64(0.1064891846921797)),
#  'sally': (np.float64(0.0017001020061203672), np.float64(0.3768718801996672)),
#  'officer': (np.float64(0.02074124447466848),
#   np.float64(0.018302828618968387)),
#  'allow': (np.float64(0.015300918055083304), np.float64(0.03577371048252912)),
#  'changes': (np.float64(0.045222713362801766),
#   np.float64(0.09983361064891846)),
#  'transfer': (np.float64(0.05134308058483509),
#   np.float64(0.028286189683860232)),
#  'due': (np.float64(0.05236314178850731), np.float64(0.09484193011647254)),
#  'be': (np.float64(0.41414484869092144), np.float64(0.5615640599001663)),
#  'frusco': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'detailed': (np.float64(0.007140428425705543),
#   np.float64(0.030782029950083195)),
#  'as': (np.float64(0.2278136688201292), np.float64(0.5199667221297837)),
#  'like': (np.float64(0.1907514450867052), np.float64(0.2113144758735441)),
#  'enron': (np.float64(0.00034002040122407346), np.float64(0.5099833610648918)),
#  'structure': (np.float64(0.01972118327099626),
#   np.float64(0.039101497504159734)),
#  'review': (np.float64(0.03570214212852771), np.float64(0.19384359400998336)),
#  'implemented': (np.float64(0.0013600816048962938),
#   np.float64(0.01747088186356073)),
#  'move': (np.float64(0.033321999319959196), np.float64(0.048252911813643926)),
#  'no': (np.float64(0.25025501530091804), np.float64(0.12562396006655574)),
#  'issue': (np.float64(0.01870112206732404), np.float64(0.07154742096505824)),
#  'take': (np.float64(0.10472628357701462), np.float64(0.10316139767054909)),
#  'happy': (np.float64(0.022781366882012922), np.float64(0.03993344425956739)),
#  'advised': (np.float64(0.011220673240394424),
#   np.float64(0.008319467554076539)),
#  'implement': (np.float64(0.0010200612036722204),
#   np.float64(0.014975041597337771)),
#  'clients': (np.float64(0.020401224073444406),
#   np.float64(0.012479201331114808)),
#  'at': (np.float64(0.3049982998979939), np.float64(0.40931780366056575)),
#  'invoicing': (np.float64(0.00034002040122407346),
#   np.float64(0.0066555740432612314)),
#  'sydney': (np.float64(0.0006800408024481469),
#   np.float64(0.0074875207986688855)),
#  'this': (np.float64(0.40360421625297516), np.float64(0.6339434276206323)),
#  'financial': (np.float64(0.04284257055423325),
#   np.float64(0.07071547420965059)),
#  'action': (np.float64(0.031281876912614755),
#   np.float64(0.045757071547420966)),
#  'time': (np.float64(0.2074124447466848), np.float64(0.26788685524126454)),
#  'faxed': (np.float64(0.0006800408024481469),
#   np.float64(0.009151414309484194)),
#  'provide': (np.float64(0.09010540632437947), np.float64(0.11647254575707154)),
#  'anything': (np.float64(0.023801428085685142),
#   np.float64(0.050748752079866885)),
#  'revised': (np.float64(0.0006800408024481469),
#   np.float64(0.04159733777038269)),
#  'entex': (np.float64(0.00034002040122407346),
#   np.float64(0.004991680532445923)),
#  'else': (np.float64(0.011560693641618497), np.float64(0.036605657237936774)),
#  'attached': (np.float64(0.016320979258755527),
#   np.float64(0.19883527454242927)),
#  'know': (np.float64(0.13736824209452567), np.float64(0.31863560732113144)),
#  'shankman': (np.float64(0.00034002040122407346),
#   np.float64(0.020798668885191347)),
#  'if': (np.float64(0.2550153009180551), np.float64(0.4800332778702163)),
#  'explain': (np.float64(0.003740224413464808),
#   np.float64(0.016638935108153077)),
#  'help': (np.float64(0.10030601836110166), np.float64(0.1464226289517471)),
#  'let': (np.float64(0.03706222373342401), np.float64(0.2720465890183028)),
#  'understand': (np.float64(0.022101326079564772),
#   np.float64(0.056572379367720464)),
#  'can': (np.float64(0.24787487249234955), np.float64(0.326955074875208)),
#  'files': (np.float64(0.010200612036722203), np.float64(0.019966722129783693)),
#  'jeff': (np.float64(0.0010200612036722204), np.float64(0.08735440931780367)),
#  'summary': (np.float64(0.0010200612036722204),
#   np.float64(0.07321131447587355)),
#  'repeat': (np.float64(0.004420265215912955),
#   np.float64(0.004991680532445923)),
#  'outlined': (np.float64(0.004080244814688882),
#   np.float64(0.014975041597337771)),
#  'answering': (np.float64(0.0006800408024481469),
#   np.float64(0.0024958402662229617)),
#  'port': (np.float64(0.0023801428085685142), np.float64(0.02745424292845258)),
#  'develop': (np.float64(0.016660999659979598),
#   np.float64(0.029950083194675542)),
#  'appropriately': (np.float64(0.0010200612036722204),
#   np.float64(0.004991680532445923)),
#  'worryingly': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'so': (np.float64(0.12580754845290718), np.float64(0.2271214642262895)),
#  'turmoil': (np.float64(0.0013600816048962938),
#   np.float64(0.0016638935108153079)),
#  'rapidly': (np.float64(0.0047602856171370285),
#   np.float64(0.004991680532445923)),
#  '17': (np.float64(0.030941856511390683), np.float64(0.08319467554076539)),
#  'immersed': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'virro': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'arrive': (np.float64(0.0023801428085685142),
#   np.float64(0.013311148086522463)),
#  'monitor': (np.float64(0.0051003060183611015),
#   np.float64(0.019966722129783693)),
#  'ian': (np.float64(0.0013600816048962938), np.float64(0.009151414309484194)),
#  'john': (np.float64(0.011220673240394424), np.float64(0.10399334442595674)),
#  'these': (np.float64(0.13226793607616458), np.float64(0.240432612312812)),
#  'pablo': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'listing': (np.float64(0.006800408024481469),
#   np.float64(0.013311148086522463)),
#  'just': (np.float64(0.24447466848010882), np.float64(0.16888519134775373)),
#  'institution': (np.float64(0.002040122407344441),
#   np.float64(0.0033277870216306157)),
#  'simply': (np.float64(0.057803468208092484),
#   np.float64(0.025790349417637273)),
#  'between': (np.float64(0.023121387283236993),
#   np.float64(0.06905158069883527)),
#  'pressure': (np.float64(0.004420265215912955),
#   np.float64(0.0066555740432612314)),
#  'get': (np.float64(0.21319279156749404), np.float64(0.20049916805324458)),
#  'forgotten': (np.float64(0.0010200612036722204),
#   np.float64(0.0024958402662229617)),
#  'right': (np.float64(0.10846650799047942), np.float64(0.04492512479201331)),
#  'anyone': (np.float64(0.022781366882012922), np.float64(0.04492512479201331)),
#  'pissanetzky': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'single': (np.float64(0.010540632437946278),
#   np.float64(0.010815307820299502)),
#  'explains': (np.float64(0.0010200612036722204),
#   np.float64(0.0033277870216306157)),
#  'form': (np.float64(0.07412444746684801), np.float64(0.04492512479201331)),
#  'some': (np.float64(0.08364501870112206), np.float64(0.18386023294509152)),
#  'were': (np.float64(0.06970418225093505), np.float64(0.13976705490848584)),
#  'late': (np.float64(0.019041142468548114), np.float64(0.04159733777038269)),
#  'lewis': (np.float64(0.0017001020061203672),
#   np.float64(0.021630615640599003)),
#  'seen': (np.float64(0.017341040462427744), np.float64(0.024958402662229616)),
#  'resulted': (np.float64(0.0027201632097925877),
#   np.float64(0.012479201331114808)),
#  'polish': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'yesterday': (np.float64(0.002040122407344441),
#   np.float64(0.051580698835274545)),
#  'effort': (np.float64(0.018361101666099965), np.float64(0.05490848585690516)),
#  'findings': (np.float64(0.0017001020061203672),
#   np.float64(0.016638935108153077)),
#  'add': (np.float64(0.022441346480788847), np.float64(0.04159733777038269)),
#  'likely': (np.float64(0.005780346820809248),
#   np.float64(0.018302828618968387)),
#  'doesn': (np.float64(0.012240734444066644), np.float64(0.01747088186356073)),
#  'risk': (np.float64(0.0435226113566814), np.float64(0.2021630615640599)),
#  'border': (np.float64(0.0013600816048962938),
#   np.float64(0.004159733777038269)),
#  't': (np.float64(0.20537232233934036), np.float64(0.15806988352745424)),
#  'because': (np.float64(0.08296497789867392), np.float64(0.09317803660565724)),
#  'largest': (np.float64(0.014960897653859231),
#   np.float64(0.010815307820299502)),
#  'addressed': (np.float64(0.0017001020061203672),
#   np.float64(0.01747088186356073)),
#  'capture': (np.float64(0.006800408024481469),
#   np.float64(0.029950083194675542)),
#  'young': (np.float64(0.009520571234274057), np.float64(0.014975041597337771)),
#  'solution': (np.float64(0.011900714042842571),
#   np.float64(0.028286189683860232)),
#  'treatment': (np.float64(0.006460387623257395),
#   np.float64(0.005823627287853577)),
#  'possible': (np.float64(0.04080244814688881),
#   np.float64(0.09317803660565724)),
#  'slipped': (np.float64(0.0013600816048962938),
#   np.float64(0.0016638935108153079)),
#  'arguing': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'given': (np.float64(0.03808228493709623), np.float64(0.07321131447587355)),
#  'steve': (np.float64(0.0047602856171370285), np.float64(0.08402662229617304)),
#  'big': (np.float64(0.033662019721183274), np.float64(0.022462562396006656)),
#  'use': (np.float64(0.12886773206392382), np.float64(0.08069883527454243)),
#  'amsterdam': (np.float64(0.003060183611016661),
#   np.float64(0.0024958402662229617)),
#  '08': (np.float64(0.011220673240394424), np.float64(0.10565723793677205)),
#  'models': (np.float64(0.002040122407344441),
#   np.float64(0.010815307820299502)),
#  'based': (np.float64(0.05542332539952397), np.float64(0.07487520798668885)),
#  'area': (np.float64(0.028221693301598096), np.float64(0.033277870216306155)),
#  'today': (np.float64(0.08534512070724243), np.float64(0.1264559068219634)),
#  'controls': (np.float64(0.0013600816048962938),
#   np.float64(0.04409317803660566)),
#  'corollary': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'exhaustive': (np.float64(0.00034002040122407346),
#   np.float64(0.005823627287853577)),
#  'enough': (np.float64(0.03944236654199252), np.float64(0.016638935108153077)),
#  'rac': (np.float64(0.017341040462427744), np.float64(0.04991680532445923)),
#  'manual': (np.float64(0.0047602856171370285),
#   np.float64(0.024958402662229616)),
#  '05': (np.float64(0.02074124447466848), np.float64(0.09317803660565724)),
#  'exercise': (np.float64(0.004420265215912955),
#   np.float64(0.010815307820299502)),
#  'transaction': (np.float64(0.03468208092485549),
#   np.float64(0.03993344425956739)),
#  'firm': (np.float64(0.007140428425705543), np.float64(0.015806988352745424)),
#  'poullain': (np.float64(0.00034002040122407346),
#   np.float64(0.02329450915141431)),
#  'reported': (np.float64(0.005440326419585175),
#   np.float64(0.016638935108153077)),
#  'sage': (np.float64(0.0010200612036722204), np.float64(0.02745424292845258)),
#  '09': (np.float64(0.01292077524651479), np.float64(0.129783693843594)),
#  'booked': (np.float64(0.0013600816048962938),
#   np.float64(0.009151414309484194)),
#  'issues': (np.float64(0.007140428425705543), np.float64(0.12063227953410982)),
#  'bound': (np.float64(0.003060183611016661),
#   np.float64(0.0033277870216306157)),
#  'lon': (np.float64(0.002040122407344441), np.float64(0.12479201331114809)),
#  '4': (np.float64(0.12682760965657938), np.float64(0.15806988352745424)),
#  'may': (np.float64(0.15912954777286636), np.float64(0.18386023294509152)),
#  'derivative': (np.float64(0.0006800408024481469),
#   np.float64(0.0033277870216306157)),
#  'joe': (np.float64(0.003740224413464808), np.float64(0.050748752079866885)),
#  'symptoms': (np.float64(0.0006800408024481469),
#   np.float64(0.0033277870216306157)),
#  'has': (np.float64(0.17953077184631078), np.float64(0.28369384359401)),
#  'day': (np.float64(0.11118667120027202), np.float64(0.14559068219633944)),
#  '12': (np.float64(0.08024481468888134), np.float64(0.1930116472545757)),
#  'memo': (np.float64(0.00034002040122407346), np.float64(0.06405990016638935)),
#  'hill': (np.float64(0.0051003060183611015), np.float64(0.012479201331114808)),
#  'place': (np.float64(0.04216252975178511), np.float64(0.07986688851913477)),
#  'last': (np.float64(0.058143488609316556), np.float64(0.12479201331114809)),
#  'justify': (np.float64(0.0006800408024481469),
#   np.float64(0.004991680532445923)),
#  'position': (np.float64(0.03876232573954437),
#   np.float64(0.07653910149750416)),
#  'incomplete': (np.float64(0.0010200612036722204),
#   np.float64(0.004159733777038269)),
#  'functionality': (np.float64(0.0006800408024481469),
#   np.float64(0.01913477537437604)),
#  'sections': (np.float64(0.004420265215912955),
#   np.float64(0.0033277870216306157)),
#  'finalised': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'deal': (np.float64(0.029921795307718463), np.float64(0.08985024958402663)),
#  'proposed': (np.float64(0.005780346820809248),
#   np.float64(0.02745424292845258)),
#  'play': (np.float64(0.017001020061203673), np.float64(0.005823627287853577)),
#  'spreadsheets': (np.float64(0.00034002040122407346),
#   np.float64(0.012479201331114808)),
#  '11': (np.float64(0.04046242774566474), np.float64(0.18302828618968386)),
#  'davies': (np.float64(0.0006800408024481469),
#   np.float64(0.013311148086522463)),
#  'completed': (np.float64(0.017341040462427744),
#   np.float64(0.064891846921797)),
#  'astray': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'certain': (np.float64(0.032641958517511054),
#   np.float64(0.036605657237936774)),
#  'beck': (np.float64(0.00034002040122407346), np.float64(0.21630615640599002)),
#  'soon': (np.float64(0.04250255015300918), np.float64(0.08319467554076539)),
#  'drop': (np.float64(0.006460387623257395), np.float64(0.009151414309484194)),
#  'london': (np.float64(0.00884053043182591), np.float64(0.129783693843594)),
#  '30': (np.float64(0.07922475348520912), np.float64(0.14725457570715475)),
#  'recommend': (np.float64(0.004420265215912955),
#   np.float64(0.012479201331114808)),
#  'th': (np.float64(0.044202652159129545), np.float64(0.11314475873544093)),
#  'brown': (np.float64(0.003060183611016661), np.float64(0.03826955074875208)),
#  'gold': (np.float64(0.013260795647738865), np.float64(0.012479201331114808)),
#  'leave': (np.float64(0.014620877252635158), np.float64(0.029950083194675542)),
#  'sloman': (np.float64(0.00034002040122407346),
#   np.float64(0.008319467554076539)),
#  'then': (np.float64(0.06630397823869433), np.float64(0.09151414309484193)),
#  'overall': (np.float64(0.004420265215912955),
#   np.float64(0.029118136439267885)),
#  'project': (np.float64(0.019041142468548114),
#   np.float64(0.07820299500831947)),
#  'matter': (np.float64(0.02584155049302958), np.float64(0.01747088186356073)),
#  'millerchip': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'many': (np.float64(0.09962597755865352), np.float64(0.06905158069883527)),
#  'completion': (np.float64(0.003060183611016661),
#   np.float64(0.022462562396006656)),
#  'rebecca': (np.float64(0.0013600816048962938),
#   np.float64(0.018302828618968387)),
#  'dpr': (np.float64(0.00034002040122407346), np.float64(0.05740432612312812)),
#  'surely': (np.float64(0.002040122407344441),
#   np.float64(0.0033277870216306157)),
#  'ticking': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'system': (np.float64(0.07786467188031282), np.float64(0.10815307820299501)),
#  'expect': (np.float64(0.023461407684461068),
#   np.float64(0.025790349417637273)),
#  'richard': (np.float64(0.005440326419585175), np.float64(0.0956738768718802)),
#  'thing': (np.float64(0.048622917375042506), np.float64(0.02745424292845258)),
#  'steps': (np.float64(0.014960897653859231), np.float64(0.03161397670549085)),
#  'band': (np.float64(0.002040122407344441), np.float64(0.0024958402662229617)),
#  'ebs': (np.float64(0.00034002040122407346), np.float64(0.03161397670549085)),
#  'apx': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'mark': (np.float64(0.008160489629377763), np.float64(0.10898502495840266)),
#  'pay': (np.float64(0.04114246854811289), np.float64(0.018302828618968387)),
#  'response': (np.float64(0.02856171370282217),
#   np.float64(0.03161397670549085)),
#  'cc': (np.float64(0.0013600816048962938), np.float64(0.348585690515807)),
#  'r': (np.float64(0.1088065283917035), np.float64(0.0632279534109817)),
#  'pickering': (np.float64(0.0006800408024481469),
#   np.float64(0.009983361064891847)),
#  'revalued': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'everyday': (np.float64(0.006460387623257395),
#   np.float64(0.005823627287853577)),
#  'appears': (np.float64(0.005780346820809248),
#   np.float64(0.016638935108153077)),
#  'nevertheless': (np.float64(0.0006800408024481469),
#   np.float64(0.005823627287853577)),
#  'lack': (np.float64(0.008500510030601836), np.float64(0.009983361064891847)),
#  'loss': (np.float64(0.015300918055083304), np.float64(0.01913477537437604)),
#  'people': (np.float64(0.10166609996599796), np.float64(0.12312811980033278)),
#  'purpose': (np.float64(0.011560693641618497),
#   np.float64(0.015806988352745424)),
#  'points': (np.float64(0.004080244814688882),
#   np.float64(0.028286189683860232)),
#  'them': (np.float64(0.06324379462767767), np.float64(0.13810316139767054)),
#  'andrew': (np.float64(0.003060183611016661),
#   np.float64(0.054076539101497505)),
#  'way': (np.float64(0.17511050663039782), np.float64(0.06988352745424292)),
#  '3': (np.float64(0.21285277116626997), np.float64(0.2096505823627288)),
#  'set': (np.float64(0.03638218293097586), np.float64(0.09650582362728785)),
#  'w': (np.float64(0.026181570894253655), np.float64(0.06738768718801996)),
#  'tim': (np.float64(0.0027201632097925877), np.float64(0.042429284525790346)),
#  'individuals': (np.float64(0.012580754845290717),
#   np.float64(0.03826955074875208)),
#  'james': (np.float64(0.003740224413464808), np.float64(0.09400998336106489)),
#  'ask': (np.float64(0.030941856511390683), np.float64(0.036605657237936774)),
#  'more': (np.float64(0.23529411764705882), np.float64(0.16555740432612312)),
#  'stem': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'tool': (np.float64(0.008160489629377763), np.float64(0.009151414309484194)),
#  'comments': (np.float64(0.0027201632097925877),
#   np.float64(0.1048252911813644)),
#  'bright': (np.float64(0.002040122407344441),
#   np.float64(0.0024958402662229617)),
#  'milder': (np.float64(0.0006800408024481469),
#   np.float64(0.0016638935108153079)),
#  'processes': (np.float64(0.006460387623257395),
#   np.float64(0.05574043261231281)),
#  'projects': (np.float64(0.029241754505270317),
#   np.float64(0.030782029950083195)),
#  'allowed': (np.float64(0.008160489629377763),
#   np.float64(0.004159733777038269)),
#  'excel': (np.float64(0.0010200612036722204),
#   np.float64(0.016638935108153077)),
#  'items': (np.float64(0.03468208092485549), np.float64(0.04658901830282862)),
#  'apologies': (np.float64(0.006120367222033322),
#   np.float64(0.009983361064891847)),
#  'apply': (np.float64(0.015640938456307377), np.float64(0.005823627287853577)),
#  'cornfield': (np.float64(0.00034002040122407346),
#   np.float64(0.03993344425956739)),
#  'recall': (np.float64(0.00034002040122407346),
#   np.float64(0.010815307820299502)),
#  'year': (np.float64(0.05406324379462768), np.float64(0.11314475873544093)),
#  'too': (np.float64(0.056783407004420264), np.float64(0.03743760399334443)),
#  'memory': (np.float64(0.0047602856171370285),
#   np.float64(0.0074875207986688855)),
#  'become': (np.float64(0.04930295817749065), np.float64(0.028286189683860232)),
#  'dp': (np.float64(0.0006800408024481469), np.float64(0.008319467554076539)),
#  'rather': (np.float64(0.006460387623257395), np.float64(0.03494176372712146)),
#  'off': (np.float64(0.03604216252975179), np.float64(0.09234608985024959)),
#  'identifying': (np.float64(0.0034002040122407345),
#   np.float64(0.008319467554076539)),
#  'those': (np.float64(0.05610336620197212), np.float64(0.064891846921797)),
#  'comment': (np.float64(0.0006800408024481469),
#   np.float64(0.01913477537437604)),
#  'during': (np.float64(0.027201632097925876), np.float64(0.09234608985024959)),
#  'former': (np.float64(0.009520571234274057),
#   np.float64(0.0074875207986688855)),
#  'seems': (np.float64(0.0047602856171370285),
#   np.float64(0.024126455906821963)),
#  'irritating': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'stand': (np.float64(0.05168310098605916), np.float64(0.0066555740432612314)),
#  'worrying': (np.float64(0.0010200612036722204),
#   np.float64(0.0033277870216306157)),
#  'an': (np.float64(0.23529411764705882), np.float64(0.2895174708818636)),
#  'changing': (np.float64(0.0047602856171370285),
#   np.float64(0.01747088186356073)),
#  'any': (np.float64(0.22067324039442365), np.float64(0.391846921797005)),
#  'sponsors': (np.float64(0.0027201632097925877),
#   np.float64(0.004991680532445923)),
#  'analyse': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'uk': (np.float64(0.043862631757905474), np.float64(0.024958402662229616)),
#  'hypothesis': (np.float64(0.0006800408024481469),
#   np.float64(0.0033277870216306157)),
#  'how': (np.float64(0.1329479768786127), np.float64(0.12728785357737105)),
#  'exchange': (np.float64(0.03060183611016661),
#   np.float64(0.019966722129783693)),
#  'tani': (np.float64(0.00034002040122407346),
#   np.float64(0.008319467554076539)),
#  'ted': (np.float64(0.0010200612036722204), np.float64(0.08319467554076539)),
#  'sherriff': (np.float64(0.00034002040122407346),
#   np.float64(0.025790349417637273)),
#  'alluded': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'inappropriate': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'operation': (np.float64(0.010540632437946278),
#   np.float64(0.010815307820299502)),
#  '5': (np.float64(0.2431145868752125), np.float64(0.13976705490848584)),
#  'spent': (np.float64(0.0384223053383203), np.float64(0.009983361064891847)),
#  'made': (np.float64(0.11424685481128868), np.float64(0.10316139767054909)),
#  'errors': (np.float64(0.015640938456307377), np.float64(0.01913477537437604)),
#  'jordan': (np.float64(0.002040122407344441), np.float64(0.09234608985024959)),
#  'applied': (np.float64(0.003060183611016661),
#   np.float64(0.011647254575707155)),
#  'fernley': (np.float64(0.00034002040122407346),
#   np.float64(0.06988352745424292)),
#  'january': (np.float64(0.006800408024481469),
#   np.float64(0.033277870216306155)),
#  'holes': (np.float64(0.0013600816048962938),
#   np.float64(0.0016638935108153079)),
#  'brent': (np.float64(0.00034002040122407346),
#   np.float64(0.10898502495840266)),
#  'witnessed': (np.float64(0.0006800408024481469),
#   np.float64(0.0016638935108153079)),
#  '10': (np.float64(0.15708942536552192), np.float64(0.1772046589018303)),
#  'why': (np.float64(0.03536212172730364), np.float64(0.03410981697171381)),
#  'matrix': (np.float64(0.004080244814688882),
#   np.float64(0.009983361064891847)),
#  '1998': (np.float64(0.005440326419585175), np.float64(0.004159733777038269)),
#  'first': (np.float64(0.07242434546072764), np.float64(0.1064891846921797)),
#  'usually': (np.float64(0.0047602856171370285),
#   np.float64(0.0074875207986688855)),
#  'consists': (np.float64(0.0047602856171370285),
#   np.float64(0.004991680532445923)),
#  'much': (np.float64(0.06766405984359061), np.float64(0.064891846921797)),
#  'counterpart': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'murphy': (np.float64(0.00034002040122407346),
#   np.float64(0.059900166389351084)),
#  'than': (np.float64(0.1101666099965998), np.float64(0.08652246256239601)),
#  'options': (np.float64(0.01088065283917035),
#   np.float64(0.026622296173044926)),
#  'missed': (np.float64(0.0017001020061203672),
#   np.float64(0.008319467554076539)),
#  'concentrated': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'incompleteness': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'who': (np.float64(0.11118667120027202), np.float64(0.1622296173044925)),
#  'out': (np.float64(0.19891193471608296), np.float64(0.19966722129783693)),
#  'hou': (np.float64(0.0017001020061203672), np.float64(0.2762063227953411)),
#  'questions': (np.float64(0.024821489289357363),
#   np.float64(0.23627287853577372)),
#  'basis': (np.float64(0.015300918055083304), np.float64(0.064891846921797)),
#  'reviews': (np.float64(0.008160489629377763),
#   np.float64(0.024126455906821963)),
#  'built': (np.float64(0.009520571234274057), np.float64(0.010815307820299502)),
#  'value': (np.float64(0.034002040122407345), np.float64(0.050748752079866885)),
#  'part': (np.float64(0.06188371302278137), np.float64(0.064891846921797)),
#  'power': (np.float64(0.02754165249914995), np.float64(0.08735440931780367)),
#  'accommodate': (np.float64(0.0017001020061203672),
#   np.float64(0.0066555740432612314)),
#  'price': (np.float64(0.09350561033662019), np.float64(0.10981697171381032)),
#  'process': (np.float64(0.035022101326079566),
#   np.float64(0.20133111480865223)),
#  'knock': (np.float64(0.0013600816048962938),
#   np.float64(0.0033277870216306157)),
#  'control': (np.float64(0.030941856511390683),
#   np.float64(0.05574043261231281)),
#  'injury': (np.float64(0.0013600816048962938),
#   np.float64(0.0016638935108153079)),
#  'should': (np.float64(0.08398503910234614), np.float64(0.21880199667221298)),
#  'doorpost': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'mike': (np.float64(0.002040122407344441), np.float64(0.15557404326123128)),
#  'especially': (np.float64(0.011220673240394424),
#   np.float64(0.01747088186356073)),
#  'post': (np.float64(0.016320979258755527), np.float64(0.021630615640599003)),
#  'intended': (np.float64(0.016660999659979598),
#   np.float64(0.015806988352745424)),
#  'aid': (np.float64(0.003060183611016661), np.float64(0.0033277870216306157)),
#  'identified': (np.float64(0.022101326079564772),
#   np.float64(0.029950083194675542)),
#  'suspect': (np.float64(0.003060183611016661),
#   np.float64(0.0066555740432612314)),
#  'limits': (np.float64(0.0017001020061203672),
#   np.float64(0.024126455906821963)),
#  'version': (np.float64(0.06766405984359061),
#   np.float64(0.039101497504159734)),
#  'effects': (np.float64(0.029241754505270317),
#   np.float64(0.004991680532445923)),
#  '1': (np.float64(0.23631417885073105), np.float64(0.22462562396006655)),
#  'commenced': (np.float64(0.0010200612036722204),
#   np.float64(0.004991680532445923)),
#  'deliveries': (np.float64(0.0006800408024481469),
#   np.float64(0.004159733777038269)),
#  'assignments': (np.float64(0.00034002040122407346),
#   np.float64(0.01913477537437604)),
#  'structured': (np.float64(0.0013600816048962938),
#   np.float64(0.011647254575707155)),
#  'happened': (np.float64(0.005780346820809248),
#   np.float64(0.011647254575707155)),
#  'sweeney': (np.float64(0.00034002040122407346),
#   np.float64(0.02329450915141431)),
#  'operate': (np.float64(0.012240734444066644),
#   np.float64(0.008319467554076539)),
#  'notification': (np.float64(0.03468208092485549),
#   np.float64(0.012479201331114808)),
#  'timelines': (np.float64(0.00034002040122407346),
#   np.float64(0.008319467554076539)),
#  'm': (np.float64(0.13056783407004421), np.float64(0.1447587354409318)),
#  'partly': (np.float64(0.0010200612036722204),
#   np.float64(0.004991680532445923)),
#  'gail': (np.float64(0.00034002040122407346),
#   np.float64(0.011647254575707155)),
#  '31': (np.float64(0.018021081264875893), np.float64(0.06156405990016639)),
#  'corp': (np.float64(0.010200612036722203), np.float64(0.20133111480865223)),
#  'most': (np.float64(0.08024481468888134), np.float64(0.08319467554076539)),
#  'higher': (np.float64(0.0217613056783407), np.float64(0.010815307820299502)),
#  'amazed': (np.float64(0.0023801428085685142),
#   np.float64(0.0024958402662229617)),
#  'relatively': (np.float64(0.003740224413464808),
#   np.float64(0.010815307820299502)),
#  'ect': (np.float64(0.0013600816048962938), np.float64(0.3211314475873544)),
#  'did': (np.float64(0.031961917715062904), np.float64(0.07903494176372712)),
#  'about': (np.float64(0.18531111866712002), np.float64(0.17221297836938437)),
#  'gas': (np.float64(0.012580754845290717), np.float64(0.1048252911813644)),
#  'doorstep': (np.float64(0.0006800408024481469),
#   np.float64(0.059900166389351084)),
#  'widespread': (np.float64(0.0010200612036722204),
#   np.float64(0.0016638935108153079)),
#  'prioritisation': (np.float64(0.00034002040122407346),
#   np.float64(0.0074875207986688855)),
#  'example': (np.float64(0.01394083645018701),
#   np.float64(0.024126455906821963)),
#  'socrates': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'dyson': (np.float64(0.00034002040122407346),
#   np.float64(0.06073211314475874)),
#  'anyway': (np.float64(0.0006800408024481469),
#   np.float64(0.005823627287853577)),
#  'stabilise': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'eric': (np.float64(0.00034002040122407346),
#   np.float64(0.024958402662229616)),
#  'continental': (np.float64(0.0034002040122407345),
#   np.float64(0.014975041597337771)),
#  'responsible': (np.float64(0.004420265215912955),
#   np.float64(0.0632279534109817)),
#  'nuances': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'been': (np.float64(0.15130907854471268), np.float64(0.24625623960066556)),
#  'possibly': (np.float64(0.003060183611016661),
#   np.float64(0.0074875207986688855)),
#  'market': (np.float64(0.06324379462767767), np.float64(0.08069883527454243)),
#  'contains': (np.float64(0.034002040122407345),
#   np.float64(0.015806988352745424)),
#  'final': (np.float64(0.020401224073444406), np.float64(0.0632279534109817)),
#  'kevin': (np.float64(0.0013600816048962938), np.float64(0.04991680532445923)),
#  'think': (np.float64(0.02448146888813329), np.float64(0.12728785357737105)),
#  'causes': (np.float64(0.004420265215912955),
#   np.float64(0.005823627287853577)),
#  'nath': (np.float64(0.00034002040122407346),
#   np.float64(0.009983361064891847)),
#  'moment': (np.float64(0.012580754845290717),
#   np.float64(0.009983361064891847)),
#  'important': (np.float64(0.033321999319959196),
#   np.float64(0.050748752079866885)),
#  'communicate': (np.float64(0.0034002040122407345),
#   np.float64(0.02329450915141431)),
#  'fundamental': (np.float64(0.00034002040122407346),
#   np.float64(0.010815307820299502)),
#  'although': (np.float64(0.011900714042842571),
#   np.float64(0.033277870216306155)),
#  '2000': (np.float64(0.013260795647738865), np.float64(0.3119800332778702)),
#  'month': (np.float64(0.05032301938116287), np.float64(0.06905158069883527)),
#  'go': (np.float64(0.09724583475008501), np.float64(0.10565723793677205)),
#  'insult': (np.float64(0.0006800408024481469),
#   np.float64(0.0016638935108153079)),
#  'ongoing': (np.float64(0.006800408024481469),
#   np.float64(0.013311148086522463)),
#  'react': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'state': (np.float64(0.03808228493709623), np.float64(0.016638935108153077)),
#  'viewed': (np.float64(0.0006800408024481469),
#   np.float64(0.0066555740432612314)),
#  'history': (np.float64(0.021081264875892555),
#   np.float64(0.008319467554076539)),
#  'revisions': (np.float64(0.00034002040122407346),
#   np.float64(0.008319467554076539)),
#  'patterson': (np.float64(0.00034002040122407346),
#   np.float64(0.024126455906821963)),
#  'us': (np.float64(0.18123087385243114), np.float64(0.22462562396006655)),
#  '7': (np.float64(0.1023461407684461), np.float64(0.08069883527454243)),
#  'concern': (np.float64(0.007480448826929616),
#   np.float64(0.01913477537437604)),
#  'document': (np.float64(0.006800408024481469),
#   np.float64(0.051580698835274545)),
#  'commodity': (np.float64(0.002040122407344441),
#   np.float64(0.07820299500831947)),
#  'performing': (np.float64(0.005440326419585175),
#   np.float64(0.008319467554076539)),
#  'michael': (np.float64(0.008160489629377763),
#   np.float64(0.09816971713810316)),
#  'trades': (np.float64(0.0013600816048962938),
#   np.float64(0.045757071547420966)),
#  'result': (np.float64(0.04930295817749065), np.float64(0.04076539101497504)),
#  'point': (np.float64(0.020061203672220335), np.float64(0.06655574043261231)),
#  'microsoft': (np.float64(0.01292077524651479),
#   np.float64(0.0066555740432612314)),
#  'forwarded': (np.float64(0.0023801428085685142),
#   np.float64(0.259567387687188)),
#  'heads': (np.float64(0.0010200612036722204),
#   np.float64(0.026622296173044926)),
#  'recent': (np.float64(0.017001020061203673), np.float64(0.04076539101497504)),
#  'valdez': (np.float64(0.00034002040122407346),
#   np.float64(0.004159733777038269)),
#  'causey': (np.float64(0.0006800408024481469),
#   np.float64(0.05574043261231281)),
#  'buy': (np.float64(0.07990479428765726), np.float64(0.048252911813643926)),
#  'following': (np.float64(0.09248554913294797),
#   np.float64(0.18136439267886856)),
#  'kaminski': (np.float64(0.00034002040122407346),
#   np.float64(0.005823627287853577)),
#  'whalley': (np.float64(0.00034002040122407346),
#   np.float64(0.014975041597337771)),
#  'america': (np.float64(0.023461407684461068),
#   np.float64(0.08652246256239601)),
#  'thoughts': (np.float64(0.0034002040122407345),
#   np.float64(0.03993344425956739)),
#  'website': (np.float64(0.15198911934716083), np.float64(0.01747088186356073)),
#  'kenneth': (np.float64(0.0017001020061203672),
#   np.float64(0.011647254575707155)),
#  'posted': (np.float64(0.002040122407344441), np.float64(0.0324459234608985)),
#  'cliff': (np.float64(0.0006800408024481469),
#   np.float64(0.004991680532445923)),
#  'joseph': (np.float64(0.0027201632097925877),
#   np.float64(0.026622296173044926)),
#  'lavorato': (np.float64(0.00034002040122407346),
#   np.float64(0.029950083194675542)),
#  'employees': (np.float64(0.007480448826929616),
#   np.float64(0.059900166389351084)),
#  'vince': (np.float64(0.0006800408024481469),
#   np.float64(0.008319467554076539)),
#  '02': (np.float64(0.01088065283917035), np.float64(0.08818635607321132)),
#  'bradford': (np.float64(0.00034002040122407346),
#   np.float64(0.012479201331114808)),
#  'veronica': (np.float64(0.0006800408024481469),
#   np.float64(0.009983361064891847)),
#  'opinion': (np.float64(0.015300918055083304),
#   np.float64(0.009983361064891847)),
#  'e': (np.float64(0.20843250595035703), np.float64(0.19384359400998336)),
#  'taylor': (np.float64(0.0017001020061203672),
#   np.float64(0.02329450915141431)),
#  'baxter': (np.float64(0.0006800408024481469),
#   np.float64(0.025790349417637273)),
#  'moscoso': (np.float64(0.00034002040122407346),
#   np.float64(0.03494176372712146)),
#  'north': (np.float64(0.01768106086365182), np.float64(0.08485856905158069)),
#  'liz': (np.float64(0.0006800408024481469), np.float64(0.004159733777038269)),
#  'perez': (np.float64(0.0017001020061203672), np.float64(0.01913477537437604)),
# ...
#   np.float64(0.0074875207986688855)),
#  'hargrave': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'solmonson': (np.float64(0.00034002040122407346),
#   np.float64(0.051580698835274545)),
#  'jennifer': (np.float64(0.0023801428085685142),
#   np.float64(0.030782029950083195)),
#  'chavira': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'riedel': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'd': (np.float64(0.0819449166950017), np.float64(0.11314475873544093)),
#  'co': (np.float64(0.03468208092485549), np.float64(0.03410981697171381)),
#  'shona': (np.float64(0.00034002040122407346),
#   np.float64(0.10981697171381032)),
#  'gretchen': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  '02372': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'ann': (np.float64(0.0023801428085685142), np.float64(0.0066555740432612314)),
#  'bryce': (np.float64(0.0010200612036722204),
#   np.float64(0.019966722129783693)),
#  'continue': (np.float64(0.03434206052363142),
#   np.float64(0.07903494176372712)),
#  'mcloughlin': (np.float64(0.00034002040122407346),
#   np.float64(0.030782029950083195)),
#  'h': (np.float64(0.022441346480788847), np.float64(0.028286189683860232)),
#  'dan': (np.float64(0.003740224413464808), np.float64(0.013311148086522463)),
#  'sprock': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'human': (np.float64(0.011560693641618497), np.float64(0.029118136439267885)),
#  'sr': (np.float64(0.0010200612036722204), np.float64(0.010815307820299502)),
#  'strambler': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'stewart': (np.float64(0.003060183611016661),
#   np.float64(0.004991680532445923)),
#  'tumey': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'lee': (np.float64(0.002040122407344441), np.float64(0.016638935108153077)),
#  'robin': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'kyle': (np.float64(0.00034002040122407346),
#   np.float64(0.004159733777038269)),
#  'dalton': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  '413': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'badge': (np.float64(0.0010200612036722204),
#   np.float64(0.004159733777038269)),
#  'burns': (np.float64(0.0017001020061203672),
#   np.float64(0.0016638935108153079)),
#  'lisa': (np.float64(0.0023801428085685142), np.float64(0.028286189683860232)),
#  'bob': (np.float64(0.0017001020061203672), np.float64(0.09650582362728785)),
#  'charlene': (np.float64(0.00034002040122407346),
#   np.float64(0.01747088186356073)),
#  'hayslett': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'oxley': (np.float64(0.00034002040122407346),
#   np.float64(0.014975041597337771)),
#  'wade': (np.float64(0.00034002040122407346),
#   np.float64(0.009983361064891847)),
#  '83': (np.float64(0.006120367222033322), np.float64(0.0033277870216306157)),
#  'apollo': (np.float64(0.00034002040122407346),
#   np.float64(0.03993344425956739)),
#  'ena': (np.float64(0.00034002040122407346), np.float64(0.08153078202995008)),
#  'dashboard': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'cynthia': (np.float64(0.00034002040122407346),
#   np.float64(0.014143094841930116)),
#  '04': (np.float64(0.007480448826929616), np.float64(0.08985024958402663)),
#  'padron': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'denise': (np.float64(0.0006800408024481469),
#   np.float64(0.004159733777038269)),
#  'bonnard': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'coombe': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'participated': (np.float64(0.0010200612036722204),
#   np.float64(0.0074875207986688855)),
#  'attended': (np.float64(0.002040122407344441),
#   np.float64(0.0066555740432612314)),
#  'sengupta': (np.float64(0.0006800408024481469),
#   np.float64(0.0033277870216306157)),
#  'lawrence': (np.float64(0.0010200612036722204),
#   np.float64(0.0033277870216306157)),
#  'mahendra': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'jackson': (np.float64(0.002040122407344441),
#   np.float64(0.03410981697171381)),
#  'attachment': (np.float64(0.0027201632097925877),
#   np.float64(0.01913477537437604)),
#  '39': (np.float64(0.03570214212852771), np.float64(0.024958402662229616)),
#  'attend': (np.float64(0.004080244814688882), np.float64(0.05906821963394343)),
#  'stubbs': (np.float64(0.00034002040122407346),
#   np.float64(0.004991680532445923)),
#  'poston': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'lessner': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'peikert': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'kathy': (np.float64(0.0006800408024481469),
#   np.float64(0.008319467554076539)),
#  'turn': (np.float64(0.017001020061203673), np.float64(0.011647254575707155)),
#  'grimes': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'sparger': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  '16': (np.float64(0.02584155049302958), np.float64(0.08901830282861897)),
#  'perkins': (np.float64(0.00034002040122407346),
#   np.float64(0.013311148086522463)),
#  'petruszka': (np.float64(0.00034002040122407346),
#   np.float64(0.004159733777038269)),
#  'mclean': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'cassandra': (np.float64(0.00034002040122407346),
#   np.float64(0.024958402662229616)),
#  'ots': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'rice': (np.float64(0.0013600816048962938), np.float64(0.005823627287853577)),
#  'yowman': (np.float64(0.00034002040122407346),
#   np.float64(0.004991680532445923)),
#  'wysatta': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'training': (np.float64(0.011900714042842571),
#   np.float64(0.02745424292845258)),
#  'selzer': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'gilchrist': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'hughes': (np.float64(0.0010200612036722204),
#   np.float64(0.008319467554076539)),
#  '32': (np.float64(0.008500510030601836), np.float64(0.024958402662229616)),
#  'projected': (np.float64(0.0034002040122407345),
#   np.float64(0.008319467554076539)),
#  'ellen': (np.float64(0.00034002040122407346),
#   np.float64(0.005823627287853577)),
#  '76': (np.float64(0.0027201632097925877), np.float64(0.0033277870216306157)),
#  'brad': (np.float64(0.0010200612036722204), np.float64(0.014975041597337771)),
#  'b': (np.float64(0.0550833049982999), np.float64(0.054076539101497505)),
#  'castleman': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'schnauber': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'rod': (np.float64(0.0010200612036722204), np.float64(0.0066555740432612314)),
#  '8': (np.float64(0.13736824209452567), np.float64(0.1048252911813644)),
#  'harman': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'ervin': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'williams': (np.float64(0.0047602856171370285),
#   np.float64(0.013311148086522463)),
#  'marlow': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'goh': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  '64': (np.float64(0.009180550833049982), np.float64(0.004159733777038269)),
#  'attendance': (np.float64(0.0017001020061203672),
#   np.float64(0.014975041597337771)),
#  'daler': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'brian': (np.float64(0.0023801428085685142), np.float64(0.04908485856905158)),
#  'everyone': (np.float64(0.018361101666099965),
#   np.float64(0.06073211314475874)),
#  'eckels': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'margaret': (np.float64(0.0010200612036722204),
#   np.float64(0.0024958402662229617)),
#  'melissa': (np.float64(0.00034002040122407346),
#   np.float64(0.02745424292845258)),
#  'sherry': (np.float64(0.00034002040122407346),
#   np.float64(0.004159733777038269)),
#  'fance': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  '53': (np.float64(0.004080244814688882), np.float64(0.01747088186356073)),
#  'kent': (np.float64(0.00034002040122407346),
#   np.float64(0.004159733777038269)),
#  'bobby': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'scott': (np.float64(0.0051003060183611015), np.float64(0.07986688851913477)),
#  'stubblefield': (np.float64(0.00034002040122407346),
#   np.float64(0.009151414309484194)),
#  'gerry': (np.float64(0.00034002040122407346),
#   np.float64(0.004991680532445923)),
#  'howes': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'debbie': (np.float64(0.0006800408024481469),
#   np.float64(0.022462562396006656)),
#  'sommers': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'nikkel': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'andrea': (np.float64(0.0006800408024481469),
#   np.float64(0.026622296173044926)),
#  'statistics': (np.float64(0.0027201632097925877),
#   np.float64(0.005823627287853577)),
#  'sullivan': (np.float64(0.00034002040122407346),
#   np.float64(0.0074875207986688855)),
#  'keith': (np.float64(0.0017001020061203672),
#   np.float64(0.011647254575707155)),
#  'drew': (np.float64(0.010200612036722203), np.float64(0.0066555740432612314)),
#  'lorna': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  '40': (np.float64(0.023801428085685142), np.float64(0.03577371048252912)),
#  'biren': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'howard': (np.float64(0.0023801428085685142),
#   np.float64(0.016638935108153077)),
#  'morton': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'fgt': (np.float64(0.00034002040122407346), np.float64(0.004991680532445923)),
#  'carol': (np.float64(0.0006800408024481469),
#   np.float64(0.015806988352745424)),
#  'janie': (np.float64(0.0006800408024481469),
#   np.float64(0.004159733777038269)),
#  'bennett': (np.float64(0.00034002040122407346),
#   np.float64(0.004991680532445923)),
#  'colwell': (np.float64(0.00034002040122407346),
#   np.float64(0.022462562396006656)),
#  'diane': (np.float64(0.002040122407344441), np.float64(0.009983361064891847)),
#  'cagney': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'coleman': (np.float64(0.00034002040122407346),
#   np.float64(0.0066555740432612314)),
#  'et': (np.float64(0.00986059163549813), np.float64(0.0074875207986688855)),
#  'kathryn': (np.float64(0.00034002040122407346),
#   np.float64(0.010815307820299502)),
#  'merlyn': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'ron': (np.float64(0.0006800408024481469), np.float64(0.008319467554076539)),
#  'amabile': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'greek': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'schultz': (np.float64(0.0013600816048962938),
#   np.float64(0.020798668885191347)),
#  'fink': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'units': (np.float64(0.0017001020061203672),
#   np.float64(0.029950083194675542)),
#  'classes': (np.float64(0.0010200612036722204),
#   np.float64(0.009151414309484194)),
#  'knudsen': (np.float64(0.00034002040122407346),
#   np.float64(0.004991680532445923)),
#  '100': (np.float64(0.08364501870112206), np.float64(0.01913477537437604)),
#  'patrick': (np.float64(0.0013600816048962938),
#   np.float64(0.019966722129783693)),
#  '94': (np.float64(0.003060183611016661), np.float64(0.0024958402662229617)),
#  'jandrell': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'traylor': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'gco': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'encouraging': (np.float64(0.002040122407344441),
#   np.float64(0.0033277870216306157)),
#  'jill': (np.float64(0.00034002040122407346),
#   np.float64(0.0066555740432612314)),
#  'gpgfin': (np.float64(0.00034002040122407346),
#   np.float64(0.011647254575707155)),
#  'miguel': (np.float64(0.0010200612036722204),
#   np.float64(0.005823627287853577)),
#  'kokas': (np.float64(0.00034002040122407346),
#   np.float64(0.004159733777038269)),
#  '91': (np.float64(0.005440326419585175), np.float64(0.0033277870216306157)),
#  'willie': (np.float64(0.00034002040122407346),
#   np.float64(0.004991680532445923)),
#  'chor': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'details': (np.float64(0.05236314178850731), np.float64(0.07321131447587355)),
#  'donnis': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'joyce': (np.float64(0.002040122407344441), np.float64(0.013311148086522463)),
#  'butts': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'c': (np.float64(0.04148248894933696), np.float64(0.08319467554076539)),
#  'lynch': (np.float64(0.0013600816048962938),
#   np.float64(0.0033277870216306157)),
#  'grest': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'olson': (np.float64(0.0017001020061203672),
#   np.float64(0.011647254575707155)),
#  'todd': (np.float64(0.0010200612036722204), np.float64(0.03826955074875208)),
#  'wes': (np.float64(0.00034002040122407346), np.float64(0.028286189683860232)),
#  'barrow': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'ray': (np.float64(0.0017001020061203672), np.float64(0.008319467554076539)),
#  'kumar': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'morrow': (np.float64(0.00034002040122407346),
#   np.float64(0.004159733777038269)),
#  'yates': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'ranendra': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  'erwin': (np.float64(0.00034002040122407346),
#   np.float64(0.0074875207986688855)),
#  'dave': (np.float64(0.0010200612036722204), np.float64(0.04159733777038269)),
#  'franz': (np.float64(0.002040122407344441),
#   np.float64(0.0024958402662229617)),
#  '68': (np.float64(0.004420265215912955), np.float64(0.0024958402662229617)),
#  'sa': (np.float64(0.011560693641618497), np.float64(0.013311148086522463)),
#  'schafer': (np.float64(0.0006800408024481469),
#   np.float64(0.0033277870216306157)),
#  'beth': (np.float64(0.00034002040122407346), np.float64(0.07487520798668885)),
#  'jeannie': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'chatham': (np.float64(0.00034002040122407346),
#   np.float64(0.0033277870216306157)),
#  'ellis': (np.float64(0.00034002040122407346),
#   np.float64(0.0024958402662229617)),
#  '78': (np.float64(0.0027201632097925877), np.float64(0.0033277870216306157)),
#  'robert': (np.float64(0.005440326419585175), np.float64(0.05324459234608985)),
#  'gpg': (np.float64(0.00034002040122407346), np.float64(0.005823627287853577)),
#  '21': (np.float64(0.04454267256035362), np.float64(0.06405990016638935)),
#  'dell': (np.float64(0.0006800408024481469), np.float64(0.004159733777038269)),
#  'o': (np.float64(0.07004420265215913), np.float64(0.018302828618968387)),
#  'lim': (np.float64(0.0017001020061203672), np.float64(0.008319467554076539)),
#  'becker': (np.float64(0.00034002040122407346),
#   np.float64(0.004159733777038269)),
#  'woods': (np.float64(0.0010200612036722204),
#   np.float64(0.0033277870216306157)),
#  'angelique': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'addendum': (np.float64(0.00034002040122407346),
#   np.float64(0.0016638935108153079)),
#  'really': (np.float64(0.05406324379462768), np.float64(0.051580698835274545)),
#  ...}

# %% [markdown]
# ### Классификация

# %%
def classify_message(words_prob, message, p_spam, p_ham):
    """
    Функция классифицирует message и определяет к какому классу оно относится 
    :param words_prob: словарь вида {key = слово; value = [P(вхождения в сообщения spam), P(вхождения в сообщения ham)]
    :param message: сообщение для классификации
    :param p_spam: Априорная вероятность, сообщение - спам
    :param p_ham: Априорная вероятность, сообщение - не спам
    :return:
    """
    message_words = preprocessing(message)
    log_prob_spam = np.log(p_spam)
    log_prob_ham = np.log(p_ham)
    for word in message_words:
        if word in words_prob:
            prob_word_in_spam, prob_word_in_ham = words_prob[word]
            log_prob_spam += np.log(prob_word_in_spam)
            log_prob_ham += np.log(prob_word_in_ham)
    if log_prob_spam > log_prob_ham :
        return 'spam'
    return 'ham'

# %% [markdown]
# ### Тестирование

# %%
numb_right_classified = 0; # счетчик точно классифицированных писем
count_emails = 0

# %%
def testing(directory,words_prob, p_spam, p_ham, class_email):
    global numb_right_classified
    global count_emails
    for filename in os.listdir(directory):
        with open(os.path.join(directory, filename), 'r') as file:
            res = classify_message(words_prob, file.read(), p_spam, p_ham)
            if res == class_email : numb_right_classified+=1
            count_emails+=1
    return

# %%
dir_spam_test = r"data2\data\spam_test"
dir_ham_test = r"data2\data\ham_test"

# %%
testing(dir_spam_test, words_prob, p_spam, p_ham, 'spam')
testing(dir_ham_test, words_prob, p_spam, p_ham, 'ham')

accuracy = numb_right_classified/ count_emails
print(f"Итоговая точность классификации: {accuracy:.2f}")
# Out:
# Итоговая точность классификации: 0.96
