# %% [markdown]
# # Naïve Bayes Classifier

# %% [markdown]
# ## Теория

# %% [markdown]
# ***Примечание 1.*** В основе NBC (Naïve Bayes Classifier) для классификации лежит, **теорема Байеса** :
# \\[P(H|E) = \frac{P(H) P(E|H)}{P(E)}\\]
#
# Для принятия решения нам потребуется научиться вычислять следующие величины:
# \\[P(спам|сообщение) = \frac{P(спам) P(сообщение|спам)}{P(сообщение)}\\]
# где,
# * \\(P(спам|сообщение)\\) - вероятность что сообщение принадлежит классу cпам, именно её нам надо рассчитать;
# * \\(P(спам)\\) - безусловная вероятность встретить сообщение класса спам в корпусе сообщений;
# * \\(P(сообщение|спам)\\) - вероятность встретить сообщение среди всех собщений класса спам;
# * \\(P(сообщение)\\) - безусловная вероятность сообщения в корпусе соообщений.
#
# ***Аналогично рассматривается величина \\(P(не\spaceспам|сообщение)\\)***

# %% [markdown]
# ***Примечание 2.*** Цель классификации состоит в том чтобы понять к какому классу принадлежит сообщение, поэтому нам нужна не сама вероятность, а наиболее вероятный класс(спам / не спам).
# Байесовский классификатор использует оценку **апостериорного максимума (Maximum a posteriori estimation)** для определения наиболее вероятного класса. Грубо говоря, это класс с максимальной вероятностью.
#
# \\[C_{\text{map}} = max(\frac{P(спам) P(сообщение|спам)}{P(сообщение)}, \frac{P(не\spaceспам) P(сообщение|не\spaceспам)}{P(сообщение)})\\]
#
# То есть нам надо рассчитать вероятность для всех классов и выбрать тот класс, который обладает максимальной вероятностью.

# %% [markdown]
# ***Примечание 3.*** знаменатель (вероятность сообщения) является константой и никак не может повлиять на ранжирование классов, поэтому в нашей задаче мы можем его игнорировать.
# **Формула №1:**
# \\[C_{\text{map}} = max(\space P(спам) P(сообщение|спам), P(не\spaceспам) P(сообщение|не\spaceспам)\space)\\]

# %% [markdown]
# ***Примечание 4.*** Байесовский же классификатор представляет документ как набор слов вероятности которых условно не зависят друг от друга.
#
# Исходя из этого предположения условная вероятность документа аппроксимируется произведением условных вероятностей всех слов входящих в документ.
#
# *например для сообщения "Купите наш товар!" принадлежещего классу **Спам***:
# \\[P(Купите\spaceнаш\spaceтовар|спам) ≈ P(Купите|спам) P(наш|спам) P(товар|спам)\\]
#
# Подставив полученное выражение в общем виде в **Формула №1** мы получим:
# \\[C_{\text{map}} = max(\space P(спам) \prod_{i=1}^{n}P(слово\space из\space сообщения|спам), P(не\spaceспам) \prod_{i=1}^{n}P(слово\space из\space сообщения|не\spaceспам)\space)\\]

# %% [markdown]
# ***Примечание 5.***  При достаточно большой длине документа придется перемножать большое количество очень маленьких чисел. Для того чтобы при этом избежать арифметического переполнения снизу зачастую пользуются свойством логарифма произведения: \\(log(ab) = \log(a) + \log(b)\\)
#
# \\[C_{\text{map}} = max(\space \log P(спам) + \sum_{i=1}^{n}\log P(слово\space из\space сообщения|спам), \log P(не\spaceспам) + \sum_{i=1}^{n}\log P(слово\space из\space сообщения|не\spaceспам)\space)\\]

# %% [markdown]
# ***Примечание 6.*** **Проблема неизвестных слов :**
# Но так как может оказаться даже что отдельное слово больше нигде не встречалось, то следует пойти на шаг дальше и применить так называемое сглаживание Лапласа, при котором мы для каждого слова мы притворяемся, что у нас есть ещё два письма: одно содержащее это слово и одно без такого слова. Т.е. финальная формула для вычисления
# такой вероятности выглядит так:
#
# \\[P(слово|спам) = \frac{P(спам-писем\space с\space словом + 1)}{P(спам-писем + 2)}\\]

# %% [markdown]
# ## Реализация

# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import os
import nltk

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Ilya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# ### Обучение
# #### Сбор данных: Соберем набор писем, которые уже помечены как спам или не спам. Создадим DataFrame на основе каталога содержащего наборы данных Enron-Spam.

# %%
def read_files(directory, label):
    """
    Прочитывает все файлы из directory и подготавливает их к упаковке в DF
    :param directory: директория из которой будут читаться файлы
    :param label: метка показывающая класс файла (spam/nam)
    :return: возвращает список подготовленных для упаковки в DF сообщений
    *(сообщение готово к упаковке в DF, если:
        -все слова находятся в lowerCase
        -отсутствуют знаки пунктуации, в т.ч. \space
        -сообщение разбито на токены ([word1, word2, .... wordn])
    """
    messages = []
    for filename in os.listdir(directory):
        with open(os.path.join(directory, filename), 'r') as file:
            text = preprocessing(file.read())
            messages.append((label, text))
    return messages


def create_dataFrame(messages):
    """
    Возвращает dataFrame с подготовленными данными для обучения классификатора на основе Naïve Bayes Classifier
    :param messages: Preprocessed Data (подготовленные данные)
    :return: dataFrame
    """
    df = pd.DataFrame(messages, columns=['Class', 'Message'])
    return df


def preprocessing(text):
    """
    Функция необходима для переработки text.
    Функция выполняет:
        1) Очистка text - удаление ненужных символов, таких как пунктуация, специальные символы.
        2) Приведение к нижнему регистру
        3) Токенизация text - разделение text на отдельные слова или токены.

    :param text: текст, который будет переработан
    :return: переработанный text
    """
    # Перевод слов в нижний регистр
    text = text.lower()

    # Удаление знаков пунткуации
    punctuation = "!\"#$%&'()*+,-./:;<=>?@[\\]^_`{|}~"
    translator = str.maketrans('', '', punctuation)
    text = text.translate(translator)

    #Токенизация
    words = text.split()
    words = list(set(words))

    return words
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Ilya\AppData\Local\Temp\ipykernel_12408\2304485705.py:2: SyntaxWarning: invalid escape sequence '\s'
#   """

# %%
path_directory_spam = r"C:\Users\Ilya\Desktop\ТВиМС\data2\data\spam"
path_directory_ham = r"C:\Users\Ilya\Desktop\ТВиМС\data2\data\ham"

messages_spam = read_files(path_directory_spam, "spam")
messages_ham = read_files(path_directory_ham, "ham")

all_messages = messages_ham + messages_spam

df = create_dataFrame(all_messages)
df
# Out:
#      Class                                            Message
# 0      ham  [roles, 2, analysis, of, need, business, curre...
# 1      ham  [taking, had, energy, allow, stay, arrangement...
# 2      ham  [revised, please, need, let, subject, understa...
# 3      ham  [them, about, way, addressed, you, been, ebs, ...
# 4      ham  [them, 1998, energy, usually, thanks, james, b...
# ...    ...                                                ...
# 4134  spam  [few, cd, draw, you, nickie, is, corel, find, ...
# 4135  spam  [few, downioad, cd, examples, draw, you, profe...
# 4136  spam  [jetlow, hate, disambiguate, silence, softs, l...
# 4137  spam  [jetlow, unknown, never, subject, looking, you...
# 4138  spam  [few, cd, examples, draw, you, regards, is, fi...
#
# [4139 rows x 2 columns]

# %% [markdown]
# #### Найдем оценку вероятности встретить каждое слово в спамном или не спамном сообщении.

# %% [markdown]
# Посчитаем сколько раз каждое слово встречается в каждом из типов сообщений:

# %%
def counts_word(data):
    """
    создает словарь вида {key = слово; value = [#количество вхождений в сообщения spam, #количество вхождений в сообщения ham]
    :param data: dataFrame с указанием класса сообщения (spam/ham) и токенизированным сообщением
    :return: словарь вида {key = слово; value = [#количество вхождений в сообщения spam, #количество вхождений в сообщения ham]
    """
    counts = defaultdict(lambda: [0,0])
    for idx, row in data.iterrows():
        for word in row["Message"]:
            counts[word][0 if  row["Class"] =='spam' else 1] +=1
    return counts

# %%
freq = counts_word(df)
freq
# Out:
# defaultdict(<function __main__.counts_word.<locals>.<lambda>()>,
#             {'roles': [2, 29],
#              '2': [509, 263],
#              'analysis': [24, 59],
#              'of': [2031, 831],
#              'need': [406, 328],
#              'business': [685, 258],
#              'currently': [97, 106],
#              'subject': [2939, 1200],
#              'i': [840, 722],
#              'am': [246, 422],
#              'in': [1732, 770],
#              'commercial': [37, 101],
#              'work': [260, 201],
#              'related': [55, 63],
#              'eott': [0, 5],
#              'me': [284, 528],
#              '6': [290, 108],
#              'a': [2102, 866],
#              'period': [39, 30],
#              'for': [1860, 915],
#              'to': [2374, 1029],
#              'months': [117, 78],
#              'analysts': [10, 36],
#              'taking': [61, 44],
#              'had': [176, 170],
#              'energy': [41, 98],
#              'allow': [44, 42],
#              'stay': [31, 28],
#              'arrangements': [2, 21],
#              'thanks': [125, 417],
#              'someone': [42, 55],
#              'working': [123, 147],
#              'there': [288, 256],
#              'managing': [34, 51],
#              'my': [311, 257],
#              'together': [56, 84],
#              'changes': [132, 119],
#              'you': [2050, 848],
#              'as': [669, 624],
#              'mason': [1, 22],
#              'prepared': [9, 28],
#              'being': [181, 130],
#              'signed': [26, 28],
#              'due': [153, 113],
#              'is': [1814, 745],
#              'required': [90, 66],
#              'it': [1218, 486],
#              'david': [21, 131],
#              'desk': [18, 62],
#              'plan': [57, 110],
#              'financial': [125, 84],
#              'relevant': [18, 13],
#              'frusco': [0, 2],
#              'upon': [113, 77],
#              'all': [912, 430],
#              'week': [178, 234],
#              'dealer': [29, 2],
#              'needs': [87, 102],
#              'or': [923, 417],
#              'be': [1217, 674],
#              'signatories': [0, 2],
#              'director': [109, 56],
#              'quilkey': [0, 4],
#              'end': [174, 121],
#              'no': [735, 150],
#              'meantime': [1, 11],
#              'here': [944, 179],
#              'sally': [4, 452],
#              'want': [454, 144],
#              'are': [1247, 655],
#              'enron': [0, 612],
#              'confirmation': [23, 32],
#              'ensure': [65, 95],
#              'move': [97, 57],
#              'please': [631, 689],
#              'fact': [109, 45],
#              'clients': [59, 14],
#              'over': [577, 168],
#              'new': [542, 264],
#              'therefore': [64, 69],
#              'individual': [41, 57],
#              'structure': [57, 46],
#              'procedure': [5, 9],
#              'list': [262, 180],
#              'senior': [33, 40],
#              'means': [144, 20],
#              'discussed': [9, 117],
#              'have': [1329, 749],
#              'australia': [24, 17],
#              'until': [96, 110],
#              'sydney': [1, 8],
#              'chief': [24, 17],
#              'her': [193, 82],
#              'settlement': [4, 23],
#              'not': [1247, 416],
#              'good': [381, 108],
#              'its': [421, 50],
#              'our': [1207, 382],
#              'heidi': [0, 30],
#              'clearly': [11, 19],
#              'finance': [46, 35],
#              'see': [516, 169],
#              'minns': [0, 2],
#              'that': [1118, 621],
#              'unavailable': [9, 8],
#              'time': [609, 321],
#              'advise': [9, 25],
#              'will': [918, 652],
#              'directory': [26, 6],
#              'planning': [27, 57],
#              'transfer': [150, 33],
#              're': [180, 285],
#              'order': [413, 86],
#              'and': [2020, 954],
#              'when': [323, 183],
#              'paul': [16, 49],
#              'invoicing': [0, 7],
#              'legal': [110, 57],
#              'stage': [25, 10],
#              'pty': [0, 2],
#              'lunch': [2, 33],
#              'they': [260, 224],
#              'event': [21, 41],
#              'do': [887, 269],
#              'timing': [23, 28],
#              'occur': [58, 17],
#              'quickly': [65, 26],
#              'met': [13, 48],
#              'raised': [9, 19],
#              'take': [307, 123],
#              'like': [560, 253],
#              'happy': [66, 47],
#              'sue': [5, 8],
#              'this': [1186, 761],
#              'ltd': [34, 9],
#              'issue': [54, 85],
#              'accessible': [9, 5],
#              'on': [1036, 800],
#              'held': [48, 43],
#              'office': [88, 213],
#              'responsibility': [21, 50],
#              'at': [896, 491],
#              'audit': [4, 35],
#              'faxed': [1, 10],
#              'coming': [50, 33],
#              'distribute': [38, 15],
#              'but': [550, 282],
#              'enact': [0, 2],
#              'procedures': [8, 36],
#              'action': [91, 54],
#              'counsel': [3, 16],
#              'review': [104, 232],
#              'make': [576, 153],
#              'now': [752, 156],
#              'which': [420, 257],
#              'primary': [23, 29],
#              'current': [182, 122],
#              'advised': [32, 9],
#              'piece': [7, 9],
#              'with': [1291, 622],
#              'look': [278, 82],
#              'by': [855, 546],
#              'seemed': [14, 13],
#              'entirety': [3, 3],
#              'signing': [6, 6],
#              'going': [129, 127],
#              'areas': [35, 46],
#              'from': [1100, 557],
#              'return': [130, 46],
#              'agreed': [38, 45],
#              'we': [1360, 638],
#              'briefly': [0, 11],
#              'opportunity': [132, 58],
#              'quite': [32, 31],
#              'would': [370, 366],
#              'confirmations': [1, 26],
#              'decided': [60, 26],
#              'volume': [31, 42],
#              'approval': [44, 79],
#              'could': [256, 147],
#              'implemented': [3, 20],
#              'detailed': [20, 36],
#              'houston': [9, 180],
#              'signatory': [0, 2],
#              'the': [2230, 1051],
#              'implement': [2, 17],
#              'log': [40, 11],
#              'maintained': [2, 8],
#              'change': [165, 81],
#              'both': [120, 120],
#              'was': [455, 269],
#              'still': [81, 126],
#              'independent': [76, 22],
#              'speak': [18, 24],
#              'officer': [60, 21],
#              'thank': [220, 163],
#              'such': [197, 76],
#              'key': [88, 71],
#              'comprehensive': [15, 11],
#              'authorised': [0, 12],
#              'taken': [39, 44],
#              'what': [458, 227],
#              'revised': [1, 49],
#              'let': [108, 326],
#              'understand': [64, 67],
#              'if': [749, 576],
#              'else': [33, 43],
#              'shankman': [0, 24],
#              'explain': [10, 19],
#              'provide': [264, 139],
#              'jeff': [2, 104],
#              'know': [403, 382],
#              'can': [728, 392],
#              'files': [29, 23],
#              'entex': [0, 5],
#              'help': [294, 175],
#              'anything': [69, 60],
#              'attached': [47, 238],
#              'them': [185, 165],
#              'about': [544, 206],
#              'way': [514, 83],
#              'addressed': [4, 20],
#              'been': [444, 295],
#              'ebs': [0, 37],
#              'anyone': [66, 53],
#              'dpr': [0, 68],
#              'just': [718, 202],
#              'ted': [2, 99],
#              'recommend': [12, 14],
#              'john': [32, 124],
#              '08': [32, 126],
#              'pissanetzky': [0, 2],
#              'davies': [1, 15],
#              'certain': [95, 43],
#              'many': [292, 82],
#              'today': [250, 151],
#              'forgotten': [2, 2],
#              'kevin': [3, 59],
#              'doorstep': [1, 71],
#              'doesn': [35, 20],
#              'effects': [85, 5],
#              '30': [232, 176],
#              'day': [326, 174],
#              'th': [129, 135],
#              'rapidly': [13, 5],
#              'anyway': [1, 6],
#              'who': [326, 194],
#              'hou': [4, 331],
#              'ongoing': [19, 15],
#              'border': [3, 4],
#              'london': [25, 155],
#              'were': [204, 167],
#              'market': [185, 96],
#              'higher': [63, 12],
#              'tani': [0, 9],
#              'individuals': [36, 45],
#              'some': [245, 220],
#              'example': [40, 28],
#              'andrew': [8, 64],
#              'recent': [49, 48],
#              'solution': [34, 33],
#              'injury': [3, 1],
#              'eric': [0, 29],
#              'commenced': [2, 5],
#              'project': [55, 93],
#              '11': [118, 219],
#              'did': [93, 94],
#              'young': [27, 17],
#              'pablo': [0, 2],
#              'identifying': [9, 9],
#              'irritating': [0, 2],
#              'possibly': [8, 8],
#              'options': [31, 31],
#              'important': [97, 60],
#              'should': [246, 262],
#              'pay': [120, 21],
#              'findings': [4, 19],
#              'incomplete': [2, 4],
#              'likely': [16, 21],
#              'finalised': [0, 3],
#              'memory': [13, 8],
#              'january': [19, 39],
#              'us': [532, 269],
#              'everyday': [18, 6],
#              'sage': [2, 32],
#              'place': [123, 95],
#              'patterson': [0, 28],
#              'beck': [0, 259],
#              'reported': [15, 19],
#              'overall': [12, 34],
#              '1': [694, 269],
#              'late': [55, 49],
#              'gas': [36, 125],
#              'booked': [3, 10],
#              'prioritisation': [0, 8],
#              'fundamental': [0, 12],
#              'questions': [72, 283],
#              'basis': [44, 77],
#              'timelines': [0, 9],
#              'control': [90, 66],
#              'memo': [0, 76],
#              '31': [52, 73],
#              'bound': [8, 3],
#              '1998': [15, 4],
#              'usually': [13, 8],
#              'built': [27, 12],
#              'dp': [1, 9],
#              'sherriff': [0, 30],
#              'soon': [124, 99],
#              'ticking': [0, 2],
#              'lon': [5, 149],
#              'suspect': [8, 7],
#              'trades': [3, 54],
#              'risk': [127, 242],
#              'response': [83, 37],
#              'thing': [142, 32],
#              'spreadsheets': [0, 14],
#              'purpose': [33, 18],
#              'operation': [30, 12],
#              'given': [111, 87],
#              'completed': [50, 77],
#              'mike': [5, 186],
#              'dyson': [0, 72],
#              'responsible': [12, 75],
#              '12': [235, 231],
#              'form': [217, 53],
#              'revisions': [0, 9],
#              'effort': [53, 65],
#              'concentrated': [0, 2],
#              'sweeney': [0, 27],
#              'arguing': [0, 1],
#              'hypothesis': [1, 3],
#              'doorpost': [0, 1],
#              'alluded': [0, 2],
#              'worryingly': [0, 3],
#              't': [603, 189],
#              'leave': [42, 35],
#              'use': [378, 96],
#              'lewis': [4, 25],
#              'bright': [5, 2],
#              'inappropriate': [0, 2],
#              'aid': [8, 3],
#              'think': [71, 152],
#              'sections': [12, 3],
#              'mark': [23, 130],
#              'monitor': [14, 23],
#              'amazed': [6, 2],
#              'may': [467, 220],
#              '4': [372, 189],
#              'than': [323, 103],
#              'michael': [23, 117],
#              'off': [105, 110],
#              '7': [300, 96],
#              'knock': [3, 3],
#              'matter': [75, 20],
#              'virro': [0, 2],
#              'price': [274, 131],
#              'pickering': [1, 11],
#              'holes': [3, 1],
#              'expect': [68, 30],
#              'milder': [1, 1],
#              'richard': [15, 114],
#              'resulted': [7, 14],
#              'band': [5, 2],
#              'post': [47, 25],
#              'possible': [119, 111],
#              'more': [691, 198],
#              'history': [61, 9],
#              'changing': [13, 20],
#              '17': [90, 99],
#              'rebecca': [3, 21],
#              'set': [106, 115],
#              'get': [626, 240],
#              'last': [170, 149],
#              'jordan': [5, 110],
#              'moment': [36, 11],
#              'steps': [43, 37],
#              'people': [298, 147],
#              'stabilise': [0, 1],
#              'point': [58, 79],
#              'between': [67, 82],
#              'widespread': [2, 1],
#              'most': [235, 99],
#              'uk': [128, 29],
#              'heads': [2, 31],
#              'an': [691, 347],
#              'fernley': [0, 83],
#              'big': [98, 26],
#              'performing': [15, 9],
#              'continental': [9, 17],
#              'appears': [16, 19],
#              'ian': [3, 10],
#              'functionality': [1, 22],
#              'then': [194, 109],
#              'brown': [8, 45],
#              'notification': [101, 14],
#              'nath': [0, 11],
#              'apx': [0, 1],
#              'excel': [2, 19],
#              'm': [383, 173],
#              'listing': [19, 15],
#              'during': [79, 110],
#              'james': [10, 112],
#              'react': [0, 3],
#              'worrying': [2, 3],
#              'right': [318, 53],
#              'missed': [4, 9],
#              'analyse': [0, 2],
#              'corollary': [0, 1],
#              'slipped': [3, 1],
#              'comment': [1, 22],
#              'apologies': [17, 11],
#              'comments': [7, 125],
#              'drop': [18, 10],
#              'millerchip': [0, 3],
#              'proposed': [16, 32],
#              'system': [228, 129],
#              'transaction': [101, 47],
#              'astray': [0, 2],
#              'symptoms': [1, 3],
#              'identified': [64, 35],
#              'why': [103, 40],
#              'joe': [10, 60],
#              'enough': [115, 19],
#              'allowed': [23, 4],
#              'gold': [38, 14],
#              'derivative': [1, 3],
#              'play': [49, 6],
#              'firm': [20, 18],
#              'much': [198, 77],
#              'so': [369, 272],
#              'errors': [45, 22],
#              'yesterday': [5, 61],
#              'microsoft': [37, 7],
#              'operate': [35, 9],
#              'poullain': [0, 27],
#              'immersed': [0, 3],
#              'former': [27, 8],
#              'stem': [0, 2],
#              'state': [111, 19],
#              'pressure': [12, 7],
#              'contains': [99, 18],
#              'area': [82, 39],
#              'deliveries': [1, 4],
#              'issues': [20, 144],
#              'deal': [87, 107],
#              'socrates': [0, 2],
#              'nevertheless': [1, 6],
#              'stand': [151, 7],
#              'forwarded': [6, 311],
#              'capture': [19, 35],
#              'recall': [0, 12],
#              'although': [34, 39],
#              'revalued': [0, 1],
#              'accommodate': [4, 7],
#              '5': [714, 167],
#              'structured': [3, 13],
#              'manual': [13, 29],
#              'add': [65, 49],
#              'models': [5, 12],
#              'insult': [1, 1],
#              'happened': [16, 13],
#              'intended': [48, 18],
#              'month': [147, 82],
#              'exercise': [12, 12],
#              'year': [158, 135],
#              'document': [19, 61],
#              'concern': [21, 22],
#              'how': [390, 152],
#              'causes': [12, 6],
#              'simply': [169, 30],
#              'outlined': [11, 17],
#              'w': [76, 80],
#              'partly': [2, 5],
#              'these': [388, 288],
#              'explains': [2, 3],
#              'murphy': [0, 71],
#              '09': [37, 155],
#              'version': [198, 46],
#              'apply': [45, 6],
#              'seen': [50, 29],
#              'value': [99, 60],
#              'has': [527, 340],
#              'tim': [7, 50],
#              'final': [59, 75],
#              'go': [285, 126],
#              'first': [212, 127],
#              'especially': [32, 20],
#              'develop': [48, 35],
#              'matrix': [11, 11],
#              'those': [164, 77],
#              'appropriately': [2, 5],
#              'exhaustive': [0, 6],
#              'assignments': [0, 22],
#              'commodity': [5, 93],
#              'items': [101, 55],
#              'completion': [8, 26],
#              'rather': [18, 41],
#              'applied': [8, 13],
#              'arrive': [6, 15],
#              'consists': [13, 5],
#              'largest': [43, 12],
#              'controls': [3, 52],
#              'any': [648, 470],
#              'r': [319, 75],
#              'justify': [1, 5],
#              'steve': [13, 100],
#              'viewed': [1, 7],
#              '2000': [38, 374],
#              'limits': [4, 28],
#              'surely': [5, 3],
#              'polish': [0, 1],
#              'summary': [2, 87],
#              'out': [584, 239],
#              'repeat': [12, 5],
#              'part': [181, 77],
#              'rac': [50, 59],
#              'gail': [0, 13],
#              'single': [30, 12],
#              'corp': [29, 241],
#              'because': [243, 111],
#              'position': [113, 91],
#              'institution': [5, 3],
#              'sponsors': [7, 5],
#              'nuances': [0, 2],
#              'seems': [13, 28],
#              'port': [6, 32],
#              'points': [11, 33],
#              'ask': [90, 43],
#              'witnessed': [1, 1],
#              'treatment': [18, 6],
#              '10': [461, 212],
#              'result': [144, 48],
#              'lack': [24, 11],
#              'spent': [112, 11],
#              'made': [335, 123],
#              'cornfield': [0, 47],
#              'too': [166, 44],
#              'become': [144, 33],
#              'reviews': [23, 28],
#              'communicate': [9, 27],
#              'tool': [23, 10],
#              'power': [80, 104],
#              'processes': [18, 66],
#              'hill': [14, 14],
#              'ect': [3, 385],
#              '3': [625, 251],
#              'answering': [1, 2],
#              'incompleteness': [0, 1],
#              'brent': [0, 130],
#              'turmoil': [3, 1],
#              'exchange': [89, 23],
#              'counterpart': [0, 2],
#              'relatively': [10, 12],
#              '05': [60, 111],
#              'sloman': [0, 9],
#              'cc': [3, 418],
#              'based': [162, 89],
#              'amsterdam': [8, 2],
#              'loss': [44, 22],
#              'process': [102, 241],
#              'projects': [85, 36],
#              'below': [273, 159],
#              'following': [271, 217],
#              'lay': [8, 12],
#              'e': [612, 232],
#              'employees': [21, 71],
#              'website': [446, 20],
#              'regarding': [58, 146],
#              'jeffrey': [2, 50],
#              'sutton': [0, 25],
#              'america': [68, 103],
#              'hannon': [0, 2],
#              'chris': [4, 55],
#              'joseph': [7, 31],
#              '50': [271, 41],
#              'skilling': [0, 24],
#              'cliff': [1, 5],
#              'bradford': [0, 14],
#              'kenneth': [4, 13],
#              'wanda': [0, 24],
#              'pm': [40, 342],
#              '00': [212, 229],
#              'north': [51, 101],
#              'executives': [19, 4],
#              'valdez': [0, 4],
#              'taylor': [4, 27],
#              'greg': [3, 65],
#              'opinion': [44, 11],
#              'vince': [1, 9],
#              'causey': [1, 66],
#              'well': [160, 185],
#              'veronica': [1, 11],
#              'fallon': [1, 2],
#              'message': [488, 134],
#              'j': [123, 64],
#              'communications': [23, 40],
#              'buy': [234, 57],
#              's': [885, 507],
#              'perez': [4, 22],
#              'abel': [0, 23],
#              'baxter': [1, 30],
#              'access': [145, 108],
#              'eugenio': [0, 42],
#              'changed': [29, 35],
#              'thoughts': [9, 47],
#              'delete': [38, 7],
#              'jim': [5, 41],
#              '9': [156, 114],
#              'liz': [1, 4],
#              'lavorato': [0, 35],
#              'your': [1984, 475],
#              'moscoso': [0, 41],
#              'reports': [35, 89],
#              'rick': [2, 88],
#              'executive': [14, 46],
#              '34': [34, 35],
#              'curry': [2, 22],
#              'whalley': [0, 17],
#              'william': [4, 22],
#              '02': [31, 105],
#              'haedicke': [0, 12],
#              'kaminski': [0, 6],
#              'posted': [5, 38],
#              'performance': [114, 68],
#              'requests': [18, 28],
#              'supervisor': [2, 36],
#              'company': [461, 88],
#              'selected': [57, 26],
#              'sbeck': [0, 2],
#              'operating': [57, 37],
#              'participate': [33, 37],
#              '6724': [0, 4],
#              'reference': [68, 28],
#              'com': [920, 168],
#              'perfmgmt': [0, 11],
#              'critical': [14, 46],
#              'employee': [11, 39],
#              'success': [230, 51],
#              'mail': [540, 124],
#              '19': [162, 98],
#              'begin': [44, 43],
#              'campos': [1, 1],
#              'reviewer': [1, 12],
#              '44': [36, 38],
#              'skinner': [0, 10],
#              'input': [10, 47],
#              '974': [0, 4],
#              'immediately': [118, 41],
#              'providing': [54, 43],
#              'name': [236, 114],
#              'quick': [68, 39],
#              'appear': [10, 18],
#              'l': [262, 93],
#              'accessing': [1, 6],
#              'norma': [0, 13],
#              '15': [156, 137],
#              '207': [6, 10],
#              'open': [59, 51],
#              'europe': [39, 74],
#              'participation': [15, 47],
#              '03': [52, 121],
#              'guide': [32, 10],
#              '403': [3, 4],
#              'online': [428, 20],
#              'specific': [70, 66],
#              'anthony': [10, 8],
#              'button': [40, 14],
#              'each': [125, 199],
#              'feedback': [12, 83],
#              'pep': [0, 30],
#              'very': [316, 120],
#              'u': [224, 24],
#              'kimberly': [1, 8],
#              'submit': [116, 22],
#              'villarreal': [0, 14],
#              '4040': [0, 10],
#              '783': [0, 12],
#              'select': [32, 31],
#              'option': [16, 42],
#              'goals': [64, 21],
#              '18': [77, 97],
#              '853': [1, 66],
#              'listed': [115, 82],
#              'only': [546, 151],
#              'meaningful': [1, 19],
#              'cumulative': [2, 13],
#              'canada': [58, 40],
#              '4777': [0, 12],
#              '713': [1, 102],
#              'plays': [10, 10],
#              'status': [56, 81],
#              'call': [109, 236],
#              'mid': [22, 74],
#              'numbers': [79, 53],
#              'group': [118, 207],
#              'receive': [294, 49],
#              'forms': [23, 17],
#              'cindy': [1, 49],
#              'constance': [0, 3],
#              'longer': [77, 27],
#              'management': [165, 195],
#              'noted': [14, 23],
#              'once': [150, 69],
#              'jun': [17, 8],
#              '54': [14, 28],
#              'described': [11, 15],
#              'note': [106, 119],
#              'melodick': [0, 6],
#              'date': [174, 208],
#              'role': [9, 53],
#              'completing': [10, 20],
#              'ees': [0, 64],
#              '07': [42, 104],
#              'requirement': [4, 14],
#              'contingency': [1, 3],
#              'june': [91, 58],
#              'close': [53, 54],
#              'believe': [141, 86],
#              'net': [301, 53],
#              'development': [89, 111],
#              'test': [25, 21],
#              'fit': [70, 24],
#              'unify': [0, 29],
#              'include': [145, 72],
#              'coordination': [2, 14],
#              'news': [195, 18],
#              'sift': [0, 3],
#              'sap': [2, 59],
#              'meeting': [19, 246],
#              'automated': [21, 9],
#              'scheduled': [8, 70],
#              'check': [205, 37],
#              'resolutions': [0, 1],
#              'difficult': [19, 25],
#              'hopefully': [1, 22],
#              'interface': [6, 21],
#              'above': [161, 63],
#              'mtg': [1, 5],
#              'financials': [1, 6],
#              'testing': [17, 36],
#              'their': [376, 197],
#              'request': [99, 107],
#              'per': [208, 92],
#              'shelly': [0, 22],
#              'x': [218, 113],
#              'jones': [25, 26],
#              'summer': [22, 25],
#              'information': [597, 250],
#              '35850': [0, 1],
#              'stewart': [8, 5],
#              'mcloughlin': [0, 36],
#              'toni': [1, 5],
#              'michelle': [2, 25],
#              'pharr': [0, 1],
#              'rc': [12, 10],
#              'robbin': [0, 1],
#              'hector': [0, 40],
#              'janice': [1, 1],
#              'badge': [2, 4],
#              'henenberg': [0, 10],
#              'jennings': [1, 1],
#              'sr': [2, 12],
#              'graham': [2, 8],
#              'nedre': [0, 1],
#              'joll': [0, 1],
#              'gretchen': [0, 2],
#              'doh': [0, 4],
#              'dempsey': [0, 1],
#              'shona': [0, 131],
#              'mary': [21, 110],
#              'report': [157, 183],
#              'davis': [3, 22],
#              '22': [76, 80],
#              'lerea': [0, 1],
#              'robin': [0, 3],
#              '39995': [0, 3],
#              'linda': [4, 14],
#              'solis': [0, 3],
#              'h': [65, 33],
#              'chance': [69, 27],
#              'monday': [22, 124],
#              'co': [101, 40],
#              'tumey': [0, 1],
#              'skarness': [0, 1],
#              'hargrave': [0, 1],
#              'wilson': [5, 80],
#              'pamela': [1, 9],
#              'riedel': [0, 1],
#              'chavira': [0, 1],
#              'gibson': [0, 3],
#              'title': [22, 10],
#              '52': [27, 31],
#              'george': [12, 22],
#              'sheila': [0, 76],
#              'hire': [0, 11],
#              'strambler': [0, 1],
#              'dan': [10, 15],
#              'parra': [0, 13],
#              'jennifer': [6, 36],
#              'dalton': [0, 3],
#              '00834': [0, 1],
#              'solmonson': [0, 61],
#              'smith': [12, 45],
#              'd': [240, 135],
#              'ann': [6, 7],
#              'hr': [3, 42],
#              'teresa': [1, 8],
#              'orientation': [0, 11],
#              'bryce': [2, 23],
#              '000': [345, 39],
#              'felicia': [0, 1],
#              '02631': [0, 1],
#              'continue': [100, 94],
#              'kyle': [0, 4],
#              'k': [78, 39],
#              'resources': [61, 109],
#              '00720': [0, 1],
#              'human': [33, 34],
#              'vargo': [0, 1],
#              'sarah': [3, 14],
#              'susan': [5, 33],
#              'burns': [4, 1],
#              'sprock': [0, 3],
#              'bien': [1, 1],
#              'carmen': [1, 2],
#              'n': [118, 19],
#              'yes': [65, 11],
#              '00813': [0, 1],
#              'specialist': [11, 12],
#              'lee': [5, 19],
#              'walton': [0, 12],
#              '413': [0, 3],
#              '02372': [0, 1],
#              'allison': [1, 1],
#              'weekly': [30, 49],
#              'angela': [2, 8],
#              'rep': [5, 15],
#              'peikert': [0, 1],
#              'lessner': [0, 1],
#              'robert': [15, 63],
#              'schnauber': [0, 1],
#              'fgt': [0, 5],
#              'merlyn': [0, 1],
#              'olson': [4, 13],
#              'knudsen': [0, 5],
#              'poston': [0, 1],
#              'grimes': [0, 1],
#              'jackson': [5, 40],
#              'wysatta': [0, 1],
#              'padron': [0, 3],
#              'oxley': [0, 17],
#              'training': [34, 32],
#              'b': [161, 64],
#              'janie': [1, 4],
#              'gpgfin': [0, 13],
#              'everyone': [53, 72],
#              'schafer': [1, 3],
#              'bobby': [0, 1],
#              'brad': [2, 17],
#              'colwell': [0, 26],
#              '53': [11, 20],
#              'c': [121, 99],
#              'dave': [2, 49],
#              '100': [245, 22],
#              '78': [7, 3],
#              'participated': [2, 8],
#              'jeannie': [0, 1],
#              '04': [21, 107],
#              'chor': [0, 1],
#              'barrow': [0, 2],
#              'jandrell': [0, 1],
#              'mahendra': [0, 1],
#              'stubblefield': [0, 10],
#              'grest': [0, 1],
#              'williams': [13, 15],
#              'details': [153, 87],
#              'lisa': [6, 33],
#              'lim': [4, 9],
#              'keith': [4, 13],
#              'patrick': [3, 23],
#              '94': [8, 2],
#              'castleman': [0, 3],
#              'drew': [29, 7],
#              'daler': [0, 1],
#              'selzer': [0, 3],
#              'bonnard': [0, 3],
#              'dashboard': [0, 1],
#              'apollo': [0, 47],
#              'gilchrist': [0, 3],
#              'coleman': [0, 7],
#              'denise': [1, 4],
#              '40': [69, 42],
#              '16': [75, 106],
#              'jill': [0, 7],
#              'melissa': [0, 32],
#              'brian': [6, 58],
#              'et': [28, 8],
#              'perkins': [0, 15],
#              'morrow': [0, 4],
#              'greek': [0, 2],
#              '68': [12, 2],
#              'dell': [1, 4],
#              'morton': [0, 1],
#              'scott': [14, 95],
#              '83': [17, 3],
#              'franz': [5, 2],
#              'gpg': [0, 6],
#              'butts': [0, 3],
#              'cynthia': [0, 16],
#              'units': [4, 35],
#              'joyce': [5, 15],
#              'lorna': [0, 1],
#              'rice': [3, 6],
#              'stubbs': [0, 5],
#              'fink': [0, 1],
#              'ellen': [0, 6],
#              'yates': [0, 2],
#              'o': [205, 21],
#              'willie': [0, 5],
#              'andrea': [1, 31],
#              'bob': [4, 115],
#              'debbie': [1, 26],
#              'kumar': [0, 1],
#              'beth': [0, 89],
#              'attendance': [4, 17],
#              'encouraging': [5, 3],
#              'classes': [2, 10],
#              'goh': [0, 1],
#              'erwin': [0, 8],
#              'miguel': [2, 6],
#              'sommers': [0, 3],
#              'carol': [1, 18],
#              '76': [7, 3],
#              'turn': [49, 13],
#              'sparger': [0, 2],
#              'amabile': [0, 1],
#              'gco': [0, 2],
#              'bennett': [0, 5],
#              'nikkel': [0, 1],
#              'ranendra': [0, 2],
#              'rod': [2, 7],
#              'howard': [6, 19],
#              'kathryn': [0, 12],
#              '64': [26, 4],
#              'becker': [0, 4],
#              'charlene': [0, 20],
#              'attachment': [7, 22],
#              'traylor': [0, 1],
#              'hayslett': [0, 3],
#              'ervin': [0, 1],
#              'ena': [0, 97],
#              'howes': [0, 3],
#              '39': [104, 29],
#              'cagney': [0, 2],
#              'fance': [0, 1],
#              'cassandra': [0, 29],
#              'kathy': [1, 9],
#              'lawrence': [2, 3],
#              'biren': [0, 1],
#              'sengupta': [1, 3],
#              'todd': [2, 45],
#              'sherry': [0, 4],
#              'statistics': [7, 6],
#              'hughes': [2, 9],
#              'ray': [4, 9],
#              'schultz': [3, 24],
#              'chatham': [0, 3],
#              'projected': [9, 9],
#              'attend': [11, 70],
#              'yowman': [0, 5],
#              'wes': [0, 33],
#              'sullivan': [0, 8],
#              'donnis': [0, 1],
#              '32': [24, 29],
#              'petruszka': [0, 4],
#              'gerry': [0, 5],
#              'kokas': [0, 4],
#              'harman': [0, 2],
#              'ellis': [0, 2],
#              'ots': [0, 3],
#              'eckels': [0, 1],
#              'wade': [0, 11],
#              'mclean': [0, 3],
#              '91': [15, 3],
#              'lynch': [3, 3],
#              'marlow': [0, 3],
#              'ron': [1, 9],
#              'attended': [5, 7],
#              '21': [130, 76],
#              'kent': [0, 4],
#              'margaret': [2, 2],
#              'diane': [5, 11],
#              '8': [403, 125],
#              'coombe': [0, 1],
#              'sa': [33, 15],
#              'woods': [2, 3],
#              'addendum': [0, 1],
#              'angelique': [0, 1],
#              'guy': [8, 17],
#              ...})

# %% [markdown]
# Сохраним в переменные общее число сообщений класса spam и ham :

# %%
all_spam = df['Class'].loc[df['Class'] == 'spam'].count()
all_ham = df['Class'].loc[df['Class'] == 'ham'].count()

all_spam, all_ham
# Out:
# (np.int64(2939), np.int64(1200))

# %% [markdown]
# Сохраним в переменные Априорные вероятности \\(P(спам)\\) \\(P(не \space спам)\\) :

# %%
p_spam = all_spam / (all_spam + all_ham)
p_ham = all_ham / (all_spam + all_ham)

p_spam, p_ham
# Out:
# (np.float64(0.7100748973181928), np.float64(0.2899251026818072))

# %% [markdown]
# Для каждого слова найдем вероятность встретить его в каждом из классов сообщений spam, hum :
# ***(Найдем \\(P(слово|не\spaceспам)\\) и \\(P(слово|спам)\\))*** Используя сглаживание Лапласса.

# %%
words_prob = {}
for word, counts in freq.items():
    spam_count, ham_count = counts
    prob_word_in_spam = (spam_count ) / (all_spam)
    prob__word_in_ham = (ham_count ) / (all_ham )
    words_prob[word] = (prob_word_in_spam, prob__word_in_ham)

# %%
words_prob
# Out:
# {'roles': (np.float64(0.0006805035726437564),
#   np.float64(0.024166666666666666)),
#  '2': (np.float64(0.173188159237836), np.float64(0.21916666666666668)),
#  'analysis': (np.float64(0.008166042871725076),
#   np.float64(0.049166666666666664)),
#  'of': (np.float64(0.6910513780197346), np.float64(0.6925)),
#  'need': (np.float64(0.13814222524668254), np.float64(0.2733333333333333)),
#  'business': (np.float64(0.23307247363048655), np.float64(0.215)),
#  'currently': (np.float64(0.033004423273222186),
#   np.float64(0.08833333333333333)),
#  'subject': (np.float64(1.0), np.float64(1.0)),
#  'i': (np.float64(0.2858115005103777), np.float64(0.6016666666666667)),
#  'am': (np.float64(0.08370193943518203), np.float64(0.3516666666666667)),
#  'in': (np.float64(0.589316093909493), np.float64(0.6416666666666667)),
#  'commercial': (np.float64(0.012589316093909493),
#   np.float64(0.08416666666666667)),
#  'work': (np.float64(0.08846546444368833), np.float64(0.1675)),
#  'related': (np.float64(0.0187138482477033), np.float64(0.0525)),
#  'eott': (np.float64(0.0), np.float64(0.004166666666666667)),
#  'me': (np.float64(0.09663150731541341), np.float64(0.44)),
#  '6': (np.float64(0.09867301803334468), np.float64(0.09)),
#  'a': (np.float64(0.715209254848588), np.float64(0.7216666666666667)),
#  'period': (np.float64(0.013269819666553249), np.float64(0.025)),
#  'for': (np.float64(0.6328683225586934), np.float64(0.7625)),
#  'to': (np.float64(0.8077577407281388), np.float64(0.8575)),
#  'months': (np.float64(0.03980945899965975), np.float64(0.065)),
#  'analysts': (np.float64(0.003402517863218782), np.float64(0.03)),
#  'taking': (np.float64(0.02075535896563457), np.float64(0.03666666666666667)),
#  'had': (np.float64(0.05988431439265056), np.float64(0.14166666666666666)),
#  'energy': (np.float64(0.013950323239197007), np.float64(0.08166666666666667)),
#  'allow': (np.float64(0.01497107859816264), np.float64(0.035)),
#  'stay': (np.float64(0.010547805375978225), np.float64(0.023333333333333334)),
#  'arrangements': (np.float64(0.0006805035726437564), np.float64(0.0175)),
#  'thanks': (np.float64(0.042531473290234774), np.float64(0.3475)),
#  'someone': (np.float64(0.014290575025518884),
#   np.float64(0.04583333333333333)),
#  'working': (np.float64(0.041850969717591016), np.float64(0.1225)),
#  'there': (np.float64(0.09799251446070092), np.float64(0.21333333333333335)),
#  'managing': (np.float64(0.011568560734943858), np.float64(0.0425)),
#  'my': (np.float64(0.10581830554610412), np.float64(0.21416666666666667)),
#  'together': (np.float64(0.01905410003402518), np.float64(0.07)),
#  'changes': (np.float64(0.04491323579448792), np.float64(0.09916666666666667)),
#  'you': (np.float64(0.6975161619598503), np.float64(0.7066666666666667)),
#  'as': (np.float64(0.22762844504933652), np.float64(0.52)),
#  'mason': (np.float64(0.0003402517863218782),
#   np.float64(0.018333333333333333)),
#  'prepared': (np.float64(0.003062266076896904),
#   np.float64(0.023333333333333334)),
#  'being': (np.float64(0.06158557332425995), np.float64(0.10833333333333334)),
#  'signed': (np.float64(0.008846546444368834),
#   np.float64(0.023333333333333334)),
#  'due': (np.float64(0.05205852330724736), np.float64(0.09416666666666666)),
#  'is': (np.float64(0.617216740387887), np.float64(0.6208333333333333)),
#  'required': (np.float64(0.030622660768969037), np.float64(0.055)),
#  'it': (np.float64(0.41442667574004766), np.float64(0.405)),
#  'david': (np.float64(0.007145287512759442), np.float64(0.10916666666666666)),
#  'desk': (np.float64(0.006124532153793808), np.float64(0.051666666666666666)),
#  'plan': (np.float64(0.01939435182034706), np.float64(0.09166666666666666)),
#  'financial': (np.float64(0.042531473290234774), np.float64(0.07)),
#  'relevant': (np.float64(0.006124532153793808),
#   np.float64(0.010833333333333334)),
#  'frusco': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'upon': (np.float64(0.038448451854372234), np.float64(0.06416666666666666)),
#  'all': (np.float64(0.31030962912555293), np.float64(0.35833333333333334)),
#  'week': (np.float64(0.06056481796529432), np.float64(0.195)),
#  'dealer': (np.float64(0.009867301803334467),
#   np.float64(0.0016666666666666668)),
#  'needs': (np.float64(0.029601905410003404), np.float64(0.085)),
#  'or': (np.float64(0.31405239877509356), np.float64(0.3475)),
#  'be': (np.float64(0.41408642395372575), np.float64(0.5616666666666666)),
#  'signatories': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'director': (np.float64(0.037087444709084726),
#   np.float64(0.04666666666666667)),
#  'quilkey': (np.float64(0.0), np.float64(0.0033333333333333335)),
#  'end': (np.float64(0.05920381082000681), np.float64(0.10083333333333333)),
#  'no': (np.float64(0.25008506294658045), np.float64(0.125)),
#  'meantime': (np.float64(0.0003402517863218782),
#   np.float64(0.009166666666666667)),
#  'here': (np.float64(0.321197686287853), np.float64(0.14916666666666667)),
#  'sally': (np.float64(0.0013610071452875127), np.float64(0.37666666666666665)),
#  'want': (np.float64(0.1544743109901327), np.float64(0.12)),
#  'are': (np.float64(0.4242939775433821), np.float64(0.5458333333333333)),
#  'enron': (np.float64(0.0), np.float64(0.51)),
#  'confirmation': (np.float64(0.007825791085403199),
#   np.float64(0.02666666666666667)),
#  'ensure': (np.float64(0.022116366110922082), np.float64(0.07916666666666666)),
#  'move': (np.float64(0.033004423273222186), np.float64(0.0475)),
#  'please': (np.float64(0.21469887716910513), np.float64(0.5741666666666667)),
#  'fact': (np.float64(0.037087444709084726), np.float64(0.0375)),
#  'clients': (np.float64(0.020074855392990813),
#   np.float64(0.011666666666666667)),
#  'over': (np.float64(0.1963252807077237), np.float64(0.14)),
#  'new': (np.float64(0.184416468186458), np.float64(0.22)),
#  'therefore': (np.float64(0.021776114324600204), np.float64(0.0575)),
#  'individual': (np.float64(0.013950323239197007), np.float64(0.0475)),
#  'structure': (np.float64(0.01939435182034706),
#   np.float64(0.03833333333333333)),
#  'procedure': (np.float64(0.001701258931609391), np.float64(0.0075)),
#  'list': (np.float64(0.08914596801633208), np.float64(0.15)),
#  'senior': (np.float64(0.01122830894862198), np.float64(0.03333333333333333)),
#  'means': (np.float64(0.04899625723035046), np.float64(0.016666666666666666)),
#  'discussed': (np.float64(0.003062266076896904), np.float64(0.0975)),
#  'have': (np.float64(0.4521946240217761), np.float64(0.6241666666666666)),
#  'australia': (np.float64(0.008166042871725076),
#   np.float64(0.014166666666666666)),
#  'until': (np.float64(0.032664171486900304), np.float64(0.09166666666666666)),
#  'sydney': (np.float64(0.0003402517863218782),
#   np.float64(0.006666666666666667)),
#  'chief': (np.float64(0.008166042871725076), np.float64(0.014166666666666666)),
#  'her': (np.float64(0.06566859476012249), np.float64(0.06833333333333333)),
#  'settlement': (np.float64(0.0013610071452875127),
#   np.float64(0.019166666666666665)),
#  'not': (np.float64(0.4242939775433821), np.float64(0.3466666666666667)),
#  'good': (np.float64(0.1296359305886356), np.float64(0.09)),
#  'its': (np.float64(0.14324600204151072), np.float64(0.041666666666666664)),
#  'our': (np.float64(0.410683906090507), np.float64(0.31833333333333336)),
#  'heidi': (np.float64(0.0), np.float64(0.025)),
#  'clearly': (np.float64(0.00374276964954066),
#   np.float64(0.015833333333333335)),
#  'finance': (np.float64(0.015651582170806397),
#   np.float64(0.029166666666666667)),
#  'see': (np.float64(0.17556992174208916), np.float64(0.14083333333333334)),
#  'minns': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'that': (np.float64(0.3804014971078598), np.float64(0.5175)),
#  'unavailable': (np.float64(0.003062266076896904),
#   np.float64(0.006666666666666667)),
#  'time': (np.float64(0.20721333787002383), np.float64(0.2675)),
#  'advise': (np.float64(0.003062266076896904),
#   np.float64(0.020833333333333332)),
#  'will': (np.float64(0.31235113984348417), np.float64(0.5433333333333333)),
#  'directory': (np.float64(0.008846546444368834), np.float64(0.005)),
#  'planning': (np.float64(0.00918679823069071), np.float64(0.0475)),
#  'transfer': (np.float64(0.05103776794828173), np.float64(0.0275)),
#  're': (np.float64(0.061245321537938074), np.float64(0.2375)),
#  'order': (np.float64(0.1405239877509357), np.float64(0.07166666666666667)),
#  'and': (np.float64(0.6873086083701939), np.float64(0.795)),
#  'when': (np.float64(0.10990132698196665), np.float64(0.1525)),
#  'paul': (np.float64(0.005444028581150051), np.float64(0.04083333333333333)),
#  'invoicing': (np.float64(0.0), np.float64(0.005833333333333334)),
#  'legal': (np.float64(0.0374276964954066), np.float64(0.0475)),
#  'stage': (np.float64(0.008506294658046955), np.float64(0.008333333333333333)),
#  'pty': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'lunch': (np.float64(0.0006805035726437564), np.float64(0.0275)),
#  'they': (np.float64(0.08846546444368833), np.float64(0.18666666666666668)),
#  'event': (np.float64(0.007145287512759442), np.float64(0.034166666666666665)),
#  'do': (np.float64(0.30180333446750596), np.float64(0.22416666666666665)),
#  'timing': (np.float64(0.007825791085403199),
#   np.float64(0.023333333333333334)),
#  'occur': (np.float64(0.019734603606668934), np.float64(0.014166666666666666)),
#  'quickly': (np.float64(0.022116366110922082),
#   np.float64(0.021666666666666667)),
#  'met': (np.float64(0.004423273222184417), np.float64(0.04)),
#  'raised': (np.float64(0.003062266076896904),
#   np.float64(0.015833333333333335)),
#  'take': (np.float64(0.1044572984008166), np.float64(0.1025)),
#  'like': (np.float64(0.1905410003402518), np.float64(0.21083333333333334)),
#  'happy': (np.float64(0.02245661789724396), np.float64(0.03916666666666667)),
#  'sue': (np.float64(0.001701258931609391), np.float64(0.006666666666666667)),
#  'this': (np.float64(0.40353861857774753), np.float64(0.6341666666666667)),
#  'ltd': (np.float64(0.011568560734943858), np.float64(0.0075)),
#  'issue': (np.float64(0.01837359646138142), np.float64(0.07083333333333333)),
#  'accessible': (np.float64(0.003062266076896904),
#   np.float64(0.004166666666666667)),
#  'on': (np.float64(0.3525008506294658), np.float64(0.6666666666666666)),
#  'held': (np.float64(0.016332085743450152), np.float64(0.035833333333333335)),
#  'office': (np.float64(0.02994215719632528), np.float64(0.1775)),
#  'responsibility': (np.float64(0.007145287512759442),
#   np.float64(0.041666666666666664)),
#  'at': (np.float64(0.30486560054440287), np.float64(0.4091666666666667)),
#  'audit': (np.float64(0.0013610071452875127),
#   np.float64(0.029166666666666667)),
#  'faxed': (np.float64(0.0003402517863218782),
#   np.float64(0.008333333333333333)),
#  'coming': (np.float64(0.01701258931609391), np.float64(0.0275)),
#  'distribute': (np.float64(0.012929567880231372), np.float64(0.0125)),
#  'but': (np.float64(0.187138482477033), np.float64(0.235)),
#  'enact': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'procedures': (np.float64(0.0027220142905750254), np.float64(0.03)),
#  'action': (np.float64(0.030962912555290916), np.float64(0.045)),
#  'counsel': (np.float64(0.0010207553589656345),
#   np.float64(0.013333333333333334)),
#  'review': (np.float64(0.035386185777475335), np.float64(0.19333333333333333)),
#  'make': (np.float64(0.19598502892140185), np.float64(0.1275)),
#  'now': (np.float64(0.2558693433140524), np.float64(0.13)),
#  'which': (np.float64(0.14290575025518884), np.float64(0.21416666666666667)),
#  'primary': (np.float64(0.007825791085403199),
#   np.float64(0.024166666666666666)),
#  'current': (np.float64(0.06192582511058183), np.float64(0.10166666666666667)),
#  'advised': (np.float64(0.010888057162300102), np.float64(0.0075)),
#  'piece': (np.float64(0.0023817625042531474), np.float64(0.0075)),
#  'with': (np.float64(0.43926505614154476), np.float64(0.5183333333333333)),
#  'look': (np.float64(0.09458999659748214), np.float64(0.06833333333333333)),
#  'by': (np.float64(0.29091527730520583), np.float64(0.455)),
#  'seemed': (np.float64(0.004763525008506295),
#   np.float64(0.010833333333333334)),
#  'entirety': (np.float64(0.0010207553589656345), np.float64(0.0025)),
#  'signing': (np.float64(0.002041510717931269), np.float64(0.005)),
#  'going': (np.float64(0.04389248043552229), np.float64(0.10583333333333333)),
#  'areas': (np.float64(0.011908812521265737), np.float64(0.03833333333333333)),
#  'from': (np.float64(0.374276964954066), np.float64(0.46416666666666667)),
#  'return': (np.float64(0.044232732221844165), np.float64(0.03833333333333333)),
#  'agreed': (np.float64(0.012929567880231372), np.float64(0.0375)),
#  'we': (np.float64(0.46274242939775434), np.float64(0.5316666666666666)),
#  'briefly': (np.float64(0.0), np.float64(0.009166666666666667)),
#  'opportunity': (np.float64(0.04491323579448792),
#   np.float64(0.04833333333333333)),
#  'quite': (np.float64(0.010888057162300102), np.float64(0.025833333333333333)),
#  'would': (np.float64(0.12589316093909492), np.float64(0.305)),
#  'confirmations': (np.float64(0.0003402517863218782),
#   np.float64(0.021666666666666667)),
#  'decided': (np.float64(0.02041510717931269),
#   np.float64(0.021666666666666667)),
#  'volume': (np.float64(0.010547805375978225), np.float64(0.035)),
#  'approval': (np.float64(0.01497107859816264),
#   np.float64(0.06583333333333333)),
#  'could': (np.float64(0.08710445729840081), np.float64(0.1225)),
#  'implemented': (np.float64(0.0010207553589656345),
#   np.float64(0.016666666666666666)),
#  'detailed': (np.float64(0.006805035726437564), np.float64(0.03)),
#  'houston': (np.float64(0.003062266076896904), np.float64(0.15)),
#  'signatory': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'the': (np.float64(0.7587614834977884), np.float64(0.8758333333333334)),
#  'implement': (np.float64(0.0006805035726437564),
#   np.float64(0.014166666666666666)),
#  'log': (np.float64(0.013610071452875128), np.float64(0.009166666666666667)),
#  'maintained': (np.float64(0.0006805035726437564),
#   np.float64(0.006666666666666667)),
#  'change': (np.float64(0.0561415447431099), np.float64(0.0675)),
#  'both': (np.float64(0.04083021435862538), np.float64(0.1)),
#  'was': (np.float64(0.15481456277645458), np.float64(0.22416666666666665)),
#  'still': (np.float64(0.027560394692072134), np.float64(0.105)),
#  'independent': (np.float64(0.025859135760462743),
#   np.float64(0.018333333333333333)),
#  'speak': (np.float64(0.006124532153793808), np.float64(0.02)),
#  'officer': (np.float64(0.02041510717931269), np.float64(0.0175)),
#  'thank': (np.float64(0.0748553929908132), np.float64(0.13583333333333333)),
#  'such': (np.float64(0.06702960190541), np.float64(0.06333333333333334)),
#  'key': (np.float64(0.02994215719632528), np.float64(0.059166666666666666)),
#  'comprehensive': (np.float64(0.005103776794828173),
#   np.float64(0.009166666666666667)),
#  'authorised': (np.float64(0.0), np.float64(0.01)),
#  'taken': (np.float64(0.013269819666553249), np.float64(0.03666666666666667)),
#  'what': (np.float64(0.1558353181354202), np.float64(0.18916666666666668)),
#  'revised': (np.float64(0.0003402517863218782),
#   np.float64(0.04083333333333333)),
#  'let': (np.float64(0.03674719292276284), np.float64(0.27166666666666667)),
#  'understand': (np.float64(0.021776114324600204),
#   np.float64(0.05583333333333333)),
#  'if': (np.float64(0.25484858795508675), np.float64(0.48)),
#  'else': (np.float64(0.01122830894862198), np.float64(0.035833333333333335)),
#  'shankman': (np.float64(0.0), np.float64(0.02)),
#  'explain': (np.float64(0.003402517863218782),
#   np.float64(0.015833333333333335)),
#  'provide': (np.float64(0.08982647158897585), np.float64(0.11583333333333333)),
#  'jeff': (np.float64(0.0006805035726437564), np.float64(0.08666666666666667)),
#  'know': (np.float64(0.13712146988771692), np.float64(0.31833333333333336)),
#  'can': (np.float64(0.24770330044232733), np.float64(0.32666666666666666)),
#  'files': (np.float64(0.009867301803334467), np.float64(0.019166666666666665)),
#  'entex': (np.float64(0.0), np.float64(0.004166666666666667)),
#  'help': (np.float64(0.10003402517863219), np.float64(0.14583333333333334)),
#  'anything': (np.float64(0.023477373256209595), np.float64(0.05)),
#  'attached': (np.float64(0.015991833957128276),
#   np.float64(0.19833333333333333)),
#  'them': (np.float64(0.06294658046954746), np.float64(0.1375)),
#  'about': (np.float64(0.18509697175910172), np.float64(0.17166666666666666)),
#  'way': (np.float64(0.1748894181694454), np.float64(0.06916666666666667)),
#  'addressed': (np.float64(0.0013610071452875127),
#   np.float64(0.016666666666666666)),
#  'been': (np.float64(0.1510717931269139), np.float64(0.24583333333333332)),
#  'ebs': (np.float64(0.0), np.float64(0.030833333333333334)),
#  'anyone': (np.float64(0.02245661789724396), np.float64(0.04416666666666667)),
#  'dpr': (np.float64(0.0), np.float64(0.056666666666666664)),
#  'just': (np.float64(0.24430078257910853), np.float64(0.16833333333333333)),
#  'ted': (np.float64(0.0006805035726437564), np.float64(0.0825)),
#  'recommend': (np.float64(0.004083021435862538),
#   np.float64(0.011666666666666667)),
#  'john': (np.float64(0.010888057162300102), np.float64(0.10333333333333333)),
#  '08': (np.float64(0.010888057162300102), np.float64(0.105)),
#  'pissanetzky': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'davies': (np.float64(0.0003402517863218782), np.float64(0.0125)),
#  'certain': (np.float64(0.03232391970057843),
#   np.float64(0.035833333333333335)),
#  'many': (np.float64(0.09935352160598843), np.float64(0.06833333333333333)),
#  'today': (np.float64(0.08506294658046955), np.float64(0.12583333333333332)),
#  'forgotten': (np.float64(0.0006805035726437564),
#   np.float64(0.0016666666666666668)),
#  'kevin': (np.float64(0.0010207553589656345),
#   np.float64(0.049166666666666664)),
#  'doorstep': (np.float64(0.0003402517863218782),
#   np.float64(0.059166666666666666)),
#  'doesn': (np.float64(0.011908812521265737), np.float64(0.016666666666666666)),
#  'effects': (np.float64(0.028921401837359646),
#   np.float64(0.004166666666666667)),
#  '30': (np.float64(0.07893841442667573), np.float64(0.14666666666666667)),
#  'day': (np.float64(0.11092208234093229), np.float64(0.145)),
#  'th': (np.float64(0.04389248043552229), np.float64(0.1125)),
#  'rapidly': (np.float64(0.004423273222184417),
#   np.float64(0.004166666666666667)),
#  'anyway': (np.float64(0.0003402517863218782), np.float64(0.005)),
#  'who': (np.float64(0.11092208234093229), np.float64(0.16166666666666665)),
#  'hou': (np.float64(0.0013610071452875127), np.float64(0.2758333333333333)),
#  'ongoing': (np.float64(0.006464783940115686), np.float64(0.0125)),
#  'border': (np.float64(0.0010207553589656345),
#   np.float64(0.0033333333333333335)),
#  'london': (np.float64(0.008506294658046955), np.float64(0.12916666666666668)),
#  'were': (np.float64(0.06941136440966315), np.float64(0.13916666666666666)),
#  'market': (np.float64(0.06294658046954746), np.float64(0.08)),
#  'higher': (np.float64(0.021435862538278325), np.float64(0.01)),
#  'tani': (np.float64(0.0), np.float64(0.0075)),
#  'individuals': (np.float64(0.012249064307587616), np.float64(0.0375)),
#  'some': (np.float64(0.08336168764886015), np.float64(0.18333333333333332)),
#  'example': (np.float64(0.013610071452875128),
#   np.float64(0.023333333333333334)),
#  'andrew': (np.float64(0.0027220142905750254),
#   np.float64(0.05333333333333334)),
#  'recent': (np.float64(0.01667233752977203), np.float64(0.04)),
#  'solution': (np.float64(0.011568560734943858), np.float64(0.0275)),
#  'injury': (np.float64(0.0010207553589656345),
#   np.float64(0.0008333333333333334)),
#  'eric': (np.float64(0.0), np.float64(0.024166666666666666)),
#  'commenced': (np.float64(0.0006805035726437564),
#   np.float64(0.004166666666666667)),
#  'project': (np.float64(0.0187138482477033), np.float64(0.0775)),
#  '11': (np.float64(0.040149710785981625), np.float64(0.1825)),
#  'did': (np.float64(0.03164341612793467), np.float64(0.07833333333333334)),
#  'young': (np.float64(0.00918679823069071), np.float64(0.014166666666666666)),
#  'pablo': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'identifying': (np.float64(0.003062266076896904), np.float64(0.0075)),
#  'irritating': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'possibly': (np.float64(0.0027220142905750254),
#   np.float64(0.006666666666666667)),
#  'options': (np.float64(0.010547805375978225),
#   np.float64(0.025833333333333333)),
#  'important': (np.float64(0.033004423273222186), np.float64(0.05)),
#  'should': (np.float64(0.08370193943518203), np.float64(0.21833333333333332)),
#  'pay': (np.float64(0.04083021435862538), np.float64(0.0175)),
#  'findings': (np.float64(0.0013610071452875127),
#   np.float64(0.015833333333333335)),
#  'incomplete': (np.float64(0.0006805035726437564),
#   np.float64(0.0033333333333333335)),
#  'likely': (np.float64(0.005444028581150051), np.float64(0.0175)),
#  'finalised': (np.float64(0.0), np.float64(0.0025)),
#  'memory': (np.float64(0.004423273222184417),
#   np.float64(0.006666666666666667)),
#  'january': (np.float64(0.006464783940115686), np.float64(0.0325)),
#  'us': (np.float64(0.1810139503232392), np.float64(0.22416666666666665)),
#  'everyday': (np.float64(0.006124532153793808), np.float64(0.005)),
#  'sage': (np.float64(0.0006805035726437564), np.float64(0.02666666666666667)),
#  'place': (np.float64(0.041850969717591016), np.float64(0.07916666666666666)),
#  'patterson': (np.float64(0.0), np.float64(0.023333333333333334)),
#  'beck': (np.float64(0.0), np.float64(0.21583333333333332)),
#  'reported': (np.float64(0.005103776794828173),
#   np.float64(0.015833333333333335)),
#  'overall': (np.float64(0.004083021435862538),
#   np.float64(0.028333333333333332)),
#  '1': (np.float64(0.23613473970738347), np.float64(0.22416666666666665)),
#  'late': (np.float64(0.0187138482477033), np.float64(0.04083333333333333)),
#  'gas': (np.float64(0.012249064307587616), np.float64(0.10416666666666667)),
#  'booked': (np.float64(0.0010207553589656345),
#   np.float64(0.008333333333333333)),
#  'prioritisation': (np.float64(0.0), np.float64(0.006666666666666667)),
#  'fundamental': (np.float64(0.0), np.float64(0.01)),
#  'questions': (np.float64(0.02449812861517523),
#   np.float64(0.23583333333333334)),
#  'basis': (np.float64(0.01497107859816264), np.float64(0.06416666666666666)),
#  'timelines': (np.float64(0.0), np.float64(0.0075)),
#  'control': (np.float64(0.030622660768969037), np.float64(0.055)),
#  'memo': (np.float64(0.0), np.float64(0.06333333333333334)),
#  '31': (np.float64(0.017693092888737667), np.float64(0.060833333333333336)),
#  'bound': (np.float64(0.0027220142905750254), np.float64(0.0025)),
#  '1998': (np.float64(0.005103776794828173), np.float64(0.0033333333333333335)),
#  'usually': (np.float64(0.004423273222184417),
#   np.float64(0.006666666666666667)),
#  'built': (np.float64(0.00918679823069071), np.float64(0.01)),
#  'dp': (np.float64(0.0003402517863218782), np.float64(0.0075)),
#  'sherriff': (np.float64(0.0), np.float64(0.025)),
#  'soon': (np.float64(0.0421912215039129), np.float64(0.0825)),
#  'ticking': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'lon': (np.float64(0.001701258931609391), np.float64(0.12416666666666666)),
#  'suspect': (np.float64(0.0027220142905750254),
#   np.float64(0.005833333333333334)),
#  'trades': (np.float64(0.0010207553589656345), np.float64(0.045)),
#  'risk': (np.float64(0.04321197686287853), np.float64(0.20166666666666666)),
#  'response': (np.float64(0.02824089826471589),
#   np.float64(0.030833333333333334)),
#  'thing': (np.float64(0.048315753657706705), np.float64(0.02666666666666667)),
#  'spreadsheets': (np.float64(0.0), np.float64(0.011666666666666667)),
#  'purpose': (np.float64(0.01122830894862198), np.float64(0.015)),
#  'operation': (np.float64(0.010207553589656346), np.float64(0.01)),
#  'given': (np.float64(0.037767948281728476), np.float64(0.0725)),
#  'completed': (np.float64(0.01701258931609391),
#   np.float64(0.06416666666666666)),
#  'mike': (np.float64(0.001701258931609391), np.float64(0.155)),
#  'dyson': (np.float64(0.0), np.float64(0.06)),
#  'responsible': (np.float64(0.004083021435862538), np.float64(0.0625)),
#  '12': (np.float64(0.07995916978564137), np.float64(0.1925)),
#  'form': (np.float64(0.07383463763184757), np.float64(0.04416666666666667)),
#  'revisions': (np.float64(0.0), np.float64(0.0075)),
#  'effort': (np.float64(0.018033344675059543), np.float64(0.05416666666666667)),
#  'concentrated': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'sweeney': (np.float64(0.0), np.float64(0.0225)),
#  'arguing': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'hypothesis': (np.float64(0.0003402517863218782), np.float64(0.0025)),
#  'doorpost': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'alluded': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'worryingly': (np.float64(0.0), np.float64(0.0025)),
#  't': (np.float64(0.20517182715209256), np.float64(0.1575)),
#  'leave': (np.float64(0.014290575025518884), np.float64(0.029166666666666667)),
#  'use': (np.float64(0.12861517522966995), np.float64(0.08)),
#  'lewis': (np.float64(0.0013610071452875127),
#   np.float64(0.020833333333333332)),
#  'bright': (np.float64(0.001701258931609391),
#   np.float64(0.0016666666666666668)),
#  'inappropriate': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'aid': (np.float64(0.0027220142905750254), np.float64(0.0025)),
#  'think': (np.float64(0.024157876828853352), np.float64(0.12666666666666668)),
#  'sections': (np.float64(0.004083021435862538), np.float64(0.0025)),
#  'mark': (np.float64(0.007825791085403199), np.float64(0.10833333333333334)),
#  'monitor': (np.float64(0.004763525008506295),
#   np.float64(0.019166666666666665)),
#  'amazed': (np.float64(0.002041510717931269),
#   np.float64(0.0016666666666666668)),
#  'may': (np.float64(0.15889758421231712), np.float64(0.18333333333333332)),
#  '4': (np.float64(0.12657366451173868), np.float64(0.1575)),
#  'than': (np.float64(0.10990132698196665), np.float64(0.08583333333333333)),
#  'michael': (np.float64(0.007825791085403199), np.float64(0.0975)),
#  'off': (np.float64(0.03572643756379721), np.float64(0.09166666666666666)),
#  '7': (np.float64(0.10207553589656346), np.float64(0.08)),
#  'knock': (np.float64(0.0010207553589656345), np.float64(0.0025)),
#  'matter': (np.float64(0.025518883974140864),
#   np.float64(0.016666666666666666)),
#  'virro': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'price': (np.float64(0.09322898945219463), np.float64(0.10916666666666666)),
#  'pickering': (np.float64(0.0003402517863218782),
#   np.float64(0.009166666666666667)),
#  'holes': (np.float64(0.0010207553589656345),
#   np.float64(0.0008333333333333334)),
#  'expect': (np.float64(0.023137121469887716), np.float64(0.025)),
#  'milder': (np.float64(0.0003402517863218782),
#   np.float64(0.0008333333333333334)),
#  'richard': (np.float64(0.005103776794828173), np.float64(0.095)),
#  'resulted': (np.float64(0.0023817625042531474),
#   np.float64(0.011666666666666667)),
#  'band': (np.float64(0.001701258931609391), np.float64(0.0016666666666666668)),
#  'post': (np.float64(0.015991833957128276), np.float64(0.020833333333333332)),
#  'possible': (np.float64(0.04048996257230351), np.float64(0.0925)),
#  'more': (np.float64(0.23511398434841782), np.float64(0.165)),
#  'history': (np.float64(0.02075535896563457), np.float64(0.0075)),
#  'changing': (np.float64(0.004423273222184417),
#   np.float64(0.016666666666666666)),
#  '17': (np.float64(0.030622660768969037), np.float64(0.0825)),
#  'rebecca': (np.float64(0.0010207553589656345), np.float64(0.0175)),
#  'set': (np.float64(0.036066689350119085), np.float64(0.09583333333333334)),
#  'get': (np.float64(0.21299761823749574), np.float64(0.2)),
#  'last': (np.float64(0.05784280367471929), np.float64(0.12416666666666666)),
#  'jordan': (np.float64(0.001701258931609391), np.float64(0.09166666666666666)),
#  'moment': (np.float64(0.012249064307587616),
#   np.float64(0.009166666666666667)),
#  'steps': (np.float64(0.014630826811840763), np.float64(0.030833333333333334)),
#  'people': (np.float64(0.1013950323239197), np.float64(0.1225)),
#  'stabilise': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'point': (np.float64(0.019734603606668934), np.float64(0.06583333333333333)),
#  'between': (np.float64(0.02279686968356584), np.float64(0.06833333333333333)),
#  'widespread': (np.float64(0.0006805035726437564),
#   np.float64(0.0008333333333333334)),
#  'most': (np.float64(0.07995916978564137), np.float64(0.0825)),
#  'uk': (np.float64(0.04355222864920041), np.float64(0.024166666666666666)),
#  'heads': (np.float64(0.0006805035726437564),
#   np.float64(0.025833333333333333)),
#  'an': (np.float64(0.23511398434841782), np.float64(0.2891666666666667)),
#  'fernley': (np.float64(0.0), np.float64(0.06916666666666667)),
#  'big': (np.float64(0.03334467505954406), np.float64(0.021666666666666667)),
#  'performing': (np.float64(0.005103776794828173), np.float64(0.0075)),
#  'continental': (np.float64(0.003062266076896904),
#   np.float64(0.014166666666666666)),
#  'appears': (np.float64(0.005444028581150051),
#   np.float64(0.015833333333333335)),
#  'ian': (np.float64(0.0010207553589656345), np.float64(0.008333333333333333)),
#  'functionality': (np.float64(0.0003402517863218782),
#   np.float64(0.018333333333333333)),
#  'then': (np.float64(0.06600884654644437), np.float64(0.09083333333333334)),
#  'brown': (np.float64(0.0027220142905750254), np.float64(0.0375)),
#  'notification': (np.float64(0.034365430418509695),
#   np.float64(0.011666666666666667)),
#  'nath': (np.float64(0.0), np.float64(0.009166666666666667)),
#  'apx': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'excel': (np.float64(0.0006805035726437564),
#   np.float64(0.015833333333333335)),
#  'm': (np.float64(0.13031643416127936), np.float64(0.14416666666666667)),
#  'listing': (np.float64(0.006464783940115686), np.float64(0.0125)),
#  'during': (np.float64(0.026879891119428376), np.float64(0.09166666666666666)),
#  'james': (np.float64(0.003402517863218782), np.float64(0.09333333333333334)),
#  'react': (np.float64(0.0), np.float64(0.0025)),
#  'worrying': (np.float64(0.0006805035726437564), np.float64(0.0025)),
#  'right': (np.float64(0.10820006805035727), np.float64(0.04416666666666667)),
#  'missed': (np.float64(0.0013610071452875127), np.float64(0.0075)),
#  'analyse': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'corollary': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'slipped': (np.float64(0.0010207553589656345),
#   np.float64(0.0008333333333333334)),
#  'comment': (np.float64(0.0003402517863218782),
#   np.float64(0.018333333333333333)),
#  'apologies': (np.float64(0.005784280367471929),
#   np.float64(0.009166666666666667)),
#  'comments': (np.float64(0.0023817625042531474),
#   np.float64(0.10416666666666667)),
#  'drop': (np.float64(0.006124532153793808), np.float64(0.008333333333333333)),
#  'millerchip': (np.float64(0.0), np.float64(0.0025)),
#  'proposed': (np.float64(0.005444028581150051),
#   np.float64(0.02666666666666667)),
#  'system': (np.float64(0.07757740728138823), np.float64(0.1075)),
#  'transaction': (np.float64(0.034365430418509695),
#   np.float64(0.03916666666666667)),
#  'astray': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'symptoms': (np.float64(0.0003402517863218782), np.float64(0.0025)),
#  'identified': (np.float64(0.021776114324600204),
#   np.float64(0.029166666666666667)),
#  'why': (np.float64(0.03504593399115345), np.float64(0.03333333333333333)),
#  'joe': (np.float64(0.003402517863218782), np.float64(0.05)),
#  'enough': (np.float64(0.03912895542701599), np.float64(0.015833333333333335)),
#  'allowed': (np.float64(0.007825791085403199),
#   np.float64(0.0033333333333333335)),
#  'gold': (np.float64(0.012929567880231372), np.float64(0.011666666666666667)),
#  'derivative': (np.float64(0.0003402517863218782), np.float64(0.0025)),
#  'play': (np.float64(0.01667233752977203), np.float64(0.005)),
#  'firm': (np.float64(0.006805035726437564), np.float64(0.015)),
#  'much': (np.float64(0.06736985369173189), np.float64(0.06416666666666666)),
#  'so': (np.float64(0.12555290915277306), np.float64(0.22666666666666666)),
#  'errors': (np.float64(0.015311330384484519),
#   np.float64(0.018333333333333333)),
#  'yesterday': (np.float64(0.001701258931609391),
#   np.float64(0.050833333333333335)),
#  'microsoft': (np.float64(0.012589316093909493),
#   np.float64(0.005833333333333334)),
#  'operate': (np.float64(0.011908812521265737), np.float64(0.0075)),
#  'poullain': (np.float64(0.0), np.float64(0.0225)),
#  'immersed': (np.float64(0.0), np.float64(0.0025)),
#  'former': (np.float64(0.00918679823069071), np.float64(0.006666666666666667)),
#  'stem': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'state': (np.float64(0.037767948281728476), np.float64(0.015833333333333335)),
#  'pressure': (np.float64(0.004083021435862538),
#   np.float64(0.005833333333333334)),
#  'contains': (np.float64(0.033684926845865944), np.float64(0.015)),
#  'area': (np.float64(0.027900646478394013), np.float64(0.0325)),
#  'deliveries': (np.float64(0.0003402517863218782),
#   np.float64(0.0033333333333333335)),
#  'issues': (np.float64(0.006805035726437564), np.float64(0.12)),
#  'deal': (np.float64(0.029601905410003404), np.float64(0.08916666666666667)),
#  'socrates': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'nevertheless': (np.float64(0.0003402517863218782), np.float64(0.005)),
#  'stand': (np.float64(0.051378019734603604), np.float64(0.005833333333333334)),
#  'forwarded': (np.float64(0.002041510717931269),
#   np.float64(0.25916666666666666)),
#  'capture': (np.float64(0.006464783940115686),
#   np.float64(0.029166666666666667)),
#  'recall': (np.float64(0.0), np.float64(0.01)),
#  'although': (np.float64(0.011568560734943858), np.float64(0.0325)),
#  'revalued': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'accommodate': (np.float64(0.0013610071452875127),
#   np.float64(0.005833333333333334)),
#  '5': (np.float64(0.24293977543382103), np.float64(0.13916666666666666)),
#  'structured': (np.float64(0.0010207553589656345),
#   np.float64(0.010833333333333334)),
#  'manual': (np.float64(0.004423273222184417),
#   np.float64(0.024166666666666666)),
#  'add': (np.float64(0.022116366110922082), np.float64(0.04083333333333333)),
#  'models': (np.float64(0.001701258931609391), np.float64(0.01)),
#  'insult': (np.float64(0.0003402517863218782),
#   np.float64(0.0008333333333333334)),
#  'happened': (np.float64(0.005444028581150051),
#   np.float64(0.010833333333333334)),
#  'intended': (np.float64(0.016332085743450152), np.float64(0.015)),
#  'month': (np.float64(0.050017012589316096), np.float64(0.06833333333333333)),
#  'exercise': (np.float64(0.004083021435862538), np.float64(0.01)),
#  'year': (np.float64(0.05375978223885675), np.float64(0.1125)),
#  'document': (np.float64(0.006464783940115686),
#   np.float64(0.050833333333333335)),
#  'concern': (np.float64(0.007145287512759442),
#   np.float64(0.018333333333333333)),
#  'how': (np.float64(0.13269819666553248), np.float64(0.12666666666666668)),
#  'causes': (np.float64(0.004083021435862538), np.float64(0.005)),
#  'simply': (np.float64(0.05750255188839742), np.float64(0.025)),
#  'outlined': (np.float64(0.00374276964954066),
#   np.float64(0.014166666666666666)),
#  'w': (np.float64(0.025859135760462743), np.float64(0.06666666666666667)),
#  'partly': (np.float64(0.0006805035726437564),
#   np.float64(0.004166666666666667)),
#  'these': (np.float64(0.13201769309288874), np.float64(0.24)),
#  'explains': (np.float64(0.0006805035726437564), np.float64(0.0025)),
#  'murphy': (np.float64(0.0), np.float64(0.059166666666666666)),
#  '09': (np.float64(0.012589316093909493), np.float64(0.12916666666666668)),
#  'version': (np.float64(0.06736985369173189), np.float64(0.03833333333333333)),
#  'apply': (np.float64(0.015311330384484519), np.float64(0.005)),
#  'seen': (np.float64(0.01701258931609391), np.float64(0.024166666666666666)),
#  'value': (np.float64(0.033684926845865944), np.float64(0.05)),
#  'has': (np.float64(0.1793126913916298), np.float64(0.2833333333333333)),
#  'tim': (np.float64(0.0023817625042531474), np.float64(0.041666666666666664)),
#  'final': (np.float64(0.020074855392990813), np.float64(0.0625)),
#  'go': (np.float64(0.09697175910173528), np.float64(0.105)),
#  'first': (np.float64(0.07213337870023817), np.float64(0.10583333333333333)),
#  'especially': (np.float64(0.010888057162300102),
#   np.float64(0.016666666666666666)),
#  'develop': (np.float64(0.016332085743450152),
#   np.float64(0.029166666666666667)),
#  'matrix': (np.float64(0.00374276964954066), np.float64(0.009166666666666667)),
#  'those': (np.float64(0.055801292956788026), np.float64(0.06416666666666666)),
#  'appropriately': (np.float64(0.0006805035726437564),
#   np.float64(0.004166666666666667)),
#  'exhaustive': (np.float64(0.0), np.float64(0.005)),
#  'assignments': (np.float64(0.0), np.float64(0.018333333333333333)),
#  'commodity': (np.float64(0.001701258931609391), np.float64(0.0775)),
#  'items': (np.float64(0.034365430418509695), np.float64(0.04583333333333333)),
#  'completion': (np.float64(0.0027220142905750254),
#   np.float64(0.021666666666666667)),
#  'rather': (np.float64(0.006124532153793808),
#   np.float64(0.034166666666666665)),
#  'applied': (np.float64(0.0027220142905750254),
#   np.float64(0.010833333333333334)),
#  'arrive': (np.float64(0.002041510717931269), np.float64(0.0125)),
#  'consists': (np.float64(0.004423273222184417),
#   np.float64(0.004166666666666667)),
#  'largest': (np.float64(0.014630826811840763), np.float64(0.01)),
#  'controls': (np.float64(0.0010207553589656345),
#   np.float64(0.043333333333333335)),
#  'any': (np.float64(0.22048315753657707), np.float64(0.39166666666666666)),
#  'r': (np.float64(0.10854031983667914), np.float64(0.0625)),
#  'justify': (np.float64(0.0003402517863218782),
#   np.float64(0.004166666666666667)),
#  'steve': (np.float64(0.004423273222184417), np.float64(0.08333333333333333)),
#  'viewed': (np.float64(0.0003402517863218782),
#   np.float64(0.005833333333333334)),
#  '2000': (np.float64(0.012929567880231372), np.float64(0.31166666666666665)),
#  'limits': (np.float64(0.0013610071452875127),
#   np.float64(0.023333333333333334)),
#  'surely': (np.float64(0.001701258931609391), np.float64(0.0025)),
#  'polish': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'summary': (np.float64(0.0006805035726437564), np.float64(0.0725)),
#  'out': (np.float64(0.19870704321197685), np.float64(0.19916666666666666)),
#  'repeat': (np.float64(0.004083021435862538),
#   np.float64(0.004166666666666667)),
#  'part': (np.float64(0.06158557332425995), np.float64(0.06416666666666666)),
#  'rac': (np.float64(0.01701258931609391), np.float64(0.049166666666666664)),
#  'gail': (np.float64(0.0), np.float64(0.010833333333333334)),
#  'single': (np.float64(0.010207553589656346), np.float64(0.01)),
#  'corp': (np.float64(0.009867301803334467), np.float64(0.20083333333333334)),
#  'because': (np.float64(0.0826811840762164), np.float64(0.0925)),
#  'position': (np.float64(0.038448451854372234),
#   np.float64(0.07583333333333334)),
#  'institution': (np.float64(0.001701258931609391), np.float64(0.0025)),
#  'sponsors': (np.float64(0.0023817625042531474),
#   np.float64(0.004166666666666667)),
#  'nuances': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'seems': (np.float64(0.004423273222184417), np.float64(0.023333333333333334)),
#  'port': (np.float64(0.002041510717931269), np.float64(0.02666666666666667)),
#  'points': (np.float64(0.00374276964954066), np.float64(0.0275)),
#  'ask': (np.float64(0.030622660768969037), np.float64(0.035833333333333335)),
#  'witnessed': (np.float64(0.0003402517863218782),
#   np.float64(0.0008333333333333334)),
#  'treatment': (np.float64(0.006124532153793808), np.float64(0.005)),
#  '10': (np.float64(0.15685607349438585), np.float64(0.17666666666666667)),
#  'result': (np.float64(0.04899625723035046), np.float64(0.04)),
#  'lack': (np.float64(0.008166042871725076), np.float64(0.009166666666666667)),
#  'spent': (np.float64(0.03810820006805036), np.float64(0.009166666666666667)),
#  'made': (np.float64(0.11398434841782919), np.float64(0.1025)),
#  'cornfield': (np.float64(0.0), np.float64(0.03916666666666667)),
#  'too': (np.float64(0.05648179652943178), np.float64(0.03666666666666667)),
#  'become': (np.float64(0.04899625723035046), np.float64(0.0275)),
#  'reviews': (np.float64(0.007825791085403199),
#   np.float64(0.023333333333333334)),
#  'communicate': (np.float64(0.003062266076896904), np.float64(0.0225)),
#  'tool': (np.float64(0.007825791085403199), np.float64(0.008333333333333333)),
#  'power': (np.float64(0.027220142905750255), np.float64(0.08666666666666667)),
#  'processes': (np.float64(0.006124532153793808), np.float64(0.055)),
#  'hill': (np.float64(0.004763525008506295), np.float64(0.011666666666666667)),
#  'ect': (np.float64(0.0010207553589656345), np.float64(0.32083333333333336)),
#  '3': (np.float64(0.21265736645117386), np.float64(0.20916666666666667)),
#  'answering': (np.float64(0.0003402517863218782),
#   np.float64(0.0016666666666666668)),
#  'incompleteness': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'brent': (np.float64(0.0), np.float64(0.10833333333333334)),
#  'turmoil': (np.float64(0.0010207553589656345),
#   np.float64(0.0008333333333333334)),
#  'exchange': (np.float64(0.03028240898264716),
#   np.float64(0.019166666666666665)),
#  'counterpart': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'relatively': (np.float64(0.003402517863218782), np.float64(0.01)),
#  '05': (np.float64(0.02041510717931269), np.float64(0.0925)),
#  'sloman': (np.float64(0.0), np.float64(0.0075)),
#  'cc': (np.float64(0.0010207553589656345), np.float64(0.34833333333333333)),
#  'based': (np.float64(0.05512078938414427), np.float64(0.07416666666666667)),
#  'amsterdam': (np.float64(0.0027220142905750254),
#   np.float64(0.0016666666666666668)),
#  'loss': (np.float64(0.01497107859816264), np.float64(0.018333333333333333)),
#  'process': (np.float64(0.03470568220483158), np.float64(0.20083333333333334)),
#  'projects': (np.float64(0.028921401837359646), np.float64(0.03)),
#  'below': (np.float64(0.09288873766587274), np.float64(0.1325)),
#  'following': (np.float64(0.092208234093229), np.float64(0.18083333333333335)),
#  'lay': (np.float64(0.0027220142905750254), np.float64(0.01)),
#  'e': (np.float64(0.20823409322898945), np.float64(0.19333333333333333)),
#  'employees': (np.float64(0.007145287512759442),
#   np.float64(0.059166666666666666)),
#  'website': (np.float64(0.15175229669955767),
#   np.float64(0.016666666666666666)),
#  'regarding': (np.float64(0.019734603606668934),
#   np.float64(0.12166666666666667)),
#  'jeffrey': (np.float64(0.0006805035726437564),
#   np.float64(0.041666666666666664)),
#  'sutton': (np.float64(0.0), np.float64(0.020833333333333332)),
#  'america': (np.float64(0.023137121469887716),
#   np.float64(0.08583333333333333)),
#  'hannon': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'chris': (np.float64(0.0013610071452875127), np.float64(0.04583333333333333)),
#  'joseph': (np.float64(0.0023817625042531474),
#   np.float64(0.025833333333333333)),
#  '50': (np.float64(0.092208234093229), np.float64(0.034166666666666665)),
#  'skilling': (np.float64(0.0), np.float64(0.02)),
#  'cliff': (np.float64(0.0003402517863218782),
#   np.float64(0.004166666666666667)),
#  'bradford': (np.float64(0.0), np.float64(0.011666666666666667)),
#  'kenneth': (np.float64(0.0013610071452875127),
#   np.float64(0.010833333333333334)),
#  'wanda': (np.float64(0.0), np.float64(0.02)),
#  'pm': (np.float64(0.013610071452875128), np.float64(0.285)),
#  '00': (np.float64(0.07213337870023817), np.float64(0.19083333333333333)),
#  'north': (np.float64(0.01735284110241579), np.float64(0.08416666666666667)),
#  'executives': (np.float64(0.006464783940115686),
#   np.float64(0.0033333333333333335)),
#  'valdez': (np.float64(0.0), np.float64(0.0033333333333333335)),
#  'taylor': (np.float64(0.0013610071452875127), np.float64(0.0225)),
#  'greg': (np.float64(0.0010207553589656345), np.float64(0.05416666666666667)),
#  'opinion': (np.float64(0.01497107859816264),
#   np.float64(0.009166666666666667)),
#  'vince': (np.float64(0.0003402517863218782), np.float64(0.0075)),
#  'causey': (np.float64(0.0003402517863218782), np.float64(0.055)),
#  'well': (np.float64(0.05444028581150051), np.float64(0.15416666666666667)),
#  'veronica': (np.float64(0.0003402517863218782),
#   np.float64(0.009166666666666667)),
#  'fallon': (np.float64(0.0003402517863218782),
#   np.float64(0.0016666666666666668)),
#  'message': (np.float64(0.16604287172507656), np.float64(0.11166666666666666)),
#  'j': (np.float64(0.041850969717591016), np.float64(0.05333333333333334)),
#  'communications': (np.float64(0.007825791085403199),
#   np.float64(0.03333333333333333)),
#  'buy': (np.float64(0.0796189179993195), np.float64(0.0475)),
#  's': (np.float64(0.3011228308948622), np.float64(0.4225)),
#  'perez': (np.float64(0.0013610071452875127),
#   np.float64(0.018333333333333333)),
#  'abel': (np.float64(0.0), np.float64(0.019166666666666665)),
#  'baxter': (np.float64(0.0003402517863218782), np.float64(0.025)),
#  'access': (np.float64(0.04933650901667234), np.float64(0.09)),
#  'eugenio': (np.float64(0.0), np.float64(0.035)),
#  'changed': (np.float64(0.009867301803334467),
#   np.float64(0.029166666666666667)),
#  'thoughts': (np.float64(0.003062266076896904),
#   np.float64(0.03916666666666667)),
#  'delete': (np.float64(0.012929567880231372),
#   np.float64(0.005833333333333334)),
#  'jim': (np.float64(0.001701258931609391), np.float64(0.034166666666666665)),
#  '9': (np.float64(0.053079278666212995), np.float64(0.095)),
#  'liz': (np.float64(0.0003402517863218782), np.float64(0.0033333333333333335)),
#  'lavorato': (np.float64(0.0), np.float64(0.029166666666666667)),
#  'your': (np.float64(0.6750595440626064), np.float64(0.3958333333333333)),
#  'moscoso': (np.float64(0.0), np.float64(0.034166666666666665)),
#  'reports': (np.float64(0.011908812521265737),
#   np.float64(0.07416666666666667)),
#  'rick': (np.float64(0.0006805035726437564), np.float64(0.07333333333333333)),
#  'executive': (np.float64(0.004763525008506295),
#   np.float64(0.03833333333333333)),
#  '34': (np.float64(0.011568560734943858), np.float64(0.029166666666666667)),
#  'curry': (np.float64(0.0006805035726437564),
#   np.float64(0.018333333333333333)),
#  'whalley': (np.float64(0.0), np.float64(0.014166666666666666)),
#  'william': (np.float64(0.0013610071452875127),
#   np.float64(0.018333333333333333)),
#  '02': (np.float64(0.010547805375978225), np.float64(0.0875)),
#  'haedicke': (np.float64(0.0), np.float64(0.01)),
#  'kaminski': (np.float64(0.0), np.float64(0.005)),
#  'posted': (np.float64(0.001701258931609391), np.float64(0.03166666666666667)),
#  'performance': (np.float64(0.03878870364069412),
#   np.float64(0.056666666666666664)),
#  'requests': (np.float64(0.006124532153793808),
#   np.float64(0.023333333333333334)),
#  'supervisor': (np.float64(0.0006805035726437564), np.float64(0.03)),
#  'company': (np.float64(0.15685607349438585), np.float64(0.07333333333333333)),
#  'selected': (np.float64(0.01939435182034706),
#   np.float64(0.021666666666666667)),
#  'sbeck': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'operating': (np.float64(0.01939435182034706),
#   np.float64(0.030833333333333334)),
#  'participate': (np.float64(0.01122830894862198),
#   np.float64(0.030833333333333334)),
#  '6724': (np.float64(0.0), np.float64(0.0033333333333333335)),
#  'reference': (np.float64(0.023137121469887716),
#   np.float64(0.023333333333333334)),
#  'com': (np.float64(0.31303164341612794), np.float64(0.14)),
#  'perfmgmt': (np.float64(0.0), np.float64(0.009166666666666667)),
#  'critical': (np.float64(0.004763525008506295),
#   np.float64(0.03833333333333333)),
#  'employee': (np.float64(0.00374276964954066), np.float64(0.0325)),
#  'success': (np.float64(0.07825791085403198), np.float64(0.0425)),
#  'mail': (np.float64(0.18373596461381422), np.float64(0.10333333333333333)),
#  '19': (np.float64(0.05512078938414427), np.float64(0.08166666666666667)),
#  'begin': (np.float64(0.01497107859816264), np.float64(0.035833333333333335)),
#  'campos': (np.float64(0.0003402517863218782),
#   np.float64(0.0008333333333333334)),
#  'reviewer': (np.float64(0.0003402517863218782), np.float64(0.01)),
#  '44': (np.float64(0.012249064307587616), np.float64(0.03166666666666667)),
#  'skinner': (np.float64(0.0), np.float64(0.008333333333333333)),
#  'input': (np.float64(0.003402517863218782), np.float64(0.03916666666666667)),
#  '974': (np.float64(0.0), np.float64(0.0033333333333333335)),
#  'immediately': (np.float64(0.040149710785981625),
#   np.float64(0.034166666666666665)),
#  'providing': (np.float64(0.01837359646138142),
#   np.float64(0.035833333333333335)),
#  'name': (np.float64(0.08029942157196325), np.float64(0.095)),
# ...
#  'joll': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'gretchen': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'doh': (np.float64(0.0), np.float64(0.0033333333333333335)),
#  'dempsey': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'shona': (np.float64(0.0), np.float64(0.10916666666666666)),
#  'mary': (np.float64(0.007145287512759442), np.float64(0.09166666666666666)),
#  'report': (np.float64(0.05341953045253488), np.float64(0.1525)),
#  'davis': (np.float64(0.0010207553589656345),
#   np.float64(0.018333333333333333)),
#  '22': (np.float64(0.025859135760462743), np.float64(0.06666666666666667)),
#  'lerea': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'robin': (np.float64(0.0), np.float64(0.0025)),
#  '39995': (np.float64(0.0), np.float64(0.0025)),
#  'linda': (np.float64(0.0013610071452875127),
#   np.float64(0.011666666666666667)),
#  'solis': (np.float64(0.0), np.float64(0.0025)),
#  'h': (np.float64(0.022116366110922082), np.float64(0.0275)),
#  'chance': (np.float64(0.023477373256209595), np.float64(0.0225)),
#  'monday': (np.float64(0.00748553929908132), np.float64(0.10333333333333333)),
#  'co': (np.float64(0.034365430418509695), np.float64(0.03333333333333333)),
#  'tumey': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'skarness': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'hargrave': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'wilson': (np.float64(0.001701258931609391), np.float64(0.06666666666666667)),
#  'pamela': (np.float64(0.0003402517863218782), np.float64(0.0075)),
#  'riedel': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'chavira': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'gibson': (np.float64(0.0), np.float64(0.0025)),
#  'title': (np.float64(0.00748553929908132), np.float64(0.008333333333333333)),
#  '52': (np.float64(0.00918679823069071), np.float64(0.025833333333333333)),
#  'george': (np.float64(0.004083021435862538),
#   np.float64(0.018333333333333333)),
#  'sheila': (np.float64(0.0), np.float64(0.06333333333333334)),
#  'hire': (np.float64(0.0), np.float64(0.009166666666666667)),
#  'strambler': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'dan': (np.float64(0.003402517863218782), np.float64(0.0125)),
#  'parra': (np.float64(0.0), np.float64(0.010833333333333334)),
#  'jennifer': (np.float64(0.002041510717931269), np.float64(0.03)),
#  'dalton': (np.float64(0.0), np.float64(0.0025)),
#  '00834': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'solmonson': (np.float64(0.0), np.float64(0.050833333333333335)),
#  'smith': (np.float64(0.004083021435862538), np.float64(0.0375)),
#  'd': (np.float64(0.08166042871725077), np.float64(0.1125)),
#  'ann': (np.float64(0.002041510717931269), np.float64(0.005833333333333334)),
#  'hr': (np.float64(0.0010207553589656345), np.float64(0.035)),
#  'teresa': (np.float64(0.0003402517863218782),
#   np.float64(0.006666666666666667)),
#  'orientation': (np.float64(0.0), np.float64(0.009166666666666667)),
#  'bryce': (np.float64(0.0006805035726437564),
#   np.float64(0.019166666666666665)),
#  '000': (np.float64(0.11738686628104797), np.float64(0.0325)),
#  'felicia': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  '02631': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'continue': (np.float64(0.03402517863218782),
#   np.float64(0.07833333333333334)),
#  'kyle': (np.float64(0.0), np.float64(0.0033333333333333335)),
#  'k': (np.float64(0.026539639333106498), np.float64(0.0325)),
#  'resources': (np.float64(0.02075535896563457),
#   np.float64(0.09083333333333334)),
#  '00720': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'human': (np.float64(0.01122830894862198), np.float64(0.028333333333333332)),
#  'vargo': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'sarah': (np.float64(0.0010207553589656345),
#   np.float64(0.011666666666666667)),
#  'susan': (np.float64(0.001701258931609391), np.float64(0.0275)),
#  'burns': (np.float64(0.0013610071452875127),
#   np.float64(0.0008333333333333334)),
#  'sprock': (np.float64(0.0), np.float64(0.0025)),
#  'bien': (np.float64(0.0003402517863218782),
#   np.float64(0.0008333333333333334)),
#  'carmen': (np.float64(0.0003402517863218782),
#   np.float64(0.0016666666666666668)),
#  'n': (np.float64(0.040149710785981625), np.float64(0.015833333333333335)),
#  'yes': (np.float64(0.022116366110922082), np.float64(0.009166666666666667)),
#  '00813': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'specialist': (np.float64(0.00374276964954066), np.float64(0.01)),
#  'lee': (np.float64(0.001701258931609391), np.float64(0.015833333333333335)),
#  'walton': (np.float64(0.0), np.float64(0.01)),
#  '413': (np.float64(0.0), np.float64(0.0025)),
#  '02372': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'allison': (np.float64(0.0003402517863218782),
#   np.float64(0.0008333333333333334)),
#  'weekly': (np.float64(0.010207553589656346), np.float64(0.04083333333333333)),
#  'angela': (np.float64(0.0006805035726437564),
#   np.float64(0.006666666666666667)),
#  'rep': (np.float64(0.001701258931609391), np.float64(0.0125)),
#  'peikert': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'lessner': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'robert': (np.float64(0.005103776794828173), np.float64(0.0525)),
#  'schnauber': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'fgt': (np.float64(0.0), np.float64(0.004166666666666667)),
#  'merlyn': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'olson': (np.float64(0.0013610071452875127),
#   np.float64(0.010833333333333334)),
#  'knudsen': (np.float64(0.0), np.float64(0.004166666666666667)),
#  'poston': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'grimes': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'jackson': (np.float64(0.001701258931609391),
#   np.float64(0.03333333333333333)),
#  'wysatta': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'padron': (np.float64(0.0), np.float64(0.0025)),
#  'oxley': (np.float64(0.0), np.float64(0.014166666666666666)),
#  'training': (np.float64(0.011568560734943858),
#   np.float64(0.02666666666666667)),
#  'b': (np.float64(0.054780537597822386), np.float64(0.05333333333333334)),
#  'janie': (np.float64(0.0003402517863218782),
#   np.float64(0.0033333333333333335)),
#  'gpgfin': (np.float64(0.0), np.float64(0.010833333333333334)),
#  'everyone': (np.float64(0.018033344675059543), np.float64(0.06)),
#  'schafer': (np.float64(0.0003402517863218782), np.float64(0.0025)),
#  'bobby': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'brad': (np.float64(0.0006805035726437564), np.float64(0.014166666666666666)),
#  'colwell': (np.float64(0.0), np.float64(0.021666666666666667)),
#  '53': (np.float64(0.00374276964954066), np.float64(0.016666666666666666)),
#  'c': (np.float64(0.04117046614494726), np.float64(0.0825)),
#  'dave': (np.float64(0.0006805035726437564), np.float64(0.04083333333333333)),
#  '100': (np.float64(0.08336168764886015), np.float64(0.018333333333333333)),
#  '78': (np.float64(0.0023817625042531474), np.float64(0.0025)),
#  'participated': (np.float64(0.0006805035726437564),
#   np.float64(0.006666666666666667)),
#  'jeannie': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  '04': (np.float64(0.007145287512759442), np.float64(0.08916666666666667)),
#  'chor': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'barrow': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'jandrell': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'mahendra': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'stubblefield': (np.float64(0.0), np.float64(0.008333333333333333)),
#  'grest': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'williams': (np.float64(0.004423273222184417), np.float64(0.0125)),
#  'details': (np.float64(0.05205852330724736), np.float64(0.0725)),
#  'lisa': (np.float64(0.002041510717931269), np.float64(0.0275)),
#  'lim': (np.float64(0.0013610071452875127), np.float64(0.0075)),
#  'keith': (np.float64(0.0013610071452875127),
#   np.float64(0.010833333333333334)),
#  'patrick': (np.float64(0.0010207553589656345),
#   np.float64(0.019166666666666665)),
#  '94': (np.float64(0.0027220142905750254), np.float64(0.0016666666666666668)),
#  'castleman': (np.float64(0.0), np.float64(0.0025)),
#  'drew': (np.float64(0.009867301803334467), np.float64(0.005833333333333334)),
#  'daler': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'selzer': (np.float64(0.0), np.float64(0.0025)),
#  'bonnard': (np.float64(0.0), np.float64(0.0025)),
#  'dashboard': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'apollo': (np.float64(0.0), np.float64(0.03916666666666667)),
#  'gilchrist': (np.float64(0.0), np.float64(0.0025)),
#  'coleman': (np.float64(0.0), np.float64(0.005833333333333334)),
#  'denise': (np.float64(0.0003402517863218782),
#   np.float64(0.0033333333333333335)),
#  '40': (np.float64(0.023477373256209595), np.float64(0.035)),
#  '16': (np.float64(0.025518883974140864), np.float64(0.08833333333333333)),
#  'jill': (np.float64(0.0), np.float64(0.005833333333333334)),
#  'melissa': (np.float64(0.0), np.float64(0.02666666666666667)),
#  'brian': (np.float64(0.002041510717931269), np.float64(0.04833333333333333)),
#  'et': (np.float64(0.00952705001701259), np.float64(0.006666666666666667)),
#  'perkins': (np.float64(0.0), np.float64(0.0125)),
#  'morrow': (np.float64(0.0), np.float64(0.0033333333333333335)),
#  'greek': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  '68': (np.float64(0.004083021435862538), np.float64(0.0016666666666666668)),
#  'dell': (np.float64(0.0003402517863218782),
#   np.float64(0.0033333333333333335)),
#  'morton': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'scott': (np.float64(0.004763525008506295), np.float64(0.07916666666666666)),
#  '83': (np.float64(0.005784280367471929), np.float64(0.0025)),
#  'franz': (np.float64(0.001701258931609391),
#   np.float64(0.0016666666666666668)),
#  'gpg': (np.float64(0.0), np.float64(0.005)),
#  'butts': (np.float64(0.0), np.float64(0.0025)),
#  'cynthia': (np.float64(0.0), np.float64(0.013333333333333334)),
#  'units': (np.float64(0.0013610071452875127),
#   np.float64(0.029166666666666667)),
#  'joyce': (np.float64(0.001701258931609391), np.float64(0.0125)),
#  'lorna': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'rice': (np.float64(0.0010207553589656345), np.float64(0.005)),
#  'stubbs': (np.float64(0.0), np.float64(0.004166666666666667)),
#  'fink': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'ellen': (np.float64(0.0), np.float64(0.005)),
#  'yates': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'o': (np.float64(0.06975161619598502), np.float64(0.0175)),
#  'willie': (np.float64(0.0), np.float64(0.004166666666666667)),
#  'andrea': (np.float64(0.0003402517863218782),
#   np.float64(0.025833333333333333)),
#  'bob': (np.float64(0.0013610071452875127), np.float64(0.09583333333333334)),
#  'debbie': (np.float64(0.0003402517863218782),
#   np.float64(0.021666666666666667)),
#  'kumar': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'beth': (np.float64(0.0), np.float64(0.07416666666666667)),
#  'attendance': (np.float64(0.0013610071452875127),
#   np.float64(0.014166666666666666)),
#  'encouraging': (np.float64(0.001701258931609391), np.float64(0.0025)),
#  'classes': (np.float64(0.0006805035726437564),
#   np.float64(0.008333333333333333)),
#  'goh': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'erwin': (np.float64(0.0), np.float64(0.006666666666666667)),
#  'miguel': (np.float64(0.0006805035726437564), np.float64(0.005)),
#  'sommers': (np.float64(0.0), np.float64(0.0025)),
#  'carol': (np.float64(0.0003402517863218782), np.float64(0.015)),
#  '76': (np.float64(0.0023817625042531474), np.float64(0.0025)),
#  'turn': (np.float64(0.01667233752977203), np.float64(0.010833333333333334)),
#  'sparger': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'amabile': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'gco': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'bennett': (np.float64(0.0), np.float64(0.004166666666666667)),
#  'nikkel': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'ranendra': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'rod': (np.float64(0.0006805035726437564), np.float64(0.005833333333333334)),
#  'howard': (np.float64(0.002041510717931269),
#   np.float64(0.015833333333333335)),
#  'kathryn': (np.float64(0.0), np.float64(0.01)),
#  '64': (np.float64(0.008846546444368834), np.float64(0.0033333333333333335)),
#  'becker': (np.float64(0.0), np.float64(0.0033333333333333335)),
#  'charlene': (np.float64(0.0), np.float64(0.016666666666666666)),
#  'attachment': (np.float64(0.0023817625042531474),
#   np.float64(0.018333333333333333)),
#  'traylor': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'hayslett': (np.float64(0.0), np.float64(0.0025)),
#  'ervin': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'ena': (np.float64(0.0), np.float64(0.08083333333333333)),
#  'howes': (np.float64(0.0), np.float64(0.0025)),
#  '39': (np.float64(0.035386185777475335), np.float64(0.024166666666666666)),
#  'cagney': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'fance': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'cassandra': (np.float64(0.0), np.float64(0.024166666666666666)),
#  'kathy': (np.float64(0.0003402517863218782), np.float64(0.0075)),
#  'lawrence': (np.float64(0.0006805035726437564), np.float64(0.0025)),
#  'biren': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'sengupta': (np.float64(0.0003402517863218782), np.float64(0.0025)),
#  'todd': (np.float64(0.0006805035726437564), np.float64(0.0375)),
#  'sherry': (np.float64(0.0), np.float64(0.0033333333333333335)),
#  'statistics': (np.float64(0.0023817625042531474), np.float64(0.005)),
#  'hughes': (np.float64(0.0006805035726437564), np.float64(0.0075)),
#  'ray': (np.float64(0.0013610071452875127), np.float64(0.0075)),
#  'schultz': (np.float64(0.0010207553589656345), np.float64(0.02)),
#  'chatham': (np.float64(0.0), np.float64(0.0025)),
#  'projected': (np.float64(0.003062266076896904), np.float64(0.0075)),
#  'attend': (np.float64(0.00374276964954066), np.float64(0.058333333333333334)),
#  'yowman': (np.float64(0.0), np.float64(0.004166666666666667)),
#  'wes': (np.float64(0.0), np.float64(0.0275)),
#  'sullivan': (np.float64(0.0), np.float64(0.006666666666666667)),
#  'donnis': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  '32': (np.float64(0.008166042871725076), np.float64(0.024166666666666666)),
#  'petruszka': (np.float64(0.0), np.float64(0.0033333333333333335)),
#  'gerry': (np.float64(0.0), np.float64(0.004166666666666667)),
#  'kokas': (np.float64(0.0), np.float64(0.0033333333333333335)),
#  'harman': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'ellis': (np.float64(0.0), np.float64(0.0016666666666666668)),
#  'ots': (np.float64(0.0), np.float64(0.0025)),
#  'eckels': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'wade': (np.float64(0.0), np.float64(0.009166666666666667)),
#  'mclean': (np.float64(0.0), np.float64(0.0025)),
#  '91': (np.float64(0.005103776794828173), np.float64(0.0025)),
#  'lynch': (np.float64(0.0010207553589656345), np.float64(0.0025)),
#  'marlow': (np.float64(0.0), np.float64(0.0025)),
#  'ron': (np.float64(0.0003402517863218782), np.float64(0.0075)),
#  'attended': (np.float64(0.001701258931609391),
#   np.float64(0.005833333333333334)),
#  '21': (np.float64(0.044232732221844165), np.float64(0.06333333333333334)),
#  'kent': (np.float64(0.0), np.float64(0.0033333333333333335)),
#  'margaret': (np.float64(0.0006805035726437564),
#   np.float64(0.0016666666666666668)),
#  'diane': (np.float64(0.001701258931609391), np.float64(0.009166666666666667)),
#  '8': (np.float64(0.13712146988771692), np.float64(0.10416666666666667)),
#  'coombe': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'sa': (np.float64(0.01122830894862198), np.float64(0.0125)),
#  'woods': (np.float64(0.0006805035726437564), np.float64(0.0025)),
#  'addendum': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'angelique': (np.float64(0.0), np.float64(0.0008333333333333334)),
#  'guy': (np.float64(0.0027220142905750254), np.float64(0.014166666666666666)),
#  ...}

# %% [markdown]
# ### Классификация

# %%
def classify_message(words_prob, message, p_spam, p_ham):
    """
    Функция классифицирует message и определяет к какому классу оно относится 
    :param words_prob: словарь вида {key = слово; value = [P(вхождения в сообщения spam), P(вхождения в сообщения ham)]
    :param message: сообщение для классификации
    :param p_spam: Априорная вероятность, сообщение - спам
    :param p_ham: Априорная вероятность, сообщение - не спам
    :return:
    """
    message_words = preprocessing(message)
    log_prob_spam = np.log(p_spam)
    log_prob_ham = np.log(p_ham)
    for word in message_words:
        if word in words_prob:
            prob_word_in_spam, prob_word_in_ham = words_prob[word]
            if ( prob_word_in_spam == 0 
            log_prob_spam += np.log(prob_word_in_spam)
            log_prob_ham += np.log(prob_word_in_ham)
    if log_prob_spam > log_prob_ham :
        return 'spam'
    return 'ham'

# %% [markdown]
# ### Тестирование

# %%
numb_right_classified = 0; # счетчик точно классифицированных писем
count_emails = 0

# %%
def testing(directory,words_prob, p_spam, p_ham, class_email):
    global numb_right_classified
    global count_emails
    for filename in os.listdir(directory):
        with open(os.path.join(directory, filename), 'r') as file:
            res = classify_message(words_prob, file.read(), p_spam, p_ham)
            if res == class_email : numb_right_classified+=1
            count_emails+=1
    return

# %%
dir_spam_test = r"C:\Users\Ilya\Desktop\ТВиМС\data2\data\spam_test"
dir_ham_test = r"C:\Users\Ilya\Desktop\ТВиМС\data2\data\ham_test"

# %%
testing(dir_spam_test, words_prob, p_spam, p_ham, 'spam')
testing(dir_ham_test, words_prob, p_spam, p_ham, 'ham')

accuracy = numb_right_classified/ count_emails
print(f"Итоговая точность классификации: {accuracy:.2f}")
# Out:
# C:\Users\Ilya\AppData\Local\Temp\ipykernel_12408\231974650.py:17: RuntimeWarning: divide by zero encountered in log
#   log_prob_ham += np.log(prob_word_in_ham)
# C:\Users\Ilya\AppData\Local\Temp\ipykernel_12408\231974650.py:16: RuntimeWarning: divide by zero encountered in log
#   log_prob_spam += np.log(prob_word_in_spam)
# Итоговая точность классификации: 0.71
